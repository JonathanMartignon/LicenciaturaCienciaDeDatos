# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanMartignon/Datos_Masitvos/blob/master/Proyecto_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Proyecto 10**
#
# * Martiñón Luna Jonathan José
#
# Fecha de Entrega: 24 Abril, 2020
#
# ---
#
# Genera un buscador de imágenes usando índice inverso y visualiza las imágenes con mayor similitud de Jaccard, MinMax y Coseno. Para su implementación debes usar listas de Python y NumPy y la base de datos a emplear es:  imágenes de edificios de París.
#
# https://www.robots.ox.ac.uk/~vgg/data/parisbuildings/
#
# ---
#
# Las bolsas ya están divididas en entrenamiento (dogs_ent.corpus y paris_ent.corpus) y validación (dogs_val.corpus y paris_ent.corpus).
# Se incluye la lista de imágenes para cada conjunto (de entrenamiento y validación)
#
# ---
#
# El formato de las bolsas es el siguiente:
#
# size_of_list_1 item1_1:freq1_1 item2_1:freq2_1 ...
#
# size_of_list_1 item1_2:freq1_22 item2_2:freq2_2 ...
#
# ...                        ...
#
# size_of_list_N item1_N:freq1_N item2_N:freq2_N ...
#
#
# Por ejemplo:
#
# 6 3:9 4:8 7:5 12:1 16:5 18:5
#
# 3 2:7 3:4 8:5
#
# 4 1:9 2:10 16:8 17:10
#
# 4 10:10 11:4 15:8 16:3
#
# 3 0:1 14:9 15:10
#
# ---

# %% [markdown]
# Inicio

# %% [markdown]
# Creando las carpetas para almacenar

# %%
# !mkdir /content/Data
# !mkdir /content/Data/Entrenamiento /content/Data/Validacion /content/Data/Imagenes

# %% [markdown]
# Descargando nuestros datos

# %%
# !wget -O Data.zip https://www.dropbox.com/sh/8rf98easjw4dvt6/AADUGsVaUW5nvAk4CESAJQf5a?dl=0/lista_ent_paris.txt?dl=1
# !wget -O Imagenes.tgz http://www.robots.ox.ac.uk/~vgg/data/parisbuildings/paris_1.tgz
# !wget -O Imagenes2.tgz http://www.robots.ox.ac.uk/~vgg/data/parisbuildings/paris_2.tgz
# Out:
# --2020-04-22 10:25:50--  https://www.dropbox.com/sh/8rf98easjw4dvt6/AADUGsVaUW5nvAk4CESAJQf5a?dl=0/lista_ent_paris.txt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/raw/8rf98easjw4dvt6/AADUGsVaUW5nvAk4CESAJQf5a [following]
# --2020-04-22 10:25:50--  https://www.dropbox.com/sh/raw/8rf98easjw4dvt6/AADUGsVaUW5nvAk4CESAJQf5a
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucbe4783910cd2127f54f03e404f.dl.dropboxusercontent.com/zip_download_get/AZv8PYDu_-Kk91UHpUICiuHpAnUv6plevPpELZxH-u9nKlXAmi2a3nAyTOb9P6d68n9e54O6TEWFVYXyegoQMp9VKtTa1KmkF5wWeDiK1POSPA [following]
# --2020-04-22 10:25:51--  https://ucbe4783910cd2127f54f03e404f.dl.dropboxusercontent.com/zip_download_get/AZv8PYDu_-Kk91UHpUICiuHpAnUv6plevPpELZxH-u9nKlXAmi2a3nAyTOb9P6d68n9e54O6TEWFVYXyegoQMp9VKtTa1KmkF5wWeDiK1POSPA
# Resolving ucbe4783910cd2127f54f03e404f.dl.dropboxusercontent.com (ucbe4783910cd2127f54f03e404f.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601b:6::a27d:806
# Connecting to ucbe4783910cd2127f54f03e404f.dl.dropboxusercontent.com (ucbe4783910cd2127f54f03e404f.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31038640 (30M) [application/zip]
# Saving to: ‘Data.zip’
#
# Data.zip            100%[===================>]  29.60M  51.7MB/s    in 0.6s
#
# 2020-04-22 10:25:52 (51.7 MB/s) - ‘Data.zip’ saved [31038640/31038640]
#
# --2020-04-22 10:25:53--  http://www.robots.ox.ac.uk/~vgg/data/parisbuildings/paris_1.tgz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1269538001 (1.2G) [application/x-gzip]
# Saving to: ‘Imagenes.tgz’
#
# Imagenes.tgz        100%[===================>]   1.18G  29.9MB/s    in 41s
#
# 2020-04-22 10:26:34 (29.7 MB/s) - ‘Imagenes.tgz’ saved [1269538001/1269538001]
#
# --2020-04-22 10:26:34--  http://www.robots.ox.ac.uk/~vgg/data/parisbuildings/paris_2.tgz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1343042257 (1.2G) [application/x-gzip]
# Saving to: ‘Imagenes2.tgz’
#
# Imagenes2.tgz       100%[===================>]   1.25G  26.5MB/s    in 53s
#
# 2020-04-22 10:27:28 (24.0 MB/s) - ‘Imagenes2.tgz’ saved [1343042257/1343042257]

# %% [markdown]
# Descomprimiendo

# %%
# !unzip Data.zip
# !tar xzf Imagenes.tgz -C /content/Data/Imagenes
# !tar xzf Imagenes2.tgz
# Out:
# Archive:  Data.zip
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
#  extracting: paris_val.corpus
#  extracting: paris_ent.corpus
#  extracting: lista_val_paris.txt
#  extracting: lista_ent_paris.txt

# %% [markdown]
# Moviendo nuestros archivos

# %%
# !mv paris_val.corpus /content/Data/Validacion/paris_val.txt
# !mv lista_val_paris.txt /content/Data/Validacion
# !mv paris_ent.corpus /content/Data/Entrenamiento/paris_ent.txt
# !mv lista_ent_paris.txt /content/Data/Entrenamiento
# !mv paris/museedorsay /content/Data/Imagenes/paris
# !mv paris/notredame /content/Data/Imagenes/paris
# !mv paris/pantheon /content/Data/Imagenes/paris
# !mv paris/pompidou /content/Data/Imagenes/paris
# !mv paris/sacrecoeur /content/Data/Imagenes/paris
# !mv paris/triomphe /content/Data/Imagenes/paris

# %% [markdown]
# Eliminando los comprimidos que ya no nos sirven

# %%
# !rm -r /content/Data # A veces me equivocaba y debía eliminar la carpeta entera
# !rm /content/Data.zip
# !rm /content/Imagenes.tgz
# !rm /content/Imagenes2.tgz
# !rm -r /content/sample_data # Me 'hacía mosca' esa carpeta
# !rm -r /content/paris

# %% [markdown]
# Una vez que ya tenemos nuestros archivos cargados, podemos proceder a trabajar.
# Empezamos por cargar nuestras funciones de similitud (Extraídas de los notebooks de clase)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from collections import Counter

# %%
#Esta función nos ayudará a igualar listas de diferentes dimensiones
# a = [1,2]
# b = [1,2,3,4]
# aux = [[1,2],[1,2,3,4]]
# Rellena_ceros(aux)
# aux = [[1,2,0,0],[1,2,3,4]]
def Rellena_ceros(listas):
  
  if len(listas[0]) < len(listas[1]):
    for i in range(len(listas[0]),len(listas[1])): # comenzamos en el final del anterior
      listas[0].append(0)
  else:
    for i in range(len(listas[1]),len(listas[0])):
      listas[1].append(0)

  return listas

# %%
# Modificamos internamente, pues le enviamos listas
def similitud_coseno(x, y):
  aux = [x,y]
  aux = Rellena_ceros(aux)
  x = np.asarray(aux[0])
  y = np.asarray(aux[1])
  return (x @ y) / (np.sqrt(x @ x) * np.sqrt(y @ y))

# %%
def similitud_jaccard(x, y):
  inter = 0
  for e in x:
    if e in y:
      inter += 1

  return inter / (len(x) + len(y) - inter)

# %%
def similitud_minmax(x, y):
  aux = [x,y]
  aux = Rellena_ceros(aux)
  x = np.asarray(aux[0])
  y = np.asarray(aux[1])
  c = np.vstack((x,y))
  mn = np.sum(np.min(c, axis=0))
  mx = np.sum(np.max(c, axis=0))
  return mn / mx

# %%
# Probando las distancias entre listas de diferente dimension
b = [1,2,3]
a = [1,2,3,4,5,6]

# %%
# Coseno
similitud_coseno(a,b)
# Out:
# 0.3922322702763681

# %%
# Jaccard
similitud_jaccard(a,b)
# Out:
# 0.3333333333333333

# %%
# MinMax
similitud_minmax(a,b)
# Out:
# 0.2857142857142857

# %% [markdown]
# ---
#
# Esta función se encargará de mostrar nuestra imagen a partir del nombre sin la necesidad de la extensión, es decir, tal y como vienen en nuestras listas
#
# ---

# %%
def obten_imagen(name):

  ruta = '/content/Data/Imagenes/paris/'
  carpeta = name.split('_')[1] + '/'
  ruta += carpeta + name +'.jpg'
  
  # print(ruta)

  imagen = plt.imread(ruta)
  plt.imshow(imagen)
  plt.title(name)
  plt.axis('off')
  plt.show()

# %% [markdown]
# Así mismo, extraemos nuestra clase de Índice inverso, teniendo en cuenta que no hacemos uso de matrices de disperción, nos vemos en la nececidad de modificar la clase

# %%
class IndiceInverso:

  # Me parece que esta función no es necesario que se modifique, pues 
  # En la clase original se convierte el csr en listas, cosa que en este
  # Caso, ya está hecho
  def  __getitem__(self, idx):
    print(f"La pocisión {idx} contiene la característica {self.Ind_Car[idx]}")
    return self.ifs[idx]

  # Esta función igualmente es llamada después de la conversión a listas
  def recupera(self, l):
    # Creo que esta función recibe la bolsa de características de una imagen
    # Y simplemente recupera las imágenes en los que están presentes cada una
    imgs = Counter()
    for Car in l:
      # Ya tenemos la característica, necesitamos su pocisión
      # En nuestro ifs
      self.Index = self.Ind_Car.index(Car)
      #Ahora sí la podemos llamar
      imgs.update(self.ifs[self.Index])

    return imgs

  # Anteriormente from_csr, no se me ocurría un nombre adecuado
  def Add(self, Data): 

    # Data es la lista de listas con cada bolsa


    # Me parece que de acuerdo a lo observado, en el comportamiento del
    # Código anterior, lo que se almacena es el documento (i)
    # De acuerdo a la característica que pertenecen (j)
    # self.ifs[j].append(i)
    # Claro, estaban en otro formato, por lo que había que convertir, sin embargo
    # Este no es el caso, se puede realizar directamente

    # A decir verdad, no entiendo bien cuántas carácterísticas voy a tener,
    # Por lo que es una lista abierta

    

    #Este ciclo se encargará de  orgranizar las características en orden
    # Para evitar tener la 1, 2, 132, y que se tenga mucha distancia
    # Si se ordenan en un arreglo, sabremos que la posición 0 corresponde 
    # a la característica 1, la posición 2 a la característica 2, la posición
    # 3 a la característica 132 y así nos evitamos los espacios de memoria
    # Vacíos

    self.Ind_Car =[] 
    self.ifs = [[]] # Como será una lista de listas, lo inicializamos con una lista incluida

    # i = 0
    for i,bolsa in enumerate(Data):
      print("Analizando bolsa:",i+1)
      #Evaluamos cada bolsa en los datos

      for Car in bolsa:

        #Evaluamos cada característica de la bolsa
        if len(self.Ind_Car) == 0:

          # La primera la añadimos automáticamente
          self.Ind_Car.append(Car)
          # así mismo, sabemos que pertenece al documento 1, por lo que
          # lo añadimos directamente en la otra lista
          self.ifs[0].append(i)  
        else:

          if Car in self.Ind_Car:
            # En caso de que la característica ya esté no hacemos nada
            pass
          else:
          
            # Si no está en nuestra lista, la añadimos
            self.Ind_Car.append(Car)
            # Y añadimos un nuevo espacio (Lista) a nuestro arreglo de índices
            self.ifs.append([])
          
          #Ya que sabemos que está en la lista y ya tenemos un espacio 
          # en el otro arreglo, simplemente añadimos la imagen
          # Con su característica
          self.Index = self.Ind_Car.index(Car) # Obtenemos la pocisión de la característica
          self.ifs[self.Index].append(i)  # Añadimos la imagen a la característica

# %% [markdown]
# Extraemos la función que lee las bolsas, recordamos que a diferencia del ejemplo visto en clase, nuestras bolsas se encuentran solo en 2 archivos, entrenamiento y validación, a diferencia del ejemplo donde teníamos una carpeta de entrenamiento y las bolsas separadas en archivos .txt

# %%
def lee_bolsa(ruta):
  b = []
  with open(ruta, 'r') as f:

    for l in f.readlines():

      # print(l) # En caso de querer ver la bolsa que se está trabajando
      aux = l.split()[1:] # Me parece que no usamos la longitud de la bolsa
      new_list = [] # Lista auxiliar que recogerá los items de cada bolsa

      for item in aux:

        item_split = item.split(':')
        new_list.append(int(item_split[0])) # Sólo tomaremos el item, la frecuencia no

        if int(item_split[1]) != 1:

          print("Valor diferente a 1 ->",item_split[1]) 
          # Las frecuencias a mi parecer siempre eran 1
          # Quería ver si alguna era diferente
          # Cosa que no sucedió

      b.append(new_list) # Añadimos la lista con los items de cada una de las bolsas

  return b

# %% [markdown]
# Modificamos La función que lee las bolsas para que lea las listas

# %%
def lee_lista(ruta):
  b = []
  with open(ruta, 'r') as f:
    for l in f.readlines():
      l = l[:-1] # El último elemento que guardaba era un salto de línea, lo eliminamos "\n"
      b.append(l)
  return b

# %% [markdown]
# ---
# Leyendo Las bolsas
#
# ---

# %%
bolsas_entrenamiento = lee_bolsa('/content/Data/Entrenamiento/paris_ent.txt')

# %%
bolsas_validacion = lee_bolsa('/content/Data/Validacion/paris_val.txt')

# %% [markdown]
# ---
# Leyendo las listas
#
# ---

# %%
Lista_Entr = lee_lista('/content/Data/Entrenamiento/lista_ent_paris.txt')

# %%
Lista_Val = lee_lista('/content/Data/Validacion/lista_val_paris.txt')

# %% [markdown]
# ---
# Verificando los datos en cada una de nuestras listas y bolsas
#
# ---

# %%
print("Contamos con",len(bolsas_entrenamiento),"bolsas de entrenamiento")
print("Los 3 primeros items de la primera bolsa son:",bolsas_entrenamiento[0][0:3])
# Out:
# Contamos con 5112 bolsas de entrenamiento
# Los 3 primeros items de la primera bolsa son: [129026, 147458, 176134]

# %%
print("Contamos con",len(bolsas_validacion),"bolsas de validación")
print("Los 3 primeros items de la primera bolsa son:",bolsas_validacion[0][0:3])
# Out:
# Contamos con 1278 bolsas de validación
# Los 3 primeros items de la primera bolsa son: [225282, 149508, 233476]

# %%
print("Nuestra lista de entrenamiento tiene",len(Lista_Entr),"elementos")
print("Las primeras 3 imágenes son:",Lista_Entr[0:3])
# Out:
# Nuestra lista de entrenamiento tiene 5112 elementos
# Las primeras 3 imágenes son: ['paris_defense_000534', 'paris_general_000904', 'paris_general_001104']

# %%
print("Nuestra lista de validación tiene",len(Lista_Val),"elementos")
print("Las primeras 3 imágenes son:",Lista_Val[0:3])
# Out:
# Nuestra lista de validación tiene 1278 elementos
# Las primeras 3 imágenes son: ['paris_moulinrouge_000529', 'paris_museedorsay_000353', 'paris_pantheon_000517']

# %% [markdown]
# ---
# Llegados a este punto hemos verificado que contamos con la misma cantidad de elementos dentro de nuestras bolsas con sus correspondientes listas, así mismo, hemos corroborado la forma de nuestras bolsas y lo elementos de las mismas.
#
# Realizamos un histograma de nuestras características en nuestro conjunto de entrenamiento
#
# ---

# %%
hist = np.array(bolsas_entrenamiento[0])
for i in range(1,len(bolsas_entrenamiento)):
  np.append(hist, bolsas_entrenamiento[i])

# %%
hist2 = np.array(bolsas_validacion[0])
for i in range(1,len(bolsas_validacion)):
  np.append(hist2, bolsas_validacion[i])

# %%
# No recuerdo para qué ploteabamos, pero se ve bonito
plt.show()
fig, axs = plt.subplots(1, 2, figsize=(13, 5), sharey=True)
axs[0].hist(hist,bins=700)
axs[0].set_title('Entrenamiento')
axs[1].hist(hist2,bins=700)
axs[1].set_title('Validación')
fig.suptitle('Histogramas de Características')
plt.show()

# %% [markdown]
# ---
#
# Ahora sí, hacemos uso de nuestro índice inverso con los datos de **Entrenamiento**
#
# ---

# %%
#Aquí es donde tarda 4, pero ya termina


#Perdón por tanto print, necesitaba ver el anvance para no desesperarme :c
ifs = IndiceInverso()
ifs.Add(bolsas_entrenamiento)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Analizando bolsa: 114
# Analizando bolsa: 115
# Analizando bolsa: 116
# Analizando bolsa: 117
# Analizando bolsa: 118
# Analizando bolsa: 119
# Analizando bolsa: 120
# Analizando bolsa: 121
# Analizando bolsa: 122
# Analizando bolsa: 123
# Analizando bolsa: 124
# Analizando bolsa: 125
# Analizando bolsa: 126
# Analizando bolsa: 127
# Analizando bolsa: 128
# Analizando bolsa: 129
# Analizando bolsa: 130
# Analizando bolsa: 131
# Analizando bolsa: 132
# Analizando bolsa: 133
# Analizando bolsa: 134
# Analizando bolsa: 135
# Analizando bolsa: 136
# Analizando bolsa: 137
# Analizando bolsa: 138
# Analizando bolsa: 139
# Analizando bolsa: 140
# Analizando bolsa: 141
# Analizando bolsa: 142
# Analizando bolsa: 143
# Analizando bolsa: 144
# Analizando bolsa: 145
# Analizando bolsa: 146
# Analizando bolsa: 147
# Analizando bolsa: 148
# Analizando bolsa: 149
# Analizando bolsa: 150
# Analizando bolsa: 151
# Analizando bolsa: 152
# Analizando bolsa: 153
# Analizando bolsa: 154
# Analizando bolsa: 155
# Analizando bolsa: 156
# Analizando bolsa: 157
# Analizando bolsa: 158
# Analizando bolsa: 159
# Analizando bolsa: 160
# Analizando bolsa: 161
# Analizando bolsa: 162
# Analizando bolsa: 163
# Analizando bolsa: 164
# Analizando bolsa: 165
# Analizando bolsa: 166
# Analizando bolsa: 167
# Analizando bolsa: 168
# Analizando bolsa: 169
# Analizando bolsa: 170
# Analizando bolsa: 171
# Analizando bolsa: 172
# Analizando bolsa: 173
# Analizando bolsa: 174
# Analizando bolsa: 175
# Analizando bolsa: 176
# Analizando bolsa: 177
# Analizando bolsa: 178
# Analizando bolsa: 179
# Analizando bolsa: 180
# Analizando bolsa: 181
# Analizando bolsa: 182
# Analizando bolsa: 183
# Analizando bolsa: 184
# Analizando bolsa: 185
# Analizando bolsa: 186
# Analizando bolsa: 187
# Analizando bolsa: 188
# Analizando bolsa: 189
# Analizando bolsa: 190
# Analizando bolsa: 191
# Analizando bolsa: 192
# Analizando bolsa: 193
# Analizando bolsa: 194
# Analizando bolsa: 195
# Analizando bolsa: 196
# Analizando bolsa: 197
# Analizando bolsa: 198
# Analizando bolsa: 199
# Analizando bolsa: 200
# Analizando bolsa: 201
# Analizando bolsa: 202
# Analizando bolsa: 203
# Analizando bolsa: 204
# Analizando bolsa: 205
# Analizando bolsa: 206
# Analizando bolsa: 207
# Analizando bolsa: 208
# Analizando bolsa: 209
# Analizando bolsa: 210
# Analizando bolsa: 211
# Analizando bolsa: 212
# Analizando bolsa: 213
# Analizando bolsa: 214
# Analizando bolsa: 215
# Analizando bolsa: 216
# Analizando bolsa: 217
# Analizando bolsa: 218
# Analizando bolsa: 219
# Analizando bolsa: 220
# Analizando bolsa: 221
# Analizando bolsa: 222
# Analizando bolsa: 223
# Analizando bolsa: 224
# Analizando bolsa: 225
# Analizando bolsa: 226
# Analizando bolsa: 227
# Analizando bolsa: 228
# Analizando bolsa: 229
# Analizando bolsa: 230
# Analizando bolsa: 231
# Analizando bolsa: 232
# Analizando bolsa: 233
# Analizando bolsa: 234
# Analizando bolsa: 235
# Analizando bolsa: 236
# Analizando bolsa: 237
# Analizando bolsa: 238
# Analizando bolsa: 239
# Analizando bolsa: 240
# Analizando bolsa: 241
# Analizando bolsa: 242
# Analizando bolsa: 243
# Analizando bolsa: 244
# Analizando bolsa: 245
# Analizando bolsa: 246
# Analizando bolsa: 247
# Analizando bolsa: 248
# Analizando bolsa: 249
# Analizando bolsa: 250
# Analizando bolsa: 251
# Analizando bolsa: 252
# Analizando bolsa: 253
# Analizando bolsa: 254
# Analizando bolsa: 255
# Analizando bolsa: 256
# Analizando bolsa: 257
# Analizando bolsa: 258
# Analizando bolsa: 259
# Analizando bolsa: 260
# Analizando bolsa: 261
# Analizando bolsa: 262
# Analizando bolsa: 263
# Analizando bolsa: 264
# Analizando bolsa: 265
# Analizando bolsa: 266
# Analizando bolsa: 267
# Analizando bolsa: 268
# Analizando bolsa: 269
# Analizando bolsa: 270
# Analizando bolsa: 271
# Analizando bolsa: 272
# Analizando bolsa: 273
# Analizando bolsa: 274
# Analizando bolsa: 275
# Analizando bolsa: 276
# Analizando bolsa: 277
# Analizando bolsa: 278
# Analizando bolsa: 279
# Analizando bolsa: 280
# Analizando bolsa: 281
# Analizando bolsa: 282
# Analizando bolsa: 283
# Analizando bolsa: 284
# Analizando bolsa: 285
# Analizando bolsa: 286
# Analizando bolsa: 287
# Analizando bolsa: 288
# Analizando bolsa: 289
# Analizando bolsa: 290
# Analizando bolsa: 291
# Analizando bolsa: 292
# Analizando bolsa: 293
# Analizando bolsa: 294
# Analizando bolsa: 295
# Analizando bolsa: 296
# Analizando bolsa: 297
# Analizando bolsa: 298
# Analizando bolsa: 299
# Analizando bolsa: 300
# Analizando bolsa: 301
# Analizando bolsa: 302
# Analizando bolsa: 303
# Analizando bolsa: 304
# Analizando bolsa: 305
# Analizando bolsa: 306
# Analizando bolsa: 307
# Analizando bolsa: 308
# Analizando bolsa: 309
# Analizando bolsa: 310
# Analizando bolsa: 311
# Analizando bolsa: 312
# Analizando bolsa: 313
# Analizando bolsa: 314
# Analizando bolsa: 315
# Analizando bolsa: 316
# Analizando bolsa: 317
# Analizando bolsa: 318
# Analizando bolsa: 319
# Analizando bolsa: 320
# Analizando bolsa: 321
# Analizando bolsa: 322
# Analizando bolsa: 323
# Analizando bolsa: 324
# Analizando bolsa: 325
# Analizando bolsa: 326
# Analizando bolsa: 327
# Analizando bolsa: 328
# Analizando bolsa: 329
# Analizando bolsa: 330
# Analizando bolsa: 331
# Analizando bolsa: 332
# Analizando bolsa: 333
# Analizando bolsa: 334
# Analizando bolsa: 335
# Analizando bolsa: 336
# Analizando bolsa: 337
# Analizando bolsa: 338
# Analizando bolsa: 339
# Analizando bolsa: 340
# Analizando bolsa: 341
# Analizando bolsa: 342
# Analizando bolsa: 343
# Analizando bolsa: 344
# Analizando bolsa: 345
# Analizando bolsa: 346
# Analizando bolsa: 347
# Analizando bolsa: 348
# Analizando bolsa: 349
# Analizando bolsa: 350
# Analizando bolsa: 351
# Analizando bolsa: 352
# Analizando bolsa: 353
# Analizando bolsa: 354
# Analizando bolsa: 355
# Analizando bolsa: 356
# Analizando bolsa: 357
# Analizando bolsa: 358
# Analizando bolsa: 359
# Analizando bolsa: 360
# Analizando bolsa: 361
# Analizando bolsa: 362
# Analizando bolsa: 363
# Analizando bolsa: 364
# Analizando bolsa: 365
# Analizando bolsa: 366
# Analizando bolsa: 367
# Analizando bolsa: 368
# Analizando bolsa: 369
# Analizando bolsa: 370
# Analizando bolsa: 371
# Analizando bolsa: 372
# Analizando bolsa: 373
# Analizando bolsa: 374
# Analizando bolsa: 375
# Analizando bolsa: 376
# Analizando bolsa: 377
# Analizando bolsa: 378
# Analizando bolsa: 379
# Analizando bolsa: 380
# Analizando bolsa: 381
# Analizando bolsa: 382
# Analizando bolsa: 383
# Analizando bolsa: 384
# Analizando bolsa: 385
# Analizando bolsa: 386
# Analizando bolsa: 387
# Analizando bolsa: 388
# Analizando bolsa: 389
# Analizando bolsa: 390
# Analizando bolsa: 391
# Analizando bolsa: 392
# Analizando bolsa: 393
# Analizando bolsa: 394
# Analizando bolsa: 395
# Analizando bolsa: 396
# Analizando bolsa: 397
# Analizando bolsa: 398
# Analizando bolsa: 399
# Analizando bolsa: 400
# Analizando bolsa: 401
# Analizando bolsa: 402
# Analizando bolsa: 403
# Analizando bolsa: 404
# Analizando bolsa: 405
# Analizando bolsa: 406
# Analizando bolsa: 407
# Analizando bolsa: 408
# Analizando bolsa: 409
# Analizando bolsa: 410
# Analizando bolsa: 411
# Analizando bolsa: 412
# Analizando bolsa: 413
# Analizando bolsa: 414
# Analizando bolsa: 415
# Analizando bolsa: 416
# Analizando bolsa: 417
# Analizando bolsa: 418
# Analizando bolsa: 419
# Analizando bolsa: 420
# Analizando bolsa: 421
# Analizando bolsa: 422
# Analizando bolsa: 423
# Analizando bolsa: 424
# Analizando bolsa: 425
# Analizando bolsa: 426
# Analizando bolsa: 427
# Analizando bolsa: 428
# Analizando bolsa: 429
# Analizando bolsa: 430
# Analizando bolsa: 431
# Analizando bolsa: 432
# Analizando bolsa: 433
# Analizando bolsa: 434
# Analizando bolsa: 435
# Analizando bolsa: 436
# Analizando bolsa: 437
# Analizando bolsa: 438
# Analizando bolsa: 439
# Analizando bolsa: 440
# Analizando bolsa: 441
# Analizando bolsa: 442
# Analizando bolsa: 443
# Analizando bolsa: 444
# Analizando bolsa: 445
# Analizando bolsa: 446
# Analizando bolsa: 447
# Analizando bolsa: 448
# Analizando bolsa: 449
# Analizando bolsa: 450
# Analizando bolsa: 451
# Analizando bolsa: 452
# Analizando bolsa: 453
# Analizando bolsa: 454
# Analizando bolsa: 455
# Analizando bolsa: 456
# Analizando bolsa: 457
# Analizando bolsa: 458
# Analizando bolsa: 459
# Analizando bolsa: 460
# Analizando bolsa: 461
# Analizando bolsa: 462
# Analizando bolsa: 463
# Analizando bolsa: 464
# Analizando bolsa: 465
# Analizando bolsa: 466
# Analizando bolsa: 467
# Analizando bolsa: 468
# Analizando bolsa: 469
# Analizando bolsa: 470
# Analizando bolsa: 471
# Analizando bolsa: 472
# Analizando bolsa: 473
# Analizando bolsa: 474
# Analizando bolsa: 475
# Analizando bolsa: 476
# Analizando bolsa: 477
# Analizando bolsa: 478
# Analizando bolsa: 479
# Analizando bolsa: 480
# Analizando bolsa: 481
# Analizando bolsa: 482
# Analizando bolsa: 483
# Analizando bolsa: 484
# Analizando bolsa: 485
# Analizando bolsa: 486
# Analizando bolsa: 487
# Analizando bolsa: 488
# Analizando bolsa: 489
# Analizando bolsa: 490
# Analizando bolsa: 491
# Analizando bolsa: 492
# Analizando bolsa: 493
# Analizando bolsa: 494
# Analizando bolsa: 495
# Analizando bolsa: 496
# Analizando bolsa: 497
# Analizando bolsa: 498
# Analizando bolsa: 499
# Analizando bolsa: 500
# Analizando bolsa: 501
# Analizando bolsa: 502
# Analizando bolsa: 503
# Analizando bolsa: 504
# Analizando bolsa: 505
# Analizando bolsa: 506
# Analizando bolsa: 507
# Analizando bolsa: 508
# Analizando bolsa: 509
# Analizando bolsa: 510
# Analizando bolsa: 511
# Analizando bolsa: 512
# Analizando bolsa: 513
# Analizando bolsa: 514
# Analizando bolsa: 515
# Analizando bolsa: 516
# Analizando bolsa: 517
# Analizando bolsa: 518
# Analizando bolsa: 519
# Analizando bolsa: 520
# Analizando bolsa: 521
# Analizando bolsa: 522
# Analizando bolsa: 523
# Analizando bolsa: 524
# Analizando bolsa: 525
# Analizando bolsa: 526
# Analizando bolsa: 527
# Analizando bolsa: 528
# Analizando bolsa: 529
# Analizando bolsa: 530
# Analizando bolsa: 531
# Analizando bolsa: 532
# Analizando bolsa: 533
# Analizando bolsa: 534
# Analizando bolsa: 535
# Analizando bolsa: 536
# Analizando bolsa: 537
# Analizando bolsa: 538
# Analizando bolsa: 539
# Analizando bolsa: 540
# Analizando bolsa: 541
# Analizando bolsa: 542
# Analizando bolsa: 543
# Analizando bolsa: 544
# Analizando bolsa: 545
# Analizando bolsa: 546
# Analizando bolsa: 547
# Analizando bolsa: 548
# Analizando bolsa: 549
# Analizando bolsa: 550
# Analizando bolsa: 551
# Analizando bolsa: 552
# Analizando bolsa: 553
# Analizando bolsa: 554
# Analizando bolsa: 555
# Analizando bolsa: 556
# Analizando bolsa: 557
# Analizando bolsa: 558
# Analizando bolsa: 559
# Analizando bolsa: 560
# Analizando bolsa: 561
# Analizando bolsa: 562
# Analizando bolsa: 563
# Analizando bolsa: 564
# Analizando bolsa: 565
# Analizando bolsa: 566
# Analizando bolsa: 567
# Analizando bolsa: 568
# Analizando bolsa: 569
# Analizando bolsa: 570
# Analizando bolsa: 571
# Analizando bolsa: 572
# Analizando bolsa: 573
# Analizando bolsa: 574
# Analizando bolsa: 575
# Analizando bolsa: 576
# Analizando bolsa: 577
# Analizando bolsa: 578
# Analizando bolsa: 579
# Analizando bolsa: 580
# Analizando bolsa: 581
# Analizando bolsa: 582
# Analizando bolsa: 583
# Analizando bolsa: 584
# Analizando bolsa: 585
# Analizando bolsa: 586
# Analizando bolsa: 587
# Analizando bolsa: 588
# Analizando bolsa: 589
# Analizando bolsa: 590
# Analizando bolsa: 591
# Analizando bolsa: 592
# Analizando bolsa: 593
# Analizando bolsa: 594
# Analizando bolsa: 595
# Analizando bolsa: 596
# Analizando bolsa: 597
# Analizando bolsa: 598
# Analizando bolsa: 599
# Analizando bolsa: 600
# Analizando bolsa: 601
# Analizando bolsa: 602
# Analizando bolsa: 603
# Analizando bolsa: 604
# Analizando bolsa: 605
# Analizando bolsa: 606
# Analizando bolsa: 607
# Analizando bolsa: 608
# Analizando bolsa: 609
# Analizando bolsa: 610
# Analizando bolsa: 611
# Analizando bolsa: 612
# Analizando bolsa: 613
# Analizando bolsa: 614
# Analizando bolsa: 615
# Analizando bolsa: 616
# Analizando bolsa: 617
# Analizando bolsa: 618
# Analizando bolsa: 619
# Analizando bolsa: 620
# Analizando bolsa: 621
# Analizando bolsa: 622
# Analizando bolsa: 623
# Analizando bolsa: 624
# Analizando bolsa: 625
# Analizando bolsa: 626
# Analizando bolsa: 627
# Analizando bolsa: 628
# Analizando bolsa: 629
# Analizando bolsa: 630
# Analizando bolsa: 631
# Analizando bolsa: 632
# Analizando bolsa: 633
# Analizando bolsa: 634
# Analizando bolsa: 635
# Analizando bolsa: 636
# Analizando bolsa: 637
# Analizando bolsa: 638
# Analizando bolsa: 639
# Analizando bolsa: 640
# Analizando bolsa: 641
# Analizando bolsa: 642
# Analizando bolsa: 643
# Analizando bolsa: 644
# Analizando bolsa: 645
# Analizando bolsa: 646
# Analizando bolsa: 647
# Analizando bolsa: 648
# Analizando bolsa: 649
# Analizando bolsa: 650
# Analizando bolsa: 651
# Analizando bolsa: 652
# Analizando bolsa: 653
# Analizando bolsa: 654
# Analizando bolsa: 655
# Analizando bolsa: 656
# Analizando bolsa: 657
# Analizando bolsa: 658
# Analizando bolsa: 659
# Analizando bolsa: 660
# Analizando bolsa: 661
# Analizando bolsa: 662
# Analizando bolsa: 663
# Analizando bolsa: 664
# Analizando bolsa: 665
# Analizando bolsa: 666
# Analizando bolsa: 667
# Analizando bolsa: 668
# Analizando bolsa: 669
# Analizando bolsa: 670
# Analizando bolsa: 671
# Analizando bolsa: 672
# Analizando bolsa: 673
# Analizando bolsa: 674
# Analizando bolsa: 675
# Analizando bolsa: 676
# Analizando bolsa: 677
# Analizando bolsa: 678
# Analizando bolsa: 679
# Analizando bolsa: 680
# Analizando bolsa: 681
# Analizando bolsa: 682
# Analizando bolsa: 683
# Analizando bolsa: 684
# Analizando bolsa: 685
# Analizando bolsa: 686
# Analizando bolsa: 687
# Analizando bolsa: 688
# Analizando bolsa: 689
# Analizando bolsa: 690
# Analizando bolsa: 691
# Analizando bolsa: 692
# Analizando bolsa: 693
# Analizando bolsa: 694
# Analizando bolsa: 695
# Analizando bolsa: 696
# Analizando bolsa: 697
# Analizando bolsa: 698
# Analizando bolsa: 699
# Analizando bolsa: 700
# Analizando bolsa: 701
# Analizando bolsa: 702
# Analizando bolsa: 703
# Analizando bolsa: 704
# Analizando bolsa: 705
# Analizando bolsa: 706
# Analizando bolsa: 707
# Analizando bolsa: 708
# Analizando bolsa: 709
# Analizando bolsa: 710
# Analizando bolsa: 711
# Analizando bolsa: 712
# Analizando bolsa: 713
# Analizando bolsa: 714
# Analizando bolsa: 715
# Analizando bolsa: 716
# Analizando bolsa: 717
# Analizando bolsa: 718
# Analizando bolsa: 719
# Analizando bolsa: 720
# Analizando bolsa: 721
# Analizando bolsa: 722
# Analizando bolsa: 723
# Analizando bolsa: 724
# Analizando bolsa: 725
# Analizando bolsa: 726
# Analizando bolsa: 727
# Analizando bolsa: 728
# Analizando bolsa: 729
# Analizando bolsa: 730
# Analizando bolsa: 731
# Analizando bolsa: 732
# Analizando bolsa: 733
# Analizando bolsa: 734
# Analizando bolsa: 735
# Analizando bolsa: 736
# Analizando bolsa: 737
# Analizando bolsa: 738
# Analizando bolsa: 739
# Analizando bolsa: 740
# Analizando bolsa: 741
# Analizando bolsa: 742
# Analizando bolsa: 743
# Analizando bolsa: 744
# Analizando bolsa: 745
# Analizando bolsa: 746
# Analizando bolsa: 747
# Analizando bolsa: 748
# Analizando bolsa: 749
# Analizando bolsa: 750
# Analizando bolsa: 751
# Analizando bolsa: 752
# Analizando bolsa: 753
# Analizando bolsa: 754
# Analizando bolsa: 755
# Analizando bolsa: 756
# Analizando bolsa: 757
# Analizando bolsa: 758
# Analizando bolsa: 759
# Analizando bolsa: 760
# Analizando bolsa: 761
# Analizando bolsa: 762
# Analizando bolsa: 763
# Analizando bolsa: 764
# Analizando bolsa: 765
# Analizando bolsa: 766
# Analizando bolsa: 767
# Analizando bolsa: 768
# Analizando bolsa: 769
# Analizando bolsa: 770
# Analizando bolsa: 771
# Analizando bolsa: 772
# Analizando bolsa: 773
# Analizando bolsa: 774
# Analizando bolsa: 775
# Analizando bolsa: 776
# Analizando bolsa: 777
# Analizando bolsa: 778
# Analizando bolsa: 779
# Analizando bolsa: 780
# Analizando bolsa: 781
# Analizando bolsa: 782
# Analizando bolsa: 783
# Analizando bolsa: 784
# Analizando bolsa: 785
# Analizando bolsa: 786
# Analizando bolsa: 787
# Analizando bolsa: 788
# Analizando bolsa: 789
# Analizando bolsa: 790
# Analizando bolsa: 791
# Analizando bolsa: 792
# Analizando bolsa: 793
# Analizando bolsa: 794
# Analizando bolsa: 795
# Analizando bolsa: 796
# Analizando bolsa: 797
# Analizando bolsa: 798
# Analizando bolsa: 799
# Analizando bolsa: 800
# Analizando bolsa: 801
# Analizando bolsa: 802
# Analizando bolsa: 803
# Analizando bolsa: 804
# Analizando bolsa: 805
# Analizando bolsa: 806
# Analizando bolsa: 807
# Analizando bolsa: 808
# Analizando bolsa: 809
# Analizando bolsa: 810
# Analizando bolsa: 811
# Analizando bolsa: 812
# Analizando bolsa: 813
# Analizando bolsa: 814
# Analizando bolsa: 815
# Analizando bolsa: 816
# Analizando bolsa: 817
# Analizando bolsa: 818
# Analizando bolsa: 819
# Analizando bolsa: 820
# Analizando bolsa: 821
# Analizando bolsa: 822
# Analizando bolsa: 823
# Analizando bolsa: 824
# Analizando bolsa: 825
# Analizando bolsa: 826
# Analizando bolsa: 827
# Analizando bolsa: 828
# Analizando bolsa: 829
# Analizando bolsa: 830
# Analizando bolsa: 831
# Analizando bolsa: 832
# Analizando bolsa: 833
# Analizando bolsa: 834
# Analizando bolsa: 835
# Analizando bolsa: 836
# Analizando bolsa: 837
# Analizando bolsa: 838
# Analizando bolsa: 839
# Analizando bolsa: 840
# Analizando bolsa: 841
# Analizando bolsa: 842
# Analizando bolsa: 843
# Analizando bolsa: 844
# Analizando bolsa: 845
# Analizando bolsa: 846
# Analizando bolsa: 847
# Analizando bolsa: 848
# Analizando bolsa: 849
# Analizando bolsa: 850
# Analizando bolsa: 851
# Analizando bolsa: 852
# Analizando bolsa: 853
# Analizando bolsa: 854
# Analizando bolsa: 855
# Analizando bolsa: 856
# Analizando bolsa: 857
# Analizando bolsa: 858
# Analizando bolsa: 859
# Analizando bolsa: 860
# Analizando bolsa: 861
# Analizando bolsa: 862
# Analizando bolsa: 863
# Analizando bolsa: 864
# Analizando bolsa: 865
# Analizando bolsa: 866
# Analizando bolsa: 867
# Analizando bolsa: 868
# Analizando bolsa: 869
# Analizando bolsa: 870
# Analizando bolsa: 871
# Analizando bolsa: 872
# Analizando bolsa: 873
# Analizando bolsa: 874
# Analizando bolsa: 875
# Analizando bolsa: 876
# Analizando bolsa: 877
# Analizando bolsa: 878
# Analizando bolsa: 879
# Analizando bolsa: 880
# Analizando bolsa: 881
# Analizando bolsa: 882
# Analizando bolsa: 883
# Analizando bolsa: 884
# Analizando bolsa: 885
# Analizando bolsa: 886
# Analizando bolsa: 887
# Analizando bolsa: 888
# Analizando bolsa: 889
# Analizando bolsa: 890
# Analizando bolsa: 891
# Analizando bolsa: 892
# Analizando bolsa: 893
# Analizando bolsa: 894
# Analizando bolsa: 895
# Analizando bolsa: 896
# Analizando bolsa: 897
# Analizando bolsa: 898
# Analizando bolsa: 899
# Analizando bolsa: 900
# Analizando bolsa: 901
# Analizando bolsa: 902
# Analizando bolsa: 903
# Analizando bolsa: 904
# Analizando bolsa: 905
# Analizando bolsa: 906
# Analizando bolsa: 907
# Analizando bolsa: 908
# Analizando bolsa: 909
# Analizando bolsa: 910
# Analizando bolsa: 911
# Analizando bolsa: 912
# Analizando bolsa: 913
# Analizando bolsa: 914
# Analizando bolsa: 915
# Analizando bolsa: 916
# Analizando bolsa: 917
# Analizando bolsa: 918
# Analizando bolsa: 919
# Analizando bolsa: 920
# Analizando bolsa: 921
# Analizando bolsa: 922
# Analizando bolsa: 923
# Analizando bolsa: 924
# Analizando bolsa: 925
# Analizando bolsa: 926
# Analizando bolsa: 927
# Analizando bolsa: 928
# Analizando bolsa: 929
# Analizando bolsa: 930
# Analizando bolsa: 931
# Analizando bolsa: 932
# Analizando bolsa: 933
# Analizando bolsa: 934
# Analizando bolsa: 935
# Analizando bolsa: 936
# Analizando bolsa: 937
# Analizando bolsa: 938
# Analizando bolsa: 939
# Analizando bolsa: 940
# Analizando bolsa: 941
# Analizando bolsa: 942
# Analizando bolsa: 943
# Analizando bolsa: 944
# Analizando bolsa: 945
# Analizando bolsa: 946
# Analizando bolsa: 947
# Analizando bolsa: 948
# Analizando bolsa: 949
# Analizando bolsa: 950
# Analizando bolsa: 951
# Analizando bolsa: 952
# Analizando bolsa: 953
# Analizando bolsa: 954
# Analizando bolsa: 955
# Analizando bolsa: 956
# Analizando bolsa: 957
# Analizando bolsa: 958
# Analizando bolsa: 959
# Analizando bolsa: 960
# Analizando bolsa: 961
# Analizando bolsa: 962
# Analizando bolsa: 963
# Analizando bolsa: 964
# Analizando bolsa: 965
# Analizando bolsa: 966
# Analizando bolsa: 967
# Analizando bolsa: 968
# Analizando bolsa: 969
# Analizando bolsa: 970
# Analizando bolsa: 971
# Analizando bolsa: 972
# Analizando bolsa: 973
# Analizando bolsa: 974
# Analizando bolsa: 975
# Analizando bolsa: 976
# Analizando bolsa: 977
# Analizando bolsa: 978
# Analizando bolsa: 979
# Analizando bolsa: 980
# Analizando bolsa: 981
# Analizando bolsa: 982
# Analizando bolsa: 983
# Analizando bolsa: 984
# Analizando bolsa: 985
# Analizando bolsa: 986
# Analizando bolsa: 987
# Analizando bolsa: 988
# Analizando bolsa: 989
# Analizando bolsa: 990
# Analizando bolsa: 991
# Analizando bolsa: 992
# Analizando bolsa: 993
# Analizando bolsa: 994
# Analizando bolsa: 995
# Analizando bolsa: 996
# Analizando bolsa: 997
# Analizando bolsa: 998
# Analizando bolsa: 999
# Analizando bolsa: 1000
# Analizando bolsa: 1001
# Analizando bolsa: 1002
# Analizando bolsa: 1003
# Analizando bolsa: 1004
# Analizando bolsa: 1005
# Analizando bolsa: 1006
# Analizando bolsa: 1007
# Analizando bolsa: 1008
# Analizando bolsa: 1009
# Analizando bolsa: 1010
# Analizando bolsa: 1011
# Analizando bolsa: 1012
# Analizando bolsa: 1013
# Analizando bolsa: 1014
# Analizando bolsa: 1015
# Analizando bolsa: 1016
# Analizando bolsa: 1017
# Analizando bolsa: 1018
# Analizando bolsa: 1019
# Analizando bolsa: 1020
# Analizando bolsa: 1021
# Analizando bolsa: 1022
# Analizando bolsa: 1023
# Analizando bolsa: 1024
# Analizando bolsa: 1025
# Analizando bolsa: 1026
# Analizando bolsa: 1027
# Analizando bolsa: 1028
# Analizando bolsa: 1029
# Analizando bolsa: 1030
# Analizando bolsa: 1031
# Analizando bolsa: 1032
# Analizando bolsa: 1033
# Analizando bolsa: 1034
# Analizando bolsa: 1035
# Analizando bolsa: 1036
# Analizando bolsa: 1037
# Analizando bolsa: 1038
# Analizando bolsa: 1039
# Analizando bolsa: 1040
# Analizando bolsa: 1041
# Analizando bolsa: 1042
# Analizando bolsa: 1043
# Analizando bolsa: 1044
# Analizando bolsa: 1045
# Analizando bolsa: 1046
# Analizando bolsa: 1047
# Analizando bolsa: 1048
# Analizando bolsa: 1049
# Analizando bolsa: 1050
# Analizando bolsa: 1051
# Analizando bolsa: 1052
# Analizando bolsa: 1053
# Analizando bolsa: 1054
# Analizando bolsa: 1055
# Analizando bolsa: 1056
# Analizando bolsa: 1057
# Analizando bolsa: 1058
# Analizando bolsa: 1059
# Analizando bolsa: 1060
# Analizando bolsa: 1061
# Analizando bolsa: 1062
# Analizando bolsa: 1063
# Analizando bolsa: 1064
# Analizando bolsa: 1065
# Analizando bolsa: 1066
# Analizando bolsa: 1067
# Analizando bolsa: 1068
# Analizando bolsa: 1069
# Analizando bolsa: 1070
# Analizando bolsa: 1071
# Analizando bolsa: 1072
# Analizando bolsa: 1073
# Analizando bolsa: 1074
# Analizando bolsa: 1075
# Analizando bolsa: 1076
# Analizando bolsa: 1077
# Analizando bolsa: 1078
# Analizando bolsa: 1079
# Analizando bolsa: 1080
# Analizando bolsa: 1081
# Analizando bolsa: 1082
# Analizando bolsa: 1083
# Analizando bolsa: 1084
# Analizando bolsa: 1085
# Analizando bolsa: 1086
# Analizando bolsa: 1087
# Analizando bolsa: 1088
# Analizando bolsa: 1089
# Analizando bolsa: 1090
# Analizando bolsa: 1091
# Analizando bolsa: 1092
# Analizando bolsa: 1093
# Analizando bolsa: 1094
# Analizando bolsa: 1095
# Analizando bolsa: 1096
# Analizando bolsa: 1097
# Analizando bolsa: 1098
# Analizando bolsa: 1099
# Analizando bolsa: 1100
# Analizando bolsa: 1101
# Analizando bolsa: 1102
# Analizando bolsa: 1103
# Analizando bolsa: 1104
# Analizando bolsa: 1105
# Analizando bolsa: 1106
# Analizando bolsa: 1107
# Analizando bolsa: 1108
# Analizando bolsa: 1109
# Analizando bolsa: 1110
# Analizando bolsa: 1111
# Analizando bolsa: 1112
# Analizando bolsa: 1113
# Analizando bolsa: 1114
# Analizando bolsa: 1115
# Analizando bolsa: 1116
# Analizando bolsa: 1117
# Analizando bolsa: 1118
# Analizando bolsa: 1119
# Analizando bolsa: 1120
# Analizando bolsa: 1121
# Analizando bolsa: 1122
# Analizando bolsa: 1123
# Analizando bolsa: 1124
# Analizando bolsa: 1125
# Analizando bolsa: 1126
# Analizando bolsa: 1127
# Analizando bolsa: 1128
# Analizando bolsa: 1129
# Analizando bolsa: 1130
# Analizando bolsa: 1131
# Analizando bolsa: 1132
# Analizando bolsa: 1133
# Analizando bolsa: 1134
# Analizando bolsa: 1135
# Analizando bolsa: 1136
# Analizando bolsa: 1137
# Analizando bolsa: 1138
# Analizando bolsa: 1139
# Analizando bolsa: 1140
# Analizando bolsa: 1141
# Analizando bolsa: 1142
# Analizando bolsa: 1143
# Analizando bolsa: 1144
# Analizando bolsa: 1145
# Analizando bolsa: 1146
# Analizando bolsa: 1147
# Analizando bolsa: 1148
# Analizando bolsa: 1149
# Analizando bolsa: 1150
# Analizando bolsa: 1151
# Analizando bolsa: 1152
# Analizando bolsa: 1153
# Analizando bolsa: 1154
# Analizando bolsa: 1155
# Analizando bolsa: 1156
# Analizando bolsa: 1157
# Analizando bolsa: 1158
# Analizando bolsa: 1159
# Analizando bolsa: 1160
# Analizando bolsa: 1161
# Analizando bolsa: 1162
# Analizando bolsa: 1163
# Analizando bolsa: 1164
# Analizando bolsa: 1165
# Analizando bolsa: 1166
# Analizando bolsa: 1167
# Analizando bolsa: 1168
# Analizando bolsa: 1169
# Analizando bolsa: 1170
# Analizando bolsa: 1171
# Analizando bolsa: 1172
# Analizando bolsa: 1173
# Analizando bolsa: 1174
# Analizando bolsa: 1175
# Analizando bolsa: 1176
# Analizando bolsa: 1177
# Analizando bolsa: 1178
# Analizando bolsa: 1179
# Analizando bolsa: 1180
# Analizando bolsa: 1181
# Analizando bolsa: 1182
# Analizando bolsa: 1183
# Analizando bolsa: 1184
# Analizando bolsa: 1185
# Analizando bolsa: 1186
# Analizando bolsa: 1187
# Analizando bolsa: 1188
# Analizando bolsa: 1189
# Analizando bolsa: 1190
# Analizando bolsa: 1191
# Analizando bolsa: 1192
# Analizando bolsa: 1193
# Analizando bolsa: 1194
# Analizando bolsa: 1195
# Analizando bolsa: 1196
# Analizando bolsa: 1197
# Analizando bolsa: 1198
# Analizando bolsa: 1199
# Analizando bolsa: 1200
# Analizando bolsa: 1201
# Analizando bolsa: 1202
# Analizando bolsa: 1203
# Analizando bolsa: 1204
# Analizando bolsa: 1205
# Analizando bolsa: 1206
# Analizando bolsa: 1207
# Analizando bolsa: 1208
# Analizando bolsa: 1209
# Analizando bolsa: 1210
# Analizando bolsa: 1211
# Analizando bolsa: 1212
# Analizando bolsa: 1213
# Analizando bolsa: 1214
# Analizando bolsa: 1215
# Analizando bolsa: 1216
# Analizando bolsa: 1217
# Analizando bolsa: 1218
# Analizando bolsa: 1219
# Analizando bolsa: 1220
# Analizando bolsa: 1221
# Analizando bolsa: 1222
# Analizando bolsa: 1223
# Analizando bolsa: 1224
# Analizando bolsa: 1225
# Analizando bolsa: 1226
# Analizando bolsa: 1227
# Analizando bolsa: 1228
# Analizando bolsa: 1229
# Analizando bolsa: 1230
# Analizando bolsa: 1231
# Analizando bolsa: 1232
# Analizando bolsa: 1233
# Analizando bolsa: 1234
# Analizando bolsa: 1235
# Analizando bolsa: 1236
# Analizando bolsa: 1237
# Analizando bolsa: 1238
# Analizando bolsa: 1239
# Analizando bolsa: 1240
# Analizando bolsa: 1241
# Analizando bolsa: 1242
# Analizando bolsa: 1243
# Analizando bolsa: 1244
# Analizando bolsa: 1245
# Analizando bolsa: 1246
# Analizando bolsa: 1247
# Analizando bolsa: 1248
# Analizando bolsa: 1249
# Analizando bolsa: 1250
# Analizando bolsa: 1251
# Analizando bolsa: 1252
# Analizando bolsa: 1253
# Analizando bolsa: 1254
# Analizando bolsa: 1255
# Analizando bolsa: 1256
# Analizando bolsa: 1257
# Analizando bolsa: 1258
# Analizando bolsa: 1259
# Analizando bolsa: 1260
# Analizando bolsa: 1261
# Analizando bolsa: 1262
# Analizando bolsa: 1263
# Analizando bolsa: 1264
# Analizando bolsa: 1265
# Analizando bolsa: 1266
# Analizando bolsa: 1267
# Analizando bolsa: 1268
# Analizando bolsa: 1269
# Analizando bolsa: 1270
# Analizando bolsa: 1271
# Analizando bolsa: 1272
# Analizando bolsa: 1273
# Analizando bolsa: 1274
# Analizando bolsa: 1275
# Analizando bolsa: 1276
# Analizando bolsa: 1277
# Analizando bolsa: 1278
# Analizando bolsa: 1279
# Analizando bolsa: 1280
# Analizando bolsa: 1281
# Analizando bolsa: 1282
# Analizando bolsa: 1283
# Analizando bolsa: 1284
# Analizando bolsa: 1285
# Analizando bolsa: 1286
# Analizando bolsa: 1287
# Analizando bolsa: 1288
# Analizando bolsa: 1289
# Analizando bolsa: 1290
# Analizando bolsa: 1291
# Analizando bolsa: 1292
# Analizando bolsa: 1293
# Analizando bolsa: 1294
# Analizando bolsa: 1295
# Analizando bolsa: 1296
# Analizando bolsa: 1297
# Analizando bolsa: 1298
# Analizando bolsa: 1299
# Analizando bolsa: 1300
# Analizando bolsa: 1301
# Analizando bolsa: 1302
# Analizando bolsa: 1303
# Analizando bolsa: 1304
# Analizando bolsa: 1305
# Analizando bolsa: 1306
# Analizando bolsa: 1307
# Analizando bolsa: 1308
# Analizando bolsa: 1309
# Analizando bolsa: 1310
# Analizando bolsa: 1311
# Analizando bolsa: 1312
# Analizando bolsa: 1313
# Analizando bolsa: 1314
# Analizando bolsa: 1315
# Analizando bolsa: 1316
# Analizando bolsa: 1317
# Analizando bolsa: 1318
# Analizando bolsa: 1319
# Analizando bolsa: 1320
# Analizando bolsa: 1321
# Analizando bolsa: 1322
# Analizando bolsa: 1323
# Analizando bolsa: 1324
# Analizando bolsa: 1325
# Analizando bolsa: 1326
# Analizando bolsa: 1327
# Analizando bolsa: 1328
# Analizando bolsa: 1329
# Analizando bolsa: 1330
# Analizando bolsa: 1331
# Analizando bolsa: 1332
# Analizando bolsa: 1333
# Analizando bolsa: 1334
# Analizando bolsa: 1335
# Analizando bolsa: 1336
# Analizando bolsa: 1337
# Analizando bolsa: 1338
# Analizando bolsa: 1339
# Analizando bolsa: 1340
# Analizando bolsa: 1341
# Analizando bolsa: 1342
# Analizando bolsa: 1343
# Analizando bolsa: 1344
# Analizando bolsa: 1345
# Analizando bolsa: 1346
# Analizando bolsa: 1347
# Analizando bolsa: 1348
# Analizando bolsa: 1349
# Analizando bolsa: 1350
# Analizando bolsa: 1351
# Analizando bolsa: 1352
# Analizando bolsa: 1353
# Analizando bolsa: 1354
# Analizando bolsa: 1355
# Analizando bolsa: 1356
# Analizando bolsa: 1357
# Analizando bolsa: 1358
# Analizando bolsa: 1359
# Analizando bolsa: 1360
# Analizando bolsa: 1361
# Analizando bolsa: 1362
# Analizando bolsa: 1363
# Analizando bolsa: 1364
# Analizando bolsa: 1365
# Analizando bolsa: 1366
# Analizando bolsa: 1367
# Analizando bolsa: 1368
# Analizando bolsa: 1369
# Analizando bolsa: 1370
# Analizando bolsa: 1371
# Analizando bolsa: 1372
# Analizando bolsa: 1373
# Analizando bolsa: 1374
# Analizando bolsa: 1375
# Analizando bolsa: 1376
# Analizando bolsa: 1377
# Analizando bolsa: 1378
# Analizando bolsa: 1379
# Analizando bolsa: 1380
# Analizando bolsa: 1381
# Analizando bolsa: 1382
# Analizando bolsa: 1383
# Analizando bolsa: 1384
# Analizando bolsa: 1385
# Analizando bolsa: 1386
# Analizando bolsa: 1387
# Analizando bolsa: 1388
# Analizando bolsa: 1389
# Analizando bolsa: 1390
# Analizando bolsa: 1391
# Analizando bolsa: 1392
# Analizando bolsa: 1393
# Analizando bolsa: 1394
# Analizando bolsa: 1395
# Analizando bolsa: 1396
# Analizando bolsa: 1397
# Analizando bolsa: 1398
# Analizando bolsa: 1399
# Analizando bolsa: 1400
# Analizando bolsa: 1401
# Analizando bolsa: 1402
# Analizando bolsa: 1403
# Analizando bolsa: 1404
# Analizando bolsa: 1405
# Analizando bolsa: 1406
# Analizando bolsa: 1407
# Analizando bolsa: 1408
# Analizando bolsa: 1409
# Analizando bolsa: 1410
# Analizando bolsa: 1411
# Analizando bolsa: 1412
# Analizando bolsa: 1413
# Analizando bolsa: 1414
# Analizando bolsa: 1415
# Analizando bolsa: 1416
# Analizando bolsa: 1417
# Analizando bolsa: 1418
# Analizando bolsa: 1419
# Analizando bolsa: 1420
# Analizando bolsa: 1421
# Analizando bolsa: 1422
# Analizando bolsa: 1423
# Analizando bolsa: 1424
# Analizando bolsa: 1425
# Analizando bolsa: 1426
# Analizando bolsa: 1427
# Analizando bolsa: 1428
# Analizando bolsa: 1429
# Analizando bolsa: 1430
# Analizando bolsa: 1431
# Analizando bolsa: 1432
# Analizando bolsa: 1433
# Analizando bolsa: 1434
# Analizando bolsa: 1435
# Analizando bolsa: 1436
# Analizando bolsa: 1437
# Analizando bolsa: 1438
# Analizando bolsa: 1439
# Analizando bolsa: 1440
# Analizando bolsa: 1441
# Analizando bolsa: 1442
# Analizando bolsa: 1443
# Analizando bolsa: 1444
# Analizando bolsa: 1445
# Analizando bolsa: 1446
# Analizando bolsa: 1447
# Analizando bolsa: 1448
# Analizando bolsa: 1449
# Analizando bolsa: 1450
# Analizando bolsa: 1451
# Analizando bolsa: 1452
# Analizando bolsa: 1453
# Analizando bolsa: 1454
# Analizando bolsa: 1455
# Analizando bolsa: 1456
# Analizando bolsa: 1457
# Analizando bolsa: 1458
# Analizando bolsa: 1459
# Analizando bolsa: 1460
# Analizando bolsa: 1461
# Analizando bolsa: 1462
# Analizando bolsa: 1463
# Analizando bolsa: 1464
# Analizando bolsa: 1465
# Analizando bolsa: 1466
# Analizando bolsa: 1467
# Analizando bolsa: 1468
# Analizando bolsa: 1469
# Analizando bolsa: 1470
# Analizando bolsa: 1471
# Analizando bolsa: 1472
# Analizando bolsa: 1473
# Analizando bolsa: 1474
# Analizando bolsa: 1475
# Analizando bolsa: 1476
# Analizando bolsa: 1477
# Analizando bolsa: 1478
# Analizando bolsa: 1479
# Analizando bolsa: 1480
# Analizando bolsa: 1481
# Analizando bolsa: 1482
# Analizando bolsa: 1483
# Analizando bolsa: 1484
# Analizando bolsa: 1485
# Analizando bolsa: 1486
# Analizando bolsa: 1487
# Analizando bolsa: 1488
# Analizando bolsa: 1489
# Analizando bolsa: 1490
# Analizando bolsa: 1491
# Analizando bolsa: 1492
# Analizando bolsa: 1493
# Analizando bolsa: 1494
# Analizando bolsa: 1495
# Analizando bolsa: 1496
# Analizando bolsa: 1497
# Analizando bolsa: 1498
# Analizando bolsa: 1499
# Analizando bolsa: 1500
# Analizando bolsa: 1501
# Analizando bolsa: 1502
# Analizando bolsa: 1503
# Analizando bolsa: 1504
# Analizando bolsa: 1505
# Analizando bolsa: 1506
# Analizando bolsa: 1507
# Analizando bolsa: 1508
# Analizando bolsa: 1509
# Analizando bolsa: 1510
# Analizando bolsa: 1511
# Analizando bolsa: 1512
# Analizando bolsa: 1513
# Analizando bolsa: 1514
# Analizando bolsa: 1515
# Analizando bolsa: 1516
# Analizando bolsa: 1517
# Analizando bolsa: 1518
# Analizando bolsa: 1519
# Analizando bolsa: 1520
# Analizando bolsa: 1521
# Analizando bolsa: 1522
# Analizando bolsa: 1523
# Analizando bolsa: 1524
# Analizando bolsa: 1525
# Analizando bolsa: 1526
# Analizando bolsa: 1527
# Analizando bolsa: 1528
# Analizando bolsa: 1529
# Analizando bolsa: 1530
# Analizando bolsa: 1531
# Analizando bolsa: 1532
# Analizando bolsa: 1533
# Analizando bolsa: 1534
# Analizando bolsa: 1535
# Analizando bolsa: 1536
# Analizando bolsa: 1537
# Analizando bolsa: 1538
# Analizando bolsa: 1539
# Analizando bolsa: 1540
# Analizando bolsa: 1541
# Analizando bolsa: 1542
# Analizando bolsa: 1543
# Analizando bolsa: 1544
# Analizando bolsa: 1545
# Analizando bolsa: 1546
# Analizando bolsa: 1547
# Analizando bolsa: 1548
# Analizando bolsa: 1549
# Analizando bolsa: 1550
# Analizando bolsa: 1551
# Analizando bolsa: 1552
# Analizando bolsa: 1553
# Analizando bolsa: 1554
# Analizando bolsa: 1555
# Analizando bolsa: 1556
# Analizando bolsa: 1557
# Analizando bolsa: 1558
# Analizando bolsa: 1559
# Analizando bolsa: 1560
# Analizando bolsa: 1561
# Analizando bolsa: 1562
# Analizando bolsa: 1563
# Analizando bolsa: 1564
# Analizando bolsa: 1565
# Analizando bolsa: 1566
# Analizando bolsa: 1567
# Analizando bolsa: 1568
# Analizando bolsa: 1569
# Analizando bolsa: 1570
# Analizando bolsa: 1571
# Analizando bolsa: 1572
# Analizando bolsa: 1573
# Analizando bolsa: 1574
# Analizando bolsa: 1575
# Analizando bolsa: 1576
# Analizando bolsa: 1577
# Analizando bolsa: 1578
# Analizando bolsa: 1579
# Analizando bolsa: 1580
# Analizando bolsa: 1581
# Analizando bolsa: 1582
# Analizando bolsa: 1583
# Analizando bolsa: 1584
# Analizando bolsa: 1585
# Analizando bolsa: 1586
# Analizando bolsa: 1587
# Analizando bolsa: 1588
# Analizando bolsa: 1589
# Analizando bolsa: 1590
# Analizando bolsa: 1591
# Analizando bolsa: 1592
# Analizando bolsa: 1593
# Analizando bolsa: 1594
# Analizando bolsa: 1595
# Analizando bolsa: 1596
# Analizando bolsa: 1597
# Analizando bolsa: 1598
# Analizando bolsa: 1599
# Analizando bolsa: 1600
# Analizando bolsa: 1601
# Analizando bolsa: 1602
# Analizando bolsa: 1603
# Analizando bolsa: 1604
# Analizando bolsa: 1605
# Analizando bolsa: 1606
# Analizando bolsa: 1607
# Analizando bolsa: 1608
# Analizando bolsa: 1609
# Analizando bolsa: 1610
# Analizando bolsa: 1611
# Analizando bolsa: 1612
# Analizando bolsa: 1613
# Analizando bolsa: 1614
# Analizando bolsa: 1615
# Analizando bolsa: 1616
# Analizando bolsa: 1617
# Analizando bolsa: 1618
# Analizando bolsa: 1619
# Analizando bolsa: 1620
# Analizando bolsa: 1621
# Analizando bolsa: 1622
# Analizando bolsa: 1623
# Analizando bolsa: 1624
# Analizando bolsa: 1625
# Analizando bolsa: 1626
# Analizando bolsa: 1627
# Analizando bolsa: 1628
# Analizando bolsa: 1629
# Analizando bolsa: 1630
# Analizando bolsa: 1631
# Analizando bolsa: 1632
# Analizando bolsa: 1633
# Analizando bolsa: 1634
# Analizando bolsa: 1635
# Analizando bolsa: 1636
# Analizando bolsa: 1637
# Analizando bolsa: 1638
# Analizando bolsa: 1639
# Analizando bolsa: 1640
# Analizando bolsa: 1641
# Analizando bolsa: 1642
# Analizando bolsa: 1643
# Analizando bolsa: 1644
# Analizando bolsa: 1645
# Analizando bolsa: 1646
# Analizando bolsa: 1647
# Analizando bolsa: 1648
# Analizando bolsa: 1649
# Analizando bolsa: 1650
# Analizando bolsa: 1651
# Analizando bolsa: 1652
# Analizando bolsa: 1653
# Analizando bolsa: 1654
# Analizando bolsa: 1655
# Analizando bolsa: 1656
# Analizando bolsa: 1657
# Analizando bolsa: 1658
# Analizando bolsa: 1659
# Analizando bolsa: 1660
# Analizando bolsa: 1661
# Analizando bolsa: 1662
# Analizando bolsa: 1663
# Analizando bolsa: 1664
# Analizando bolsa: 1665
# Analizando bolsa: 1666
# Analizando bolsa: 1667
# Analizando bolsa: 1668
# Analizando bolsa: 1669
# Analizando bolsa: 1670
# Analizando bolsa: 1671
# Analizando bolsa: 1672
# Analizando bolsa: 1673
# Analizando bolsa: 1674
# Analizando bolsa: 1675
# Analizando bolsa: 1676
# Analizando bolsa: 1677
# Analizando bolsa: 1678
# Analizando bolsa: 1679
# Analizando bolsa: 1680
# Analizando bolsa: 1681
# Analizando bolsa: 1682
# Analizando bolsa: 1683
# Analizando bolsa: 1684
# Analizando bolsa: 1685
# Analizando bolsa: 1686
# Analizando bolsa: 1687
# Analizando bolsa: 1688
# Analizando bolsa: 1689
# Analizando bolsa: 1690
# Analizando bolsa: 1691
# Analizando bolsa: 1692
# Analizando bolsa: 1693
# Analizando bolsa: 1694
# Analizando bolsa: 1695
# Analizando bolsa: 1696
# Analizando bolsa: 1697
# Analizando bolsa: 1698
# Analizando bolsa: 1699
# Analizando bolsa: 1700
# Analizando bolsa: 1701
# Analizando bolsa: 1702
# Analizando bolsa: 1703
# Analizando bolsa: 1704
# Analizando bolsa: 1705
# Analizando bolsa: 1706
# Analizando bolsa: 1707
# Analizando bolsa: 1708
# Analizando bolsa: 1709
# Analizando bolsa: 1710
# Analizando bolsa: 1711
# Analizando bolsa: 1712
# Analizando bolsa: 1713
# Analizando bolsa: 1714
# Analizando bolsa: 1715
# Analizando bolsa: 1716
# Analizando bolsa: 1717
# Analizando bolsa: 1718
# Analizando bolsa: 1719
# Analizando bolsa: 1720
# Analizando bolsa: 1721
# Analizando bolsa: 1722
# Analizando bolsa: 1723
# Analizando bolsa: 1724
# Analizando bolsa: 1725
# Analizando bolsa: 1726
# Analizando bolsa: 1727
# Analizando bolsa: 1728
# Analizando bolsa: 1729
# Analizando bolsa: 1730
# Analizando bolsa: 1731
# Analizando bolsa: 1732
# Analizando bolsa: 1733
# Analizando bolsa: 1734
# Analizando bolsa: 1735
# Analizando bolsa: 1736
# Analizando bolsa: 1737
# Analizando bolsa: 1738
# Analizando bolsa: 1739
# Analizando bolsa: 1740
# Analizando bolsa: 1741
# Analizando bolsa: 1742
# Analizando bolsa: 1743
# Analizando bolsa: 1744
# Analizando bolsa: 1745
# Analizando bolsa: 1746
# Analizando bolsa: 1747
# Analizando bolsa: 1748
# Analizando bolsa: 1749
# Analizando bolsa: 1750
# Analizando bolsa: 1751
# Analizando bolsa: 1752
# Analizando bolsa: 1753
# Analizando bolsa: 1754
# Analizando bolsa: 1755
# Analizando bolsa: 1756
# Analizando bolsa: 1757
# Analizando bolsa: 1758
# Analizando bolsa: 1759
# Analizando bolsa: 1760
# Analizando bolsa: 1761
# Analizando bolsa: 1762
# Analizando bolsa: 1763
# Analizando bolsa: 1764
# Analizando bolsa: 1765
# Analizando bolsa: 1766
# Analizando bolsa: 1767
# Analizando bolsa: 1768
# Analizando bolsa: 1769
# Analizando bolsa: 1770
# Analizando bolsa: 1771
# Analizando bolsa: 1772
# Analizando bolsa: 1773
# Analizando bolsa: 1774
# Analizando bolsa: 1775
# Analizando bolsa: 1776
# Analizando bolsa: 1777
# Analizando bolsa: 1778
# Analizando bolsa: 1779
# Analizando bolsa: 1780
# Analizando bolsa: 1781
# Analizando bolsa: 1782
# Analizando bolsa: 1783
# Analizando bolsa: 1784
# Analizando bolsa: 1785
# Analizando bolsa: 1786
# Analizando bolsa: 1787
# Analizando bolsa: 1788
# Analizando bolsa: 1789
# Analizando bolsa: 1790
# Analizando bolsa: 1791
# Analizando bolsa: 1792
# Analizando bolsa: 1793
# Analizando bolsa: 1794
# Analizando bolsa: 1795
# Analizando bolsa: 1796
# Analizando bolsa: 1797
# Analizando bolsa: 1798
# Analizando bolsa: 1799
# Analizando bolsa: 1800
# Analizando bolsa: 1801
# Analizando bolsa: 1802
# Analizando bolsa: 1803
# Analizando bolsa: 1804
# Analizando bolsa: 1805
# Analizando bolsa: 1806
# Analizando bolsa: 1807
# Analizando bolsa: 1808
# Analizando bolsa: 1809
# Analizando bolsa: 1810
# Analizando bolsa: 1811
# Analizando bolsa: 1812
# Analizando bolsa: 1813
# Analizando bolsa: 1814
# Analizando bolsa: 1815
# Analizando bolsa: 1816
# Analizando bolsa: 1817
# Analizando bolsa: 1818
# Analizando bolsa: 1819
# Analizando bolsa: 1820
# Analizando bolsa: 1821
# Analizando bolsa: 1822
# Analizando bolsa: 1823
# Analizando bolsa: 1824
# Analizando bolsa: 1825
# Analizando bolsa: 1826
# Analizando bolsa: 1827
# Analizando bolsa: 1828
# Analizando bolsa: 1829
# Analizando bolsa: 1830
# Analizando bolsa: 1831
# Analizando bolsa: 1832
# Analizando bolsa: 1833
# Analizando bolsa: 1834
# Analizando bolsa: 1835
# Analizando bolsa: 1836
# Analizando bolsa: 1837
# Analizando bolsa: 1838
# Analizando bolsa: 1839
# Analizando bolsa: 1840
# Analizando bolsa: 1841
# Analizando bolsa: 1842
# Analizando bolsa: 1843
# Analizando bolsa: 1844
# Analizando bolsa: 1845
# Analizando bolsa: 1846
# Analizando bolsa: 1847
# Analizando bolsa: 1848
# Analizando bolsa: 1849
# Analizando bolsa: 1850
# Analizando bolsa: 1851
# Analizando bolsa: 1852
# Analizando bolsa: 1853
# Analizando bolsa: 1854
# Analizando bolsa: 1855
# Analizando bolsa: 1856
# Analizando bolsa: 1857
# Analizando bolsa: 1858
# Analizando bolsa: 1859
# Analizando bolsa: 1860
# Analizando bolsa: 1861
# Analizando bolsa: 1862
# Analizando bolsa: 1863
# Analizando bolsa: 1864
# Analizando bolsa: 1865
# Analizando bolsa: 1866
# Analizando bolsa: 1867
# Analizando bolsa: 1868
# Analizando bolsa: 1869
# Analizando bolsa: 1870
# Analizando bolsa: 1871
# Analizando bolsa: 1872
# Analizando bolsa: 1873
# Analizando bolsa: 1874
# Analizando bolsa: 1875
# Analizando bolsa: 1876
# Analizando bolsa: 1877
# Analizando bolsa: 1878
# Analizando bolsa: 1879
# Analizando bolsa: 1880
# Analizando bolsa: 1881
# Analizando bolsa: 1882
# Analizando bolsa: 1883
# Analizando bolsa: 1884
# Analizando bolsa: 1885
# Analizando bolsa: 1886
# Analizando bolsa: 1887
# Analizando bolsa: 1888
# Analizando bolsa: 1889
# Analizando bolsa: 1890
# Analizando bolsa: 1891
# Analizando bolsa: 1892
# Analizando bolsa: 1893
# Analizando bolsa: 1894
# Analizando bolsa: 1895
# Analizando bolsa: 1896
# Analizando bolsa: 1897
# Analizando bolsa: 1898
# Analizando bolsa: 1899
# Analizando bolsa: 1900
# Analizando bolsa: 1901
# Analizando bolsa: 1902
# Analizando bolsa: 1903
# Analizando bolsa: 1904
# Analizando bolsa: 1905
# Analizando bolsa: 1906
# Analizando bolsa: 1907
# Analizando bolsa: 1908
# Analizando bolsa: 1909
# Analizando bolsa: 1910
# Analizando bolsa: 1911
# Analizando bolsa: 1912
# Analizando bolsa: 1913
# Analizando bolsa: 1914
# Analizando bolsa: 1915
# Analizando bolsa: 1916
# Analizando bolsa: 1917
# Analizando bolsa: 1918
# Analizando bolsa: 1919
# Analizando bolsa: 1920
# Analizando bolsa: 1921
# Analizando bolsa: 1922
# Analizando bolsa: 1923
# Analizando bolsa: 1924
# Analizando bolsa: 1925
# Analizando bolsa: 1926
# Analizando bolsa: 1927
# Analizando bolsa: 1928
# Analizando bolsa: 1929
# Analizando bolsa: 1930
# Analizando bolsa: 1931
# Analizando bolsa: 1932
# Analizando bolsa: 1933
# Analizando bolsa: 1934
# Analizando bolsa: 1935
# Analizando bolsa: 1936
# Analizando bolsa: 1937
# Analizando bolsa: 1938
# Analizando bolsa: 1939
# Analizando bolsa: 1940
# Analizando bolsa: 1941
# Analizando bolsa: 1942
# Analizando bolsa: 1943
# Analizando bolsa: 1944
# Analizando bolsa: 1945
# Analizando bolsa: 1946
# Analizando bolsa: 1947
# Analizando bolsa: 1948
# Analizando bolsa: 1949
# Analizando bolsa: 1950
# Analizando bolsa: 1951
# Analizando bolsa: 1952
# Analizando bolsa: 1953
# Analizando bolsa: 1954
# Analizando bolsa: 1955
# Analizando bolsa: 1956
# Analizando bolsa: 1957
# Analizando bolsa: 1958
# Analizando bolsa: 1959
# Analizando bolsa: 1960
# Analizando bolsa: 1961
# Analizando bolsa: 1962
# Analizando bolsa: 1963
# Analizando bolsa: 1964
# Analizando bolsa: 1965
# Analizando bolsa: 1966
# Analizando bolsa: 1967
# Analizando bolsa: 1968
# Analizando bolsa: 1969
# Analizando bolsa: 1970
# Analizando bolsa: 1971
# Analizando bolsa: 1972
# Analizando bolsa: 1973
# Analizando bolsa: 1974
# Analizando bolsa: 1975
# Analizando bolsa: 1976
# Analizando bolsa: 1977
# Analizando bolsa: 1978
# Analizando bolsa: 1979
# Analizando bolsa: 1980
# Analizando bolsa: 1981
# Analizando bolsa: 1982
# Analizando bolsa: 1983
# Analizando bolsa: 1984
# Analizando bolsa: 1985
# Analizando bolsa: 1986
# Analizando bolsa: 1987
# Analizando bolsa: 1988
# Analizando bolsa: 1989
# Analizando bolsa: 1990
# Analizando bolsa: 1991
# Analizando bolsa: 1992
# Analizando bolsa: 1993
# Analizando bolsa: 1994
# Analizando bolsa: 1995
# Analizando bolsa: 1996
# Analizando bolsa: 1997
# Analizando bolsa: 1998
# Analizando bolsa: 1999
# Analizando bolsa: 2000
# Analizando bolsa: 2001
# Analizando bolsa: 2002
# Analizando bolsa: 2003
# Analizando bolsa: 2004
# Analizando bolsa: 2005
# Analizando bolsa: 2006
# Analizando bolsa: 2007
# Analizando bolsa: 2008
# Analizando bolsa: 2009
# Analizando bolsa: 2010
# Analizando bolsa: 2011
# Analizando bolsa: 2012
# Analizando bolsa: 2013
# Analizando bolsa: 2014
# Analizando bolsa: 2015
# Analizando bolsa: 2016
# Analizando bolsa: 2017
# Analizando bolsa: 2018
# Analizando bolsa: 2019
# Analizando bolsa: 2020
# Analizando bolsa: 2021
# Analizando bolsa: 2022
# Analizando bolsa: 2023
# Analizando bolsa: 2024
# Analizando bolsa: 2025
# Analizando bolsa: 2026
# Analizando bolsa: 2027
# Analizando bolsa: 2028
# Analizando bolsa: 2029
# Analizando bolsa: 2030
# Analizando bolsa: 2031
# Analizando bolsa: 2032
# Analizando bolsa: 2033
# Analizando bolsa: 2034
# Analizando bolsa: 2035
# Analizando bolsa: 2036
# Analizando bolsa: 2037
# Analizando bolsa: 2038
# Analizando bolsa: 2039
# Analizando bolsa: 2040
# Analizando bolsa: 2041
# Analizando bolsa: 2042
# Analizando bolsa: 2043
# Analizando bolsa: 2044
# Analizando bolsa: 2045
# Analizando bolsa: 2046
# Analizando bolsa: 2047
# Analizando bolsa: 2048
# Analizando bolsa: 2049
# Analizando bolsa: 2050
# Analizando bolsa: 2051
# Analizando bolsa: 2052
# Analizando bolsa: 2053
# Analizando bolsa: 2054
# Analizando bolsa: 2055
# Analizando bolsa: 2056
# Analizando bolsa: 2057
# Analizando bolsa: 2058
# Analizando bolsa: 2059
# Analizando bolsa: 2060
# Analizando bolsa: 2061
# Analizando bolsa: 2062
# Analizando bolsa: 2063
# Analizando bolsa: 2064
# Analizando bolsa: 2065
# Analizando bolsa: 2066
# Analizando bolsa: 2067
# Analizando bolsa: 2068
# Analizando bolsa: 2069
# Analizando bolsa: 2070
# Analizando bolsa: 2071
# Analizando bolsa: 2072
# Analizando bolsa: 2073
# Analizando bolsa: 2074
# Analizando bolsa: 2075
# Analizando bolsa: 2076
# Analizando bolsa: 2077
# Analizando bolsa: 2078
# Analizando bolsa: 2079
# Analizando bolsa: 2080
# Analizando bolsa: 2081
# Analizando bolsa: 2082
# Analizando bolsa: 2083
# Analizando bolsa: 2084
# Analizando bolsa: 2085
# Analizando bolsa: 2086
# Analizando bolsa: 2087
# Analizando bolsa: 2088
# Analizando bolsa: 2089
# Analizando bolsa: 2090
# Analizando bolsa: 2091
# Analizando bolsa: 2092
# Analizando bolsa: 2093
# Analizando bolsa: 2094
# Analizando bolsa: 2095
# Analizando bolsa: 2096
# Analizando bolsa: 2097
# Analizando bolsa: 2098
# Analizando bolsa: 2099
# Analizando bolsa: 2100
# Analizando bolsa: 2101
# Analizando bolsa: 2102
# Analizando bolsa: 2103
# Analizando bolsa: 2104
# Analizando bolsa: 2105
# Analizando bolsa: 2106
# Analizando bolsa: 2107
# Analizando bolsa: 2108
# Analizando bolsa: 2109
# Analizando bolsa: 2110
# Analizando bolsa: 2111
# Analizando bolsa: 2112
# Analizando bolsa: 2113
# Analizando bolsa: 2114
# Analizando bolsa: 2115
# Analizando bolsa: 2116
# Analizando bolsa: 2117
# Analizando bolsa: 2118
# Analizando bolsa: 2119
# Analizando bolsa: 2120
# Analizando bolsa: 2121
# Analizando bolsa: 2122
# Analizando bolsa: 2123
# Analizando bolsa: 2124
# Analizando bolsa: 2125
# Analizando bolsa: 2126
# Analizando bolsa: 2127
# Analizando bolsa: 2128
# Analizando bolsa: 2129
# Analizando bolsa: 2130
# Analizando bolsa: 2131
# Analizando bolsa: 2132
# Analizando bolsa: 2133
# Analizando bolsa: 2134
# Analizando bolsa: 2135
# Analizando bolsa: 2136
# Analizando bolsa: 2137
# Analizando bolsa: 2138
# Analizando bolsa: 2139
# Analizando bolsa: 2140
# Analizando bolsa: 2141
# Analizando bolsa: 2142
# Analizando bolsa: 2143
# Analizando bolsa: 2144
# Analizando bolsa: 2145
# Analizando bolsa: 2146
# Analizando bolsa: 2147
# Analizando bolsa: 2148
# Analizando bolsa: 2149
# Analizando bolsa: 2150
# Analizando bolsa: 2151
# Analizando bolsa: 2152
# Analizando bolsa: 2153
# Analizando bolsa: 2154
# Analizando bolsa: 2155
# Analizando bolsa: 2156
# Analizando bolsa: 2157
# Analizando bolsa: 2158
# Analizando bolsa: 2159
# Analizando bolsa: 2160
# Analizando bolsa: 2161
# Analizando bolsa: 2162
# Analizando bolsa: 2163
# Analizando bolsa: 2164
# Analizando bolsa: 2165
# Analizando bolsa: 2166
# Analizando bolsa: 2167
# Analizando bolsa: 2168
# Analizando bolsa: 2169
# Analizando bolsa: 2170
# Analizando bolsa: 2171
# Analizando bolsa: 2172
# Analizando bolsa: 2173
# Analizando bolsa: 2174
# Analizando bolsa: 2175
# Analizando bolsa: 2176
# Analizando bolsa: 2177
# Analizando bolsa: 2178
# Analizando bolsa: 2179
# Analizando bolsa: 2180
# Analizando bolsa: 2181
# Analizando bolsa: 2182
# Analizando bolsa: 2183
# Analizando bolsa: 2184
# Analizando bolsa: 2185
# Analizando bolsa: 2186
# Analizando bolsa: 2187
# Analizando bolsa: 2188
# Analizando bolsa: 2189
# Analizando bolsa: 2190
# Analizando bolsa: 2191
# Analizando bolsa: 2192
# Analizando bolsa: 2193
# Analizando bolsa: 2194
# Analizando bolsa: 2195
# Analizando bolsa: 2196
# Analizando bolsa: 2197
# Analizando bolsa: 2198
# Analizando bolsa: 2199
# Analizando bolsa: 2200
# Analizando bolsa: 2201
# Analizando bolsa: 2202
# Analizando bolsa: 2203
# Analizando bolsa: 2204
# Analizando bolsa: 2205
# Analizando bolsa: 2206
# Analizando bolsa: 2207
# Analizando bolsa: 2208
# Analizando bolsa: 2209
# Analizando bolsa: 2210
# Analizando bolsa: 2211
# Analizando bolsa: 2212
# Analizando bolsa: 2213
# Analizando bolsa: 2214
# Analizando bolsa: 2215
# Analizando bolsa: 2216
# Analizando bolsa: 2217
# Analizando bolsa: 2218
# Analizando bolsa: 2219
# Analizando bolsa: 2220
# Analizando bolsa: 2221
# Analizando bolsa: 2222
# Analizando bolsa: 2223
# Analizando bolsa: 2224
# Analizando bolsa: 2225
# Analizando bolsa: 2226
# Analizando bolsa: 2227
# Analizando bolsa: 2228
# Analizando bolsa: 2229
# Analizando bolsa: 2230
# Analizando bolsa: 2231
# Analizando bolsa: 2232
# Analizando bolsa: 2233
# Analizando bolsa: 2234
# Analizando bolsa: 2235
# ...
# Analizando bolsa: 4418
# Analizando bolsa: 4419
# Analizando bolsa: 4420
# Analizando bolsa: 4421
# Analizando bolsa: 4422
# Analizando bolsa: 4423
# Analizando bolsa: 4424
# Analizando bolsa: 4425
# Analizando bolsa: 4426
# Analizando bolsa: 4427
# Analizando bolsa: 4428
# Analizando bolsa: 4429
# Analizando bolsa: 4430
# Analizando bolsa: 4431
# Analizando bolsa: 4432
# Analizando bolsa: 4433
# Analizando bolsa: 4434
# Analizando bolsa: 4435
# Analizando bolsa: 4436
# Analizando bolsa: 4437
# Analizando bolsa: 4438
# Analizando bolsa: 4439
# Analizando bolsa: 4440
# Analizando bolsa: 4441
# Analizando bolsa: 4442
# Analizando bolsa: 4443
# Analizando bolsa: 4444
# Analizando bolsa: 4445
# Analizando bolsa: 4446
# Analizando bolsa: 4447
# Analizando bolsa: 4448
# Analizando bolsa: 4449
# Analizando bolsa: 4450
# Analizando bolsa: 4451
# Analizando bolsa: 4452
# Analizando bolsa: 4453
# Analizando bolsa: 4454
# Analizando bolsa: 4455
# Analizando bolsa: 4456
# Analizando bolsa: 4457
# Analizando bolsa: 4458
# Analizando bolsa: 4459
# Analizando bolsa: 4460
# Analizando bolsa: 4461
# Analizando bolsa: 4462
# Analizando bolsa: 4463
# Analizando bolsa: 4464
# Analizando bolsa: 4465
# Analizando bolsa: 4466
# Analizando bolsa: 4467
# Analizando bolsa: 4468
# Analizando bolsa: 4469
# Analizando bolsa: 4470
# Analizando bolsa: 4471
# Analizando bolsa: 4472
# Analizando bolsa: 4473
# Analizando bolsa: 4474
# Analizando bolsa: 4475
# Analizando bolsa: 4476
# Analizando bolsa: 4477
# Analizando bolsa: 4478
# Analizando bolsa: 4479
# Analizando bolsa: 4480
# Analizando bolsa: 4481
# Analizando bolsa: 4482
# Analizando bolsa: 4483
# Analizando bolsa: 4484
# Analizando bolsa: 4485
# Analizando bolsa: 4486
# Analizando bolsa: 4487
# Analizando bolsa: 4488
# Analizando bolsa: 4489
# Analizando bolsa: 4490
# Analizando bolsa: 4491
# Analizando bolsa: 4492
# Analizando bolsa: 4493
# Analizando bolsa: 4494
# Analizando bolsa: 4495
# Analizando bolsa: 4496
# Analizando bolsa: 4497
# Analizando bolsa: 4498
# Analizando bolsa: 4499
# Analizando bolsa: 4500
# Analizando bolsa: 4501
# Analizando bolsa: 4502
# Analizando bolsa: 4503
# Analizando bolsa: 4504
# Analizando bolsa: 4505
# Analizando bolsa: 4506
# Analizando bolsa: 4507
# Analizando bolsa: 4508
# Analizando bolsa: 4509
# Analizando bolsa: 4510
# Analizando bolsa: 4511
# Analizando bolsa: 4512
# Analizando bolsa: 4513
# Analizando bolsa: 4514
# Analizando bolsa: 4515
# Analizando bolsa: 4516
# Analizando bolsa: 4517
# Analizando bolsa: 4518
# Analizando bolsa: 4519
# Analizando bolsa: 4520
# Analizando bolsa: 4521
# Analizando bolsa: 4522
# Analizando bolsa: 4523
# Analizando bolsa: 4524
# Analizando bolsa: 4525
# Analizando bolsa: 4526
# Analizando bolsa: 4527
# Analizando bolsa: 4528
# Analizando bolsa: 4529
# Analizando bolsa: 4530
# Analizando bolsa: 4531
# Analizando bolsa: 4532
# Analizando bolsa: 4533
# Analizando bolsa: 4534
# Analizando bolsa: 4535
# Analizando bolsa: 4536
# Analizando bolsa: 4537
# Analizando bolsa: 4538
# Analizando bolsa: 4539
# Analizando bolsa: 4540
# Analizando bolsa: 4541
# Analizando bolsa: 4542
# Analizando bolsa: 4543
# Analizando bolsa: 4544
# Analizando bolsa: 4545
# Analizando bolsa: 4546
# Analizando bolsa: 4547
# Analizando bolsa: 4548
# Analizando bolsa: 4549
# Analizando bolsa: 4550
# Analizando bolsa: 4551
# Analizando bolsa: 4552
# Analizando bolsa: 4553
# Analizando bolsa: 4554
# Analizando bolsa: 4555
# Analizando bolsa: 4556
# Analizando bolsa: 4557
# Analizando bolsa: 4558
# Analizando bolsa: 4559
# Analizando bolsa: 4560
# Analizando bolsa: 4561
# Analizando bolsa: 4562
# Analizando bolsa: 4563
# Analizando bolsa: 4564
# Analizando bolsa: 4565
# Analizando bolsa: 4566
# Analizando bolsa: 4567
# Analizando bolsa: 4568
# Analizando bolsa: 4569
# Analizando bolsa: 4570
# Analizando bolsa: 4571
# Analizando bolsa: 4572
# Analizando bolsa: 4573
# Analizando bolsa: 4574
# Analizando bolsa: 4575
# Analizando bolsa: 4576
# Analizando bolsa: 4577
# Analizando bolsa: 4578
# Analizando bolsa: 4579
# Analizando bolsa: 4580
# Analizando bolsa: 4581
# Analizando bolsa: 4582
# Analizando bolsa: 4583
# Analizando bolsa: 4584
# Analizando bolsa: 4585
# Analizando bolsa: 4586
# Analizando bolsa: 4587
# Analizando bolsa: 4588
# Analizando bolsa: 4589
# Analizando bolsa: 4590
# Analizando bolsa: 4591
# Analizando bolsa: 4592
# Analizando bolsa: 4593
# Analizando bolsa: 4594
# Analizando bolsa: 4595
# Analizando bolsa: 4596
# Analizando bolsa: 4597
# Analizando bolsa: 4598
# Analizando bolsa: 4599
# Analizando bolsa: 4600
# Analizando bolsa: 4601
# Analizando bolsa: 4602
# Analizando bolsa: 4603
# Analizando bolsa: 4604
# Analizando bolsa: 4605
# Analizando bolsa: 4606
# Analizando bolsa: 4607
# Analizando bolsa: 4608
# Analizando bolsa: 4609
# Analizando bolsa: 4610
# Analizando bolsa: 4611
# Analizando bolsa: 4612
# Analizando bolsa: 4613
# Analizando bolsa: 4614
# Analizando bolsa: 4615
# Analizando bolsa: 4616
# Analizando bolsa: 4617
# Analizando bolsa: 4618
# Analizando bolsa: 4619
# Analizando bolsa: 4620
# Analizando bolsa: 4621
# Analizando bolsa: 4622
# Analizando bolsa: 4623
# Analizando bolsa: 4624
# Analizando bolsa: 4625
# Analizando bolsa: 4626
# Analizando bolsa: 4627
# Analizando bolsa: 4628
# Analizando bolsa: 4629
# Analizando bolsa: 4630
# Analizando bolsa: 4631
# Analizando bolsa: 4632
# Analizando bolsa: 4633
# Analizando bolsa: 4634
# Analizando bolsa: 4635
# Analizando bolsa: 4636
# Analizando bolsa: 4637
# Analizando bolsa: 4638
# Analizando bolsa: 4639
# Analizando bolsa: 4640
# Analizando bolsa: 4641
# Analizando bolsa: 4642
# Analizando bolsa: 4643
# Analizando bolsa: 4644
# Analizando bolsa: 4645
# Analizando bolsa: 4646
# Analizando bolsa: 4647
# Analizando bolsa: 4648
# Analizando bolsa: 4649
# Analizando bolsa: 4650
# Analizando bolsa: 4651
# Analizando bolsa: 4652
# Analizando bolsa: 4653
# Analizando bolsa: 4654
# Analizando bolsa: 4655
# Analizando bolsa: 4656
# Analizando bolsa: 4657
# Analizando bolsa: 4658
# Analizando bolsa: 4659
# Analizando bolsa: 4660
# Analizando bolsa: 4661
# Analizando bolsa: 4662
# Analizando bolsa: 4663
# Analizando bolsa: 4664
# Analizando bolsa: 4665
# Analizando bolsa: 4666
# Analizando bolsa: 4667
# Analizando bolsa: 4668
# Analizando bolsa: 4669
# Analizando bolsa: 4670
# Analizando bolsa: 4671
# Analizando bolsa: 4672
# Analizando bolsa: 4673
# Analizando bolsa: 4674
# Analizando bolsa: 4675
# Analizando bolsa: 4676
# Analizando bolsa: 4677
# Analizando bolsa: 4678
# Analizando bolsa: 4679
# Analizando bolsa: 4680
# Analizando bolsa: 4681
# Analizando bolsa: 4682
# Analizando bolsa: 4683
# Analizando bolsa: 4684
# Analizando bolsa: 4685
# Analizando bolsa: 4686
# Analizando bolsa: 4687
# Analizando bolsa: 4688
# Analizando bolsa: 4689
# Analizando bolsa: 4690
# Analizando bolsa: 4691
# Analizando bolsa: 4692
# Analizando bolsa: 4693
# Analizando bolsa: 4694
# Analizando bolsa: 4695
# Analizando bolsa: 4696
# Analizando bolsa: 4697
# Analizando bolsa: 4698
# Analizando bolsa: 4699
# Analizando bolsa: 4700
# Analizando bolsa: 4701
# Analizando bolsa: 4702
# Analizando bolsa: 4703
# Analizando bolsa: 4704
# Analizando bolsa: 4705
# Analizando bolsa: 4706
# Analizando bolsa: 4707
# Analizando bolsa: 4708
# Analizando bolsa: 4709
# Analizando bolsa: 4710
# Analizando bolsa: 4711
# Analizando bolsa: 4712
# Analizando bolsa: 4713
# Analizando bolsa: 4714
# Analizando bolsa: 4715
# Analizando bolsa: 4716
# Analizando bolsa: 4717
# Analizando bolsa: 4718
# Analizando bolsa: 4719
# Analizando bolsa: 4720
# Analizando bolsa: 4721
# Analizando bolsa: 4722
# Analizando bolsa: 4723
# Analizando bolsa: 4724
# Analizando bolsa: 4725
# Analizando bolsa: 4726
# Analizando bolsa: 4727
# Analizando bolsa: 4728
# Analizando bolsa: 4729
# Analizando bolsa: 4730
# Analizando bolsa: 4731
# Analizando bolsa: 4732
# Analizando bolsa: 4733
# Analizando bolsa: 4734
# Analizando bolsa: 4735
# Analizando bolsa: 4736
# Analizando bolsa: 4737
# Analizando bolsa: 4738
# Analizando bolsa: 4739
# Analizando bolsa: 4740
# Analizando bolsa: 4741
# Analizando bolsa: 4742
# Analizando bolsa: 4743
# Analizando bolsa: 4744
# Analizando bolsa: 4745
# Analizando bolsa: 4746
# Analizando bolsa: 4747
# Analizando bolsa: 4748
# Analizando bolsa: 4749
# Analizando bolsa: 4750
# Analizando bolsa: 4751
# Analizando bolsa: 4752
# Analizando bolsa: 4753
# Analizando bolsa: 4754
# Analizando bolsa: 4755
# Analizando bolsa: 4756
# Analizando bolsa: 4757
# Analizando bolsa: 4758
# Analizando bolsa: 4759
# Analizando bolsa: 4760
# Analizando bolsa: 4761
# Analizando bolsa: 4762
# Analizando bolsa: 4763
# Analizando bolsa: 4764
# Analizando bolsa: 4765
# Analizando bolsa: 4766
# Analizando bolsa: 4767
# Analizando bolsa: 4768
# Analizando bolsa: 4769
# Analizando bolsa: 4770
# Analizando bolsa: 4771
# Analizando bolsa: 4772
# Analizando bolsa: 4773
# Analizando bolsa: 4774
# Analizando bolsa: 4775
# Analizando bolsa: 4776
# Analizando bolsa: 4777
# Analizando bolsa: 4778
# Analizando bolsa: 4779
# Analizando bolsa: 4780
# Analizando bolsa: 4781
# Analizando bolsa: 4782
# Analizando bolsa: 4783
# Analizando bolsa: 4784
# Analizando bolsa: 4785
# Analizando bolsa: 4786
# Analizando bolsa: 4787
# Analizando bolsa: 4788
# Analizando bolsa: 4789
# Analizando bolsa: 4790
# Analizando bolsa: 4791
# Analizando bolsa: 4792
# Analizando bolsa: 4793
# Analizando bolsa: 4794
# Analizando bolsa: 4795
# Analizando bolsa: 4796
# Analizando bolsa: 4797
# Analizando bolsa: 4798
# Analizando bolsa: 4799
# Analizando bolsa: 4800
# Analizando bolsa: 4801
# Analizando bolsa: 4802
# Analizando bolsa: 4803
# Analizando bolsa: 4804
# Analizando bolsa: 4805
# Analizando bolsa: 4806
# Analizando bolsa: 4807
# Analizando bolsa: 4808
# Analizando bolsa: 4809
# Analizando bolsa: 4810
# Analizando bolsa: 4811
# Analizando bolsa: 4812
# Analizando bolsa: 4813
# Analizando bolsa: 4814
# Analizando bolsa: 4815
# Analizando bolsa: 4816
# Analizando bolsa: 4817
# Analizando bolsa: 4818
# Analizando bolsa: 4819
# Analizando bolsa: 4820
# Analizando bolsa: 4821
# Analizando bolsa: 4822
# Analizando bolsa: 4823
# Analizando bolsa: 4824
# Analizando bolsa: 4825
# Analizando bolsa: 4826
# Analizando bolsa: 4827
# Analizando bolsa: 4828
# Analizando bolsa: 4829
# Analizando bolsa: 4830
# Analizando bolsa: 4831
# Analizando bolsa: 4832
# Analizando bolsa: 4833
# Analizando bolsa: 4834
# Analizando bolsa: 4835
# Analizando bolsa: 4836
# Analizando bolsa: 4837
# Analizando bolsa: 4838
# Analizando bolsa: 4839
# Analizando bolsa: 4840
# Analizando bolsa: 4841
# Analizando bolsa: 4842
# Analizando bolsa: 4843
# Analizando bolsa: 4844
# Analizando bolsa: 4845
# Analizando bolsa: 4846
# Analizando bolsa: 4847
# Analizando bolsa: 4848
# Analizando bolsa: 4849
# Analizando bolsa: 4850
# Analizando bolsa: 4851
# Analizando bolsa: 4852
# Analizando bolsa: 4853
# Analizando bolsa: 4854
# Analizando bolsa: 4855
# Analizando bolsa: 4856
# Analizando bolsa: 4857
# Analizando bolsa: 4858
# Analizando bolsa: 4859
# Analizando bolsa: 4860
# Analizando bolsa: 4861
# Analizando bolsa: 4862
# Analizando bolsa: 4863
# Analizando bolsa: 4864
# Analizando bolsa: 4865
# Analizando bolsa: 4866
# Analizando bolsa: 4867
# Analizando bolsa: 4868
# Analizando bolsa: 4869
# Analizando bolsa: 4870
# Analizando bolsa: 4871
# Analizando bolsa: 4872
# Analizando bolsa: 4873
# Analizando bolsa: 4874
# Analizando bolsa: 4875
# Analizando bolsa: 4876
# Analizando bolsa: 4877
# Analizando bolsa: 4878
# Analizando bolsa: 4879
# Analizando bolsa: 4880
# Analizando bolsa: 4881
# Analizando bolsa: 4882
# Analizando bolsa: 4883
# Analizando bolsa: 4884
# Analizando bolsa: 4885
# Analizando bolsa: 4886
# Analizando bolsa: 4887
# Analizando bolsa: 4888
# Analizando bolsa: 4889
# Analizando bolsa: 4890
# Analizando bolsa: 4891
# Analizando bolsa: 4892
# Analizando bolsa: 4893
# Analizando bolsa: 4894
# Analizando bolsa: 4895
# Analizando bolsa: 4896
# Analizando bolsa: 4897
# Analizando bolsa: 4898
# Analizando bolsa: 4899
# Analizando bolsa: 4900
# Analizando bolsa: 4901
# Analizando bolsa: 4902
# Analizando bolsa: 4903
# Analizando bolsa: 4904
# Analizando bolsa: 4905
# Analizando bolsa: 4906
# Analizando bolsa: 4907
# Analizando bolsa: 4908
# Analizando bolsa: 4909
# Analizando bolsa: 4910
# Analizando bolsa: 4911
# Analizando bolsa: 4912
# Analizando bolsa: 4913
# Analizando bolsa: 4914
# Analizando bolsa: 4915
# Analizando bolsa: 4916
# Analizando bolsa: 4917
# Analizando bolsa: 4918
# Analizando bolsa: 4919
# Analizando bolsa: 4920
# Analizando bolsa: 4921
# Analizando bolsa: 4922
# Analizando bolsa: 4923
# Analizando bolsa: 4924
# Analizando bolsa: 4925
# Analizando bolsa: 4926
# Analizando bolsa: 4927
# Analizando bolsa: 4928
# Analizando bolsa: 4929
# Analizando bolsa: 4930
# Analizando bolsa: 4931
# Analizando bolsa: 4932
# Analizando bolsa: 4933
# Analizando bolsa: 4934
# Analizando bolsa: 4935
# Analizando bolsa: 4936
# Analizando bolsa: 4937
# Analizando bolsa: 4938
# Analizando bolsa: 4939
# Analizando bolsa: 4940
# Analizando bolsa: 4941
# Analizando bolsa: 4942
# Analizando bolsa: 4943
# Analizando bolsa: 4944
# Analizando bolsa: 4945
# Analizando bolsa: 4946
# Analizando bolsa: 4947
# Analizando bolsa: 4948
# Analizando bolsa: 4949
# Analizando bolsa: 4950
# Analizando bolsa: 4951
# Analizando bolsa: 4952
# Analizando bolsa: 4953
# Analizando bolsa: 4954
# Analizando bolsa: 4955
# Analizando bolsa: 4956
# Analizando bolsa: 4957
# Analizando bolsa: 4958
# Analizando bolsa: 4959
# Analizando bolsa: 4960
# Analizando bolsa: 4961
# Analizando bolsa: 4962
# Analizando bolsa: 4963
# Analizando bolsa: 4964
# Analizando bolsa: 4965
# Analizando bolsa: 4966
# Analizando bolsa: 4967
# Analizando bolsa: 4968
# Analizando bolsa: 4969
# Analizando bolsa: 4970
# Analizando bolsa: 4971
# Analizando bolsa: 4972
# Analizando bolsa: 4973
# Analizando bolsa: 4974
# Analizando bolsa: 4975
# Analizando bolsa: 4976
# Analizando bolsa: 4977
# Analizando bolsa: 4978
# Analizando bolsa: 4979
# Analizando bolsa: 4980
# Analizando bolsa: 4981
# Analizando bolsa: 4982
# Analizando bolsa: 4983
# Analizando bolsa: 4984
# Analizando bolsa: 4985
# Analizando bolsa: 4986
# Analizando bolsa: 4987
# Analizando bolsa: 4988
# Analizando bolsa: 4989
# Analizando bolsa: 4990
# Analizando bolsa: 4991
# Analizando bolsa: 4992
# Analizando bolsa: 4993
# Analizando bolsa: 4994
# Analizando bolsa: 4995
# Analizando bolsa: 4996
# Analizando bolsa: 4997
# Analizando bolsa: 4998
# Analizando bolsa: 4999
# Analizando bolsa: 5000
# Analizando bolsa: 5001
# Analizando bolsa: 5002
# Analizando bolsa: 5003
# Analizando bolsa: 5004
# Analizando bolsa: 5005
# Analizando bolsa: 5006
# Analizando bolsa: 5007
# Analizando bolsa: 5008
# Analizando bolsa: 5009
# Analizando bolsa: 5010
# Analizando bolsa: 5011
# Analizando bolsa: 5012
# Analizando bolsa: 5013
# Analizando bolsa: 5014
# Analizando bolsa: 5015
# Analizando bolsa: 5016
# Analizando bolsa: 5017
# Analizando bolsa: 5018
# Analizando bolsa: 5019
# Analizando bolsa: 5020
# Analizando bolsa: 5021
# Analizando bolsa: 5022
# Analizando bolsa: 5023
# Analizando bolsa: 5024
# Analizando bolsa: 5025
# Analizando bolsa: 5026
# Analizando bolsa: 5027
# Analizando bolsa: 5028
# Analizando bolsa: 5029
# Analizando bolsa: 5030
# Analizando bolsa: 5031
# Analizando bolsa: 5032
# Analizando bolsa: 5033
# Analizando bolsa: 5034
# Analizando bolsa: 5035
# Analizando bolsa: 5036
# Analizando bolsa: 5037
# Analizando bolsa: 5038
# Analizando bolsa: 5039
# Analizando bolsa: 5040
# Analizando bolsa: 5041
# Analizando bolsa: 5042
# Analizando bolsa: 5043
# Analizando bolsa: 5044
# Analizando bolsa: 5045
# Analizando bolsa: 5046
# Analizando bolsa: 5047
# Analizando bolsa: 5048
# Analizando bolsa: 5049
# Analizando bolsa: 5050
# Analizando bolsa: 5051
# Analizando bolsa: 5052
# Analizando bolsa: 5053
# Analizando bolsa: 5054
# Analizando bolsa: 5055
# Analizando bolsa: 5056
# Analizando bolsa: 5057
# Analizando bolsa: 5058
# Analizando bolsa: 5059
# Analizando bolsa: 5060
# Analizando bolsa: 5061
# Analizando bolsa: 5062
# Analizando bolsa: 5063
# Analizando bolsa: 5064
# Analizando bolsa: 5065
# Analizando bolsa: 5066
# Analizando bolsa: 5067
# Analizando bolsa: 5068
# Analizando bolsa: 5069
# Analizando bolsa: 5070
# Analizando bolsa: 5071
# Analizando bolsa: 5072
# Analizando bolsa: 5073
# Analizando bolsa: 5074
# Analizando bolsa: 5075
# Analizando bolsa: 5076
# Analizando bolsa: 5077
# Analizando bolsa: 5078
# Analizando bolsa: 5079
# Analizando bolsa: 5080
# Analizando bolsa: 5081
# Analizando bolsa: 5082
# Analizando bolsa: 5083
# Analizando bolsa: 5084
# Analizando bolsa: 5085
# Analizando bolsa: 5086
# Analizando bolsa: 5087
# Analizando bolsa: 5088
# Analizando bolsa: 5089
# Analizando bolsa: 5090
# Analizando bolsa: 5091
# Analizando bolsa: 5092
# Analizando bolsa: 5093
# Analizando bolsa: 5094
# Analizando bolsa: 5095
# Analizando bolsa: 5096
# Analizando bolsa: 5097
# Analizando bolsa: 5098
# Analizando bolsa: 5099
# Analizando bolsa: 5100
# Analizando bolsa: 5101
# Analizando bolsa: 5102
# Analizando bolsa: 5103
# Analizando bolsa: 5104
# Analizando bolsa: 5105
# Analizando bolsa: 5106
# Analizando bolsa: 5107
# Analizando bolsa: 5108
# Analizando bolsa: 5109
# Analizando bolsa: 5110
# Analizando bolsa: 5111
# Analizando bolsa: 5112

# %% [markdown]
# ---
#
# Observando en qué imágenes está presente la característica 0
#
# ---

# %%
ifs.__getitem__(0)
# Out:
# La pocisión 0 contiene la característica 129026
# [0, 60, 83, 96, 161, 1149, 1307, 1524, 3193, 3197, 3706, 4277, 4279, 4922]

# %% [markdown]
# ---
#
# De acuerdo a lo que entendí, las búsquedas se realizarían enviando la imagen completa (En este caso, se mandaría la bolsa de características completa), para hacerlo más interesante escogo una imagen al azar para así observar el desempeño del algoritmo de mejor forma
#
# ---

# %%
consulta = random.randint(0,len(bolsas_entrenamiento)-1)
img_cons = Lista_Entr[consulta]

# %%
print(f"La imagen de consulta es: {img_cons}")
obten_imagen(img_cons)
# Out:
# La imagen de consulta es: paris_general_001844

# %% [markdown]
# ---
#
# Usamos el índice inverso para recuperar las que contienen las características de la una consulta ordenados por coincidencias
#
# ---

# %%
consulta = bolsas_entrenamiento[consulta]

# %%
Parecidos = ifs.recupera(consulta)

# %% [markdown]
# ---
#
# Como dato cultural muestro la imágen que tuvo más coincidencias
#
# ---

# %%
mayor = Parecidos.most_common()[1]# Tomamos el 1, porque el 0 es la misma imagen
mayor
# Out:
# (2319, 82)

# %%
Index_inv_img = Lista_Entr[mayor[0]]

# %%
print(f"La imagen con mayor parecido por índice inverso es: {Index_inv_img}")
obten_imagen(Index_inv_img)
# Out:
# La imagen con mayor parecido por índice inverso es: paris_general_002769

# %% [markdown]
# ---
#
# Ya tenemos las imágenes que se pueden parecer más, ahora bien, me parece que aquellas cuya frecuencia sea igua o menor a 2, es decir sólo hubo a lo mucho 2 características que coincidieron, no pienso que san realmente relevantes, así que los elimino
#
# ---

# %%
Res = []
comunes = Parecidos.most_common()[1:]#Nuevamente desechamos el primer valor 
print(len(comunes))
k=0
for (_,i) in comunes:
  k+=1
  if i > 2:
    Res.append(comunes[k])
# Out:
# 1594

# %%
len(Res) # como podemos observar, reducimos en más del 50% los datos a analizar
# Out:
# 413

# %%
Res[1:4]
# Out:
# [(2543, 81), (2551, 80), (2296, 74)]

# %% [markdown]
# ---
#
# Ahora sí ya contamos con la lista de imagenes a evaluar en cuanto a distancias, por lo que procedemos a crear una función que nos ayude a evaluar las 3 distancias y retornar el mayor de cada una.
#
# ---

# %%
def Evalua_distancias(Consulta, Parecidos, lista):
    
    # De acuerdo con las especificaciones del proyecto, debo evaluar
    # con Jaccard, MinMax y Coseno, por lo que eso hace esta función
    # PERO, sólo va a mostar el que tuvo mayor coincidencia de 
    # Cada una de las funciones, es decir, devolverá el más común para 
    # Jaccad, el más común para Coseno y el más común para MinMax

    Jac = []
    Cos = []
    Min = []

    # Calculamos las distancias entre cada uno de ellos
    for (imagen,_) in Parecidos:
      # Calculamos la distancia entre las características de la consulta con las de la imagen parecida
      Cos.append(similitud_coseno(Consulta,lista[imagen])) 
      Jac.append(similitud_jaccard(Consulta,lista[imagen]))
      Min.append(similitud_minmax(Consulta,lista[imagen]))

    Res = []

    #Finalmente crearemos una lista con los máximos de cada uno, devolveremos 3 elementos

    aux = np.argmax(Jac)
    Res.append((aux, Jac[aux]))

    aux = np.argmax(Cos)
    Res.append((aux,Cos[aux]))

    aux = np.argmax(Min)
    Res.append((aux,Min[aux]))

    return Res # Devolvemos la lista con los 3 que tuvieron mayor coincidencia y claro, su valor

# %% [markdown]
# ---
#
# Lo último que queda es llamarla y mostrar nuestras Imágenes con mayor coincidencia
#
# ---

# %%
Maximos = Evalua_distancias(consulta,Res,bolsas_entrenamiento)

# %%
# Sabemos que tenemos 3 tuplas cuyos valores corresponden a 
# (No. imagen, valor de similitud)
Maximos
# Out:
# [(22, 0.36180904522613067),
#  (261, 0.7513367353312126),
#  (261, 0.4975759013350502)]

# %%
def max_dist(consulta,metodo,maximo,lista,lis):
  print('Se evaluó la imagen:',consulta)
  print("\nLa mayor coincidencia en similitud de",metodo,"fue:",lista[lis[maximo[0]][0]],'\ncon un resultado de:',maximo[1])
  print('\n')
  obten_imagen(lista[lis[maximo[0]][0]])

# %%
max_dist(img_cons,'Coseno',Maximos[0],Lista_Entr,Res)
# Out:
# Se evaluó la imagen: paris_general_001844
#
# La mayor coincidencia en similitud de Coseno fue: paris_museedorsay_000019
# con un resultado de: 0.36180904522613067

# %%
max_dist(img_cons,'Jaccard',Maximos[1],Lista_Entr,Res)
# Out:
# Se evaluó la imagen: paris_general_001844
#
# La mayor coincidencia en similitud de Jaccard fue: paris_general_001249
# con un resultado de: 0.7513367353312126

# %%
max_dist(img_cons,'MinMax',Maximos[2],Lista_Entr,Res)
# Out:
# Se evaluó la imagen: paris_general_001844
#
# La mayor coincidencia en similitud de MinMax fue: paris_general_001249
# con un resultado de: 0.4975759013350502

# %% [markdown]
# ---
#
# Personalmente no me gustaron los resultados, yo esperaba obtener la misma imagen desde diversos ángulos, al parecer no fue así, si acaso las 2 últimas tienen relación, pues igual son 'General', pero la primera no tanto (Hablando del ejemplo aplicado a paris_general_001844)
#
# ---

# %% [markdown]
# ---
#
# # Aplicando el clasificador a los datos de validación
#
# ---

# %%
ifs_validacion = IndiceInverso()
ifs_validacion.Add(bolsas_validacion)
# Out:
# Analizando bolsa: 1
# Analizando bolsa: 2
# Analizando bolsa: 3
# Analizando bolsa: 4
# Analizando bolsa: 5
# Analizando bolsa: 6
# Analizando bolsa: 7
# Analizando bolsa: 8
# Analizando bolsa: 9
# Analizando bolsa: 10
# Analizando bolsa: 11
# Analizando bolsa: 12
# Analizando bolsa: 13
# Analizando bolsa: 14
# Analizando bolsa: 15
# Analizando bolsa: 16
# Analizando bolsa: 17
# Analizando bolsa: 18
# Analizando bolsa: 19
# Analizando bolsa: 20
# Analizando bolsa: 21
# Analizando bolsa: 22
# Analizando bolsa: 23
# Analizando bolsa: 24
# Analizando bolsa: 25
# Analizando bolsa: 26
# Analizando bolsa: 27
# Analizando bolsa: 28
# Analizando bolsa: 29
# Analizando bolsa: 30
# Analizando bolsa: 31
# Analizando bolsa: 32
# Analizando bolsa: 33
# Analizando bolsa: 34
# Analizando bolsa: 35
# Analizando bolsa: 36
# Analizando bolsa: 37
# Analizando bolsa: 38
# Analizando bolsa: 39
# Analizando bolsa: 40
# Analizando bolsa: 41
# Analizando bolsa: 42
# Analizando bolsa: 43
# Analizando bolsa: 44
# Analizando bolsa: 45
# Analizando bolsa: 46
# Analizando bolsa: 47
# Analizando bolsa: 48
# Analizando bolsa: 49
# Analizando bolsa: 50
# Analizando bolsa: 51
# Analizando bolsa: 52
# Analizando bolsa: 53
# Analizando bolsa: 54
# Analizando bolsa: 55
# Analizando bolsa: 56
# Analizando bolsa: 57
# Analizando bolsa: 58
# Analizando bolsa: 59
# Analizando bolsa: 60
# Analizando bolsa: 61
# Analizando bolsa: 62
# Analizando bolsa: 63
# Analizando bolsa: 64
# Analizando bolsa: 65
# Analizando bolsa: 66
# Analizando bolsa: 67
# Analizando bolsa: 68
# Analizando bolsa: 69
# Analizando bolsa: 70
# Analizando bolsa: 71
# Analizando bolsa: 72
# Analizando bolsa: 73
# Analizando bolsa: 74
# Analizando bolsa: 75
# Analizando bolsa: 76
# Analizando bolsa: 77
# Analizando bolsa: 78
# Analizando bolsa: 79
# Analizando bolsa: 80
# Analizando bolsa: 81
# Analizando bolsa: 82
# Analizando bolsa: 83
# Analizando bolsa: 84
# Analizando bolsa: 85
# Analizando bolsa: 86
# Analizando bolsa: 87
# Analizando bolsa: 88
# Analizando bolsa: 89
# Analizando bolsa: 90
# Analizando bolsa: 91
# Analizando bolsa: 92
# Analizando bolsa: 93
# Analizando bolsa: 94
# Analizando bolsa: 95
# Analizando bolsa: 96
# Analizando bolsa: 97
# Analizando bolsa: 98
# Analizando bolsa: 99
# Analizando bolsa: 100
# Analizando bolsa: 101
# Analizando bolsa: 102
# Analizando bolsa: 103
# Analizando bolsa: 104
# Analizando bolsa: 105
# Analizando bolsa: 106
# Analizando bolsa: 107
# Analizando bolsa: 108
# Analizando bolsa: 109
# Analizando bolsa: 110
# Analizando bolsa: 111
# Analizando bolsa: 112
# Analizando bolsa: 113
# Analizando bolsa: 114
# Analizando bolsa: 115
# Analizando bolsa: 116
# Analizando bolsa: 117
# Analizando bolsa: 118
# Analizando bolsa: 119
# Analizando bolsa: 120
# Analizando bolsa: 121
# Analizando bolsa: 122
# Analizando bolsa: 123
# Analizando bolsa: 124
# Analizando bolsa: 125
# Analizando bolsa: 126
# Analizando bolsa: 127
# Analizando bolsa: 128
# Analizando bolsa: 129
# Analizando bolsa: 130
# Analizando bolsa: 131
# Analizando bolsa: 132
# Analizando bolsa: 133
# Analizando bolsa: 134
# Analizando bolsa: 135
# Analizando bolsa: 136
# Analizando bolsa: 137
# Analizando bolsa: 138
# Analizando bolsa: 139
# Analizando bolsa: 140
# Analizando bolsa: 141
# Analizando bolsa: 142
# Analizando bolsa: 143
# Analizando bolsa: 144
# Analizando bolsa: 145
# Analizando bolsa: 146
# Analizando bolsa: 147
# Analizando bolsa: 148
# Analizando bolsa: 149
# Analizando bolsa: 150
# Analizando bolsa: 151
# Analizando bolsa: 152
# Analizando bolsa: 153
# Analizando bolsa: 154
# Analizando bolsa: 155
# Analizando bolsa: 156
# Analizando bolsa: 157
# Analizando bolsa: 158
# Analizando bolsa: 159
# Analizando bolsa: 160
# Analizando bolsa: 161
# Analizando bolsa: 162
# Analizando bolsa: 163
# Analizando bolsa: 164
# Analizando bolsa: 165
# Analizando bolsa: 166
# Analizando bolsa: 167
# Analizando bolsa: 168
# Analizando bolsa: 169
# Analizando bolsa: 170
# Analizando bolsa: 171
# Analizando bolsa: 172
# Analizando bolsa: 173
# Analizando bolsa: 174
# Analizando bolsa: 175
# Analizando bolsa: 176
# Analizando bolsa: 177
# Analizando bolsa: 178
# Analizando bolsa: 179
# Analizando bolsa: 180
# Analizando bolsa: 181
# Analizando bolsa: 182
# Analizando bolsa: 183
# Analizando bolsa: 184
# Analizando bolsa: 185
# Analizando bolsa: 186
# Analizando bolsa: 187
# Analizando bolsa: 188
# Analizando bolsa: 189
# Analizando bolsa: 190
# Analizando bolsa: 191
# Analizando bolsa: 192
# Analizando bolsa: 193
# Analizando bolsa: 194
# Analizando bolsa: 195
# Analizando bolsa: 196
# Analizando bolsa: 197
# Analizando bolsa: 198
# Analizando bolsa: 199
# Analizando bolsa: 200
# Analizando bolsa: 201
# Analizando bolsa: 202
# Analizando bolsa: 203
# Analizando bolsa: 204
# Analizando bolsa: 205
# Analizando bolsa: 206
# Analizando bolsa: 207
# Analizando bolsa: 208
# Analizando bolsa: 209
# Analizando bolsa: 210
# Analizando bolsa: 211
# Analizando bolsa: 212
# Analizando bolsa: 213
# Analizando bolsa: 214
# Analizando bolsa: 215
# Analizando bolsa: 216
# Analizando bolsa: 217
# Analizando bolsa: 218
# Analizando bolsa: 219
# Analizando bolsa: 220
# Analizando bolsa: 221
# Analizando bolsa: 222
# Analizando bolsa: 223
# Analizando bolsa: 224
# Analizando bolsa: 225
# Analizando bolsa: 226
# Analizando bolsa: 227
# Analizando bolsa: 228
# Analizando bolsa: 229
# Analizando bolsa: 230
# Analizando bolsa: 231
# Analizando bolsa: 232
# Analizando bolsa: 233
# Analizando bolsa: 234
# Analizando bolsa: 235
# Analizando bolsa: 236
# Analizando bolsa: 237
# Analizando bolsa: 238
# Analizando bolsa: 239
# Analizando bolsa: 240
# Analizando bolsa: 241
# Analizando bolsa: 242
# Analizando bolsa: 243
# Analizando bolsa: 244
# Analizando bolsa: 245
# Analizando bolsa: 246
# Analizando bolsa: 247
# Analizando bolsa: 248
# Analizando bolsa: 249
# Analizando bolsa: 250
# Analizando bolsa: 251
# Analizando bolsa: 252
# Analizando bolsa: 253
# Analizando bolsa: 254
# Analizando bolsa: 255
# Analizando bolsa: 256
# Analizando bolsa: 257
# Analizando bolsa: 258
# Analizando bolsa: 259
# Analizando bolsa: 260
# Analizando bolsa: 261
# Analizando bolsa: 262
# Analizando bolsa: 263
# Analizando bolsa: 264
# Analizando bolsa: 265
# Analizando bolsa: 266
# Analizando bolsa: 267
# Analizando bolsa: 268
# Analizando bolsa: 269
# Analizando bolsa: 270
# Analizando bolsa: 271
# Analizando bolsa: 272
# Analizando bolsa: 273
# Analizando bolsa: 274
# Analizando bolsa: 275
# Analizando bolsa: 276
# Analizando bolsa: 277
# Analizando bolsa: 278
# Analizando bolsa: 279
# Analizando bolsa: 280
# Analizando bolsa: 281
# Analizando bolsa: 282
# Analizando bolsa: 283
# Analizando bolsa: 284
# Analizando bolsa: 285
# Analizando bolsa: 286
# Analizando bolsa: 287
# Analizando bolsa: 288
# Analizando bolsa: 289
# Analizando bolsa: 290
# Analizando bolsa: 291
# Analizando bolsa: 292
# Analizando bolsa: 293
# Analizando bolsa: 294
# Analizando bolsa: 295
# Analizando bolsa: 296
# Analizando bolsa: 297
# Analizando bolsa: 298
# Analizando bolsa: 299
# Analizando bolsa: 300
# Analizando bolsa: 301
# Analizando bolsa: 302
# Analizando bolsa: 303
# Analizando bolsa: 304
# Analizando bolsa: 305
# Analizando bolsa: 306
# Analizando bolsa: 307
# Analizando bolsa: 308
# Analizando bolsa: 309
# Analizando bolsa: 310
# Analizando bolsa: 311
# Analizando bolsa: 312
# Analizando bolsa: 313
# Analizando bolsa: 314
# Analizando bolsa: 315
# Analizando bolsa: 316
# Analizando bolsa: 317
# Analizando bolsa: 318
# Analizando bolsa: 319
# Analizando bolsa: 320
# Analizando bolsa: 321
# Analizando bolsa: 322
# Analizando bolsa: 323
# Analizando bolsa: 324
# Analizando bolsa: 325
# Analizando bolsa: 326
# Analizando bolsa: 327
# Analizando bolsa: 328
# Analizando bolsa: 329
# Analizando bolsa: 330
# Analizando bolsa: 331
# Analizando bolsa: 332
# Analizando bolsa: 333
# Analizando bolsa: 334
# Analizando bolsa: 335
# Analizando bolsa: 336
# Analizando bolsa: 337
# Analizando bolsa: 338
# Analizando bolsa: 339
# Analizando bolsa: 340
# Analizando bolsa: 341
# Analizando bolsa: 342
# Analizando bolsa: 343
# Analizando bolsa: 344
# Analizando bolsa: 345
# Analizando bolsa: 346
# Analizando bolsa: 347
# Analizando bolsa: 348
# Analizando bolsa: 349
# Analizando bolsa: 350
# Analizando bolsa: 351
# Analizando bolsa: 352
# Analizando bolsa: 353
# Analizando bolsa: 354
# Analizando bolsa: 355
# Analizando bolsa: 356
# Analizando bolsa: 357
# Analizando bolsa: 358
# Analizando bolsa: 359
# Analizando bolsa: 360
# Analizando bolsa: 361
# Analizando bolsa: 362
# Analizando bolsa: 363
# Analizando bolsa: 364
# Analizando bolsa: 365
# Analizando bolsa: 366
# Analizando bolsa: 367
# Analizando bolsa: 368
# Analizando bolsa: 369
# Analizando bolsa: 370
# Analizando bolsa: 371
# Analizando bolsa: 372
# Analizando bolsa: 373
# Analizando bolsa: 374
# Analizando bolsa: 375
# Analizando bolsa: 376
# Analizando bolsa: 377
# Analizando bolsa: 378
# Analizando bolsa: 379
# Analizando bolsa: 380
# Analizando bolsa: 381
# Analizando bolsa: 382
# Analizando bolsa: 383
# Analizando bolsa: 384
# Analizando bolsa: 385
# Analizando bolsa: 386
# Analizando bolsa: 387
# Analizando bolsa: 388
# Analizando bolsa: 389
# Analizando bolsa: 390
# Analizando bolsa: 391
# Analizando bolsa: 392
# Analizando bolsa: 393
# Analizando bolsa: 394
# Analizando bolsa: 395
# Analizando bolsa: 396
# Analizando bolsa: 397
# Analizando bolsa: 398
# Analizando bolsa: 399
# Analizando bolsa: 400
# Analizando bolsa: 401
# Analizando bolsa: 402
# Analizando bolsa: 403
# Analizando bolsa: 404
# Analizando bolsa: 405
# Analizando bolsa: 406
# Analizando bolsa: 407
# Analizando bolsa: 408
# Analizando bolsa: 409
# Analizando bolsa: 410
# Analizando bolsa: 411
# Analizando bolsa: 412
# Analizando bolsa: 413
# Analizando bolsa: 414
# Analizando bolsa: 415
# Analizando bolsa: 416
# Analizando bolsa: 417
# Analizando bolsa: 418
# Analizando bolsa: 419
# Analizando bolsa: 420
# Analizando bolsa: 421
# Analizando bolsa: 422
# Analizando bolsa: 423
# Analizando bolsa: 424
# Analizando bolsa: 425
# Analizando bolsa: 426
# Analizando bolsa: 427
# Analizando bolsa: 428
# Analizando bolsa: 429
# Analizando bolsa: 430
# Analizando bolsa: 431
# Analizando bolsa: 432
# Analizando bolsa: 433
# Analizando bolsa: 434
# Analizando bolsa: 435
# Analizando bolsa: 436
# Analizando bolsa: 437
# Analizando bolsa: 438
# Analizando bolsa: 439
# Analizando bolsa: 440
# Analizando bolsa: 441
# Analizando bolsa: 442
# Analizando bolsa: 443
# Analizando bolsa: 444
# Analizando bolsa: 445
# Analizando bolsa: 446
# Analizando bolsa: 447
# Analizando bolsa: 448
# Analizando bolsa: 449
# Analizando bolsa: 450
# Analizando bolsa: 451
# Analizando bolsa: 452
# Analizando bolsa: 453
# Analizando bolsa: 454
# Analizando bolsa: 455
# Analizando bolsa: 456
# Analizando bolsa: 457
# Analizando bolsa: 458
# Analizando bolsa: 459
# Analizando bolsa: 460
# Analizando bolsa: 461
# Analizando bolsa: 462
# Analizando bolsa: 463
# Analizando bolsa: 464
# Analizando bolsa: 465
# Analizando bolsa: 466
# Analizando bolsa: 467
# Analizando bolsa: 468
# Analizando bolsa: 469
# Analizando bolsa: 470
# Analizando bolsa: 471
# Analizando bolsa: 472
# Analizando bolsa: 473
# Analizando bolsa: 474
# Analizando bolsa: 475
# Analizando bolsa: 476
# Analizando bolsa: 477
# Analizando bolsa: 478
# Analizando bolsa: 479
# Analizando bolsa: 480
# Analizando bolsa: 481
# Analizando bolsa: 482
# Analizando bolsa: 483
# Analizando bolsa: 484
# Analizando bolsa: 485
# Analizando bolsa: 486
# Analizando bolsa: 487
# Analizando bolsa: 488
# Analizando bolsa: 489
# Analizando bolsa: 490
# Analizando bolsa: 491
# Analizando bolsa: 492
# Analizando bolsa: 493
# Analizando bolsa: 494
# Analizando bolsa: 495
# Analizando bolsa: 496
# Analizando bolsa: 497
# Analizando bolsa: 498
# Analizando bolsa: 499
# Analizando bolsa: 500
# Analizando bolsa: 501
# Analizando bolsa: 502
# Analizando bolsa: 503
# Analizando bolsa: 504
# Analizando bolsa: 505
# Analizando bolsa: 506
# Analizando bolsa: 507
# Analizando bolsa: 508
# Analizando bolsa: 509
# Analizando bolsa: 510
# Analizando bolsa: 511
# Analizando bolsa: 512
# Analizando bolsa: 513
# Analizando bolsa: 514
# Analizando bolsa: 515
# Analizando bolsa: 516
# Analizando bolsa: 517
# Analizando bolsa: 518
# Analizando bolsa: 519
# Analizando bolsa: 520
# Analizando bolsa: 521
# Analizando bolsa: 522
# Analizando bolsa: 523
# Analizando bolsa: 524
# Analizando bolsa: 525
# Analizando bolsa: 526
# Analizando bolsa: 527
# Analizando bolsa: 528
# Analizando bolsa: 529
# Analizando bolsa: 530
# Analizando bolsa: 531
# Analizando bolsa: 532
# Analizando bolsa: 533
# Analizando bolsa: 534
# Analizando bolsa: 535
# Analizando bolsa: 536
# Analizando bolsa: 537
# Analizando bolsa: 538
# Analizando bolsa: 539
# Analizando bolsa: 540
# Analizando bolsa: 541
# Analizando bolsa: 542
# Analizando bolsa: 543
# Analizando bolsa: 544
# Analizando bolsa: 545
# Analizando bolsa: 546
# Analizando bolsa: 547
# Analizando bolsa: 548
# Analizando bolsa: 549
# Analizando bolsa: 550
# Analizando bolsa: 551
# Analizando bolsa: 552
# Analizando bolsa: 553
# Analizando bolsa: 554
# Analizando bolsa: 555
# Analizando bolsa: 556
# Analizando bolsa: 557
# Analizando bolsa: 558
# Analizando bolsa: 559
# Analizando bolsa: 560
# Analizando bolsa: 561
# Analizando bolsa: 562
# Analizando bolsa: 563
# Analizando bolsa: 564
# Analizando bolsa: 565
# Analizando bolsa: 566
# Analizando bolsa: 567
# Analizando bolsa: 568
# Analizando bolsa: 569
# Analizando bolsa: 570
# Analizando bolsa: 571
# Analizando bolsa: 572
# Analizando bolsa: 573
# Analizando bolsa: 574
# Analizando bolsa: 575
# Analizando bolsa: 576
# Analizando bolsa: 577
# Analizando bolsa: 578
# Analizando bolsa: 579
# Analizando bolsa: 580
# Analizando bolsa: 581
# Analizando bolsa: 582
# Analizando bolsa: 583
# Analizando bolsa: 584
# Analizando bolsa: 585
# Analizando bolsa: 586
# Analizando bolsa: 587
# Analizando bolsa: 588
# Analizando bolsa: 589
# Analizando bolsa: 590
# Analizando bolsa: 591
# Analizando bolsa: 592
# Analizando bolsa: 593
# Analizando bolsa: 594
# Analizando bolsa: 595
# Analizando bolsa: 596
# Analizando bolsa: 597
# Analizando bolsa: 598
# Analizando bolsa: 599
# Analizando bolsa: 600
# Analizando bolsa: 601
# Analizando bolsa: 602
# Analizando bolsa: 603
# Analizando bolsa: 604
# Analizando bolsa: 605
# Analizando bolsa: 606
# Analizando bolsa: 607
# Analizando bolsa: 608
# Analizando bolsa: 609
# Analizando bolsa: 610
# Analizando bolsa: 611
# Analizando bolsa: 612
# Analizando bolsa: 613
# Analizando bolsa: 614
# Analizando bolsa: 615
# Analizando bolsa: 616
# Analizando bolsa: 617
# Analizando bolsa: 618
# Analizando bolsa: 619
# Analizando bolsa: 620
# Analizando bolsa: 621
# Analizando bolsa: 622
# Analizando bolsa: 623
# Analizando bolsa: 624
# Analizando bolsa: 625
# Analizando bolsa: 626
# Analizando bolsa: 627
# Analizando bolsa: 628
# Analizando bolsa: 629
# Analizando bolsa: 630
# Analizando bolsa: 631
# Analizando bolsa: 632
# Analizando bolsa: 633
# Analizando bolsa: 634
# Analizando bolsa: 635
# Analizando bolsa: 636
# Analizando bolsa: 637
# Analizando bolsa: 638
# Analizando bolsa: 639
# Analizando bolsa: 640
# Analizando bolsa: 641
# Analizando bolsa: 642
# Analizando bolsa: 643
# Analizando bolsa: 644
# Analizando bolsa: 645
# Analizando bolsa: 646
# Analizando bolsa: 647
# Analizando bolsa: 648
# Analizando bolsa: 649
# Analizando bolsa: 650
# Analizando bolsa: 651
# Analizando bolsa: 652
# Analizando bolsa: 653
# Analizando bolsa: 654
# Analizando bolsa: 655
# Analizando bolsa: 656
# Analizando bolsa: 657
# Analizando bolsa: 658
# Analizando bolsa: 659
# Analizando bolsa: 660
# Analizando bolsa: 661
# Analizando bolsa: 662
# Analizando bolsa: 663
# Analizando bolsa: 664
# Analizando bolsa: 665
# Analizando bolsa: 666
# Analizando bolsa: 667
# Analizando bolsa: 668
# Analizando bolsa: 669
# Analizando bolsa: 670
# Analizando bolsa: 671
# Analizando bolsa: 672
# Analizando bolsa: 673
# Analizando bolsa: 674
# Analizando bolsa: 675
# Analizando bolsa: 676
# Analizando bolsa: 677
# Analizando bolsa: 678
# Analizando bolsa: 679
# Analizando bolsa: 680
# Analizando bolsa: 681
# Analizando bolsa: 682
# Analizando bolsa: 683
# Analizando bolsa: 684
# Analizando bolsa: 685
# Analizando bolsa: 686
# Analizando bolsa: 687
# Analizando bolsa: 688
# Analizando bolsa: 689
# Analizando bolsa: 690
# Analizando bolsa: 691
# Analizando bolsa: 692
# Analizando bolsa: 693
# Analizando bolsa: 694
# Analizando bolsa: 695
# Analizando bolsa: 696
# Analizando bolsa: 697
# Analizando bolsa: 698
# Analizando bolsa: 699
# Analizando bolsa: 700
# Analizando bolsa: 701
# Analizando bolsa: 702
# Analizando bolsa: 703
# Analizando bolsa: 704
# Analizando bolsa: 705
# Analizando bolsa: 706
# Analizando bolsa: 707
# Analizando bolsa: 708
# Analizando bolsa: 709
# Analizando bolsa: 710
# Analizando bolsa: 711
# Analizando bolsa: 712
# Analizando bolsa: 713
# Analizando bolsa: 714
# Analizando bolsa: 715
# Analizando bolsa: 716
# Analizando bolsa: 717
# Analizando bolsa: 718
# Analizando bolsa: 719
# Analizando bolsa: 720
# Analizando bolsa: 721
# Analizando bolsa: 722
# Analizando bolsa: 723
# Analizando bolsa: 724
# Analizando bolsa: 725
# Analizando bolsa: 726
# Analizando bolsa: 727
# Analizando bolsa: 728
# Analizando bolsa: 729
# Analizando bolsa: 730
# Analizando bolsa: 731
# Analizando bolsa: 732
# Analizando bolsa: 733
# Analizando bolsa: 734
# Analizando bolsa: 735
# Analizando bolsa: 736
# Analizando bolsa: 737
# Analizando bolsa: 738
# Analizando bolsa: 739
# Analizando bolsa: 740
# Analizando bolsa: 741
# Analizando bolsa: 742
# Analizando bolsa: 743
# Analizando bolsa: 744
# Analizando bolsa: 745
# Analizando bolsa: 746
# Analizando bolsa: 747
# Analizando bolsa: 748
# Analizando bolsa: 749
# Analizando bolsa: 750
# Analizando bolsa: 751
# Analizando bolsa: 752
# Analizando bolsa: 753
# Analizando bolsa: 754
# Analizando bolsa: 755
# Analizando bolsa: 756
# Analizando bolsa: 757
# Analizando bolsa: 758
# Analizando bolsa: 759
# Analizando bolsa: 760
# Analizando bolsa: 761
# Analizando bolsa: 762
# Analizando bolsa: 763
# Analizando bolsa: 764
# Analizando bolsa: 765
# Analizando bolsa: 766
# Analizando bolsa: 767
# Analizando bolsa: 768
# Analizando bolsa: 769
# Analizando bolsa: 770
# Analizando bolsa: 771
# Analizando bolsa: 772
# Analizando bolsa: 773
# Analizando bolsa: 774
# Analizando bolsa: 775
# Analizando bolsa: 776
# Analizando bolsa: 777
# Analizando bolsa: 778
# Analizando bolsa: 779
# Analizando bolsa: 780
# Analizando bolsa: 781
# Analizando bolsa: 782
# Analizando bolsa: 783
# Analizando bolsa: 784
# Analizando bolsa: 785
# Analizando bolsa: 786
# Analizando bolsa: 787
# Analizando bolsa: 788
# Analizando bolsa: 789
# Analizando bolsa: 790
# Analizando bolsa: 791
# Analizando bolsa: 792
# Analizando bolsa: 793
# Analizando bolsa: 794
# Analizando bolsa: 795
# Analizando bolsa: 796
# Analizando bolsa: 797
# Analizando bolsa: 798
# Analizando bolsa: 799
# Analizando bolsa: 800
# Analizando bolsa: 801
# Analizando bolsa: 802
# Analizando bolsa: 803
# Analizando bolsa: 804
# Analizando bolsa: 805
# Analizando bolsa: 806
# Analizando bolsa: 807
# Analizando bolsa: 808
# Analizando bolsa: 809
# Analizando bolsa: 810
# Analizando bolsa: 811
# Analizando bolsa: 812
# Analizando bolsa: 813
# Analizando bolsa: 814
# Analizando bolsa: 815
# Analizando bolsa: 816
# Analizando bolsa: 817
# Analizando bolsa: 818
# Analizando bolsa: 819
# Analizando bolsa: 820
# Analizando bolsa: 821
# Analizando bolsa: 822
# Analizando bolsa: 823
# Analizando bolsa: 824
# Analizando bolsa: 825
# Analizando bolsa: 826
# Analizando bolsa: 827
# Analizando bolsa: 828
# Analizando bolsa: 829
# Analizando bolsa: 830
# Analizando bolsa: 831
# Analizando bolsa: 832
# Analizando bolsa: 833
# Analizando bolsa: 834
# Analizando bolsa: 835
# Analizando bolsa: 836
# Analizando bolsa: 837
# Analizando bolsa: 838
# Analizando bolsa: 839
# Analizando bolsa: 840
# Analizando bolsa: 841
# Analizando bolsa: 842
# Analizando bolsa: 843
# Analizando bolsa: 844
# Analizando bolsa: 845
# Analizando bolsa: 846
# Analizando bolsa: 847
# Analizando bolsa: 848
# Analizando bolsa: 849
# Analizando bolsa: 850
# Analizando bolsa: 851
# Analizando bolsa: 852
# Analizando bolsa: 853
# Analizando bolsa: 854
# Analizando bolsa: 855
# Analizando bolsa: 856
# Analizando bolsa: 857
# Analizando bolsa: 858
# Analizando bolsa: 859
# Analizando bolsa: 860
# Analizando bolsa: 861
# Analizando bolsa: 862
# Analizando bolsa: 863
# Analizando bolsa: 864
# Analizando bolsa: 865
# Analizando bolsa: 866
# Analizando bolsa: 867
# Analizando bolsa: 868
# Analizando bolsa: 869
# Analizando bolsa: 870
# Analizando bolsa: 871
# Analizando bolsa: 872
# Analizando bolsa: 873
# Analizando bolsa: 874
# Analizando bolsa: 875
# Analizando bolsa: 876
# Analizando bolsa: 877
# Analizando bolsa: 878
# Analizando bolsa: 879
# Analizando bolsa: 880
# Analizando bolsa: 881
# Analizando bolsa: 882
# Analizando bolsa: 883
# Analizando bolsa: 884
# Analizando bolsa: 885
# Analizando bolsa: 886
# Analizando bolsa: 887
# Analizando bolsa: 888
# Analizando bolsa: 889
# Analizando bolsa: 890
# Analizando bolsa: 891
# Analizando bolsa: 892
# Analizando bolsa: 893
# Analizando bolsa: 894
# Analizando bolsa: 895
# Analizando bolsa: 896
# Analizando bolsa: 897
# Analizando bolsa: 898
# Analizando bolsa: 899
# Analizando bolsa: 900
# Analizando bolsa: 901
# Analizando bolsa: 902
# Analizando bolsa: 903
# Analizando bolsa: 904
# Analizando bolsa: 905
# Analizando bolsa: 906
# Analizando bolsa: 907
# Analizando bolsa: 908
# Analizando bolsa: 909
# Analizando bolsa: 910
# Analizando bolsa: 911
# Analizando bolsa: 912
# Analizando bolsa: 913
# Analizando bolsa: 914
# Analizando bolsa: 915
# Analizando bolsa: 916
# Analizando bolsa: 917
# Analizando bolsa: 918
# Analizando bolsa: 919
# Analizando bolsa: 920
# Analizando bolsa: 921
# Analizando bolsa: 922
# Analizando bolsa: 923
# Analizando bolsa: 924
# Analizando bolsa: 925
# Analizando bolsa: 926
# Analizando bolsa: 927
# Analizando bolsa: 928
# Analizando bolsa: 929
# Analizando bolsa: 930
# Analizando bolsa: 931
# Analizando bolsa: 932
# Analizando bolsa: 933
# Analizando bolsa: 934
# Analizando bolsa: 935
# Analizando bolsa: 936
# Analizando bolsa: 937
# Analizando bolsa: 938
# Analizando bolsa: 939
# Analizando bolsa: 940
# Analizando bolsa: 941
# Analizando bolsa: 942
# Analizando bolsa: 943
# Analizando bolsa: 944
# Analizando bolsa: 945
# Analizando bolsa: 946
# Analizando bolsa: 947
# Analizando bolsa: 948
# Analizando bolsa: 949
# Analizando bolsa: 950
# Analizando bolsa: 951
# Analizando bolsa: 952
# Analizando bolsa: 953
# Analizando bolsa: 954
# Analizando bolsa: 955
# Analizando bolsa: 956
# Analizando bolsa: 957
# Analizando bolsa: 958
# Analizando bolsa: 959
# Analizando bolsa: 960
# Analizando bolsa: 961
# Analizando bolsa: 962
# Analizando bolsa: 963
# Analizando bolsa: 964
# Analizando bolsa: 965
# Analizando bolsa: 966
# Analizando bolsa: 967
# Analizando bolsa: 968
# Analizando bolsa: 969
# Analizando bolsa: 970
# Analizando bolsa: 971
# Analizando bolsa: 972
# Analizando bolsa: 973
# Analizando bolsa: 974
# Analizando bolsa: 975
# Analizando bolsa: 976
# Analizando bolsa: 977
# Analizando bolsa: 978
# Analizando bolsa: 979
# Analizando bolsa: 980
# Analizando bolsa: 981
# Analizando bolsa: 982
# Analizando bolsa: 983
# Analizando bolsa: 984
# Analizando bolsa: 985
# Analizando bolsa: 986
# Analizando bolsa: 987
# Analizando bolsa: 988
# Analizando bolsa: 989
# Analizando bolsa: 990
# Analizando bolsa: 991
# Analizando bolsa: 992
# Analizando bolsa: 993
# Analizando bolsa: 994
# Analizando bolsa: 995
# Analizando bolsa: 996
# Analizando bolsa: 997
# Analizando bolsa: 998
# Analizando bolsa: 999
# Analizando bolsa: 1000
# Analizando bolsa: 1001
# Analizando bolsa: 1002
# Analizando bolsa: 1003
# Analizando bolsa: 1004
# Analizando bolsa: 1005
# Analizando bolsa: 1006
# Analizando bolsa: 1007
# Analizando bolsa: 1008
# Analizando bolsa: 1009
# Analizando bolsa: 1010
# Analizando bolsa: 1011
# Analizando bolsa: 1012
# Analizando bolsa: 1013
# Analizando bolsa: 1014
# Analizando bolsa: 1015
# Analizando bolsa: 1016
# Analizando bolsa: 1017
# Analizando bolsa: 1018
# Analizando bolsa: 1019
# Analizando bolsa: 1020
# Analizando bolsa: 1021
# Analizando bolsa: 1022
# Analizando bolsa: 1023
# Analizando bolsa: 1024
# Analizando bolsa: 1025
# Analizando bolsa: 1026
# Analizando bolsa: 1027
# Analizando bolsa: 1028
# Analizando bolsa: 1029
# Analizando bolsa: 1030
# Analizando bolsa: 1031
# Analizando bolsa: 1032
# Analizando bolsa: 1033
# Analizando bolsa: 1034
# Analizando bolsa: 1035
# Analizando bolsa: 1036
# Analizando bolsa: 1037
# Analizando bolsa: 1038
# Analizando bolsa: 1039
# Analizando bolsa: 1040
# Analizando bolsa: 1041
# Analizando bolsa: 1042
# Analizando bolsa: 1043
# Analizando bolsa: 1044
# Analizando bolsa: 1045
# Analizando bolsa: 1046
# Analizando bolsa: 1047
# Analizando bolsa: 1048
# Analizando bolsa: 1049
# Analizando bolsa: 1050
# Analizando bolsa: 1051
# Analizando bolsa: 1052
# Analizando bolsa: 1053
# Analizando bolsa: 1054
# Analizando bolsa: 1055
# Analizando bolsa: 1056
# Analizando bolsa: 1057
# Analizando bolsa: 1058
# Analizando bolsa: 1059
# Analizando bolsa: 1060
# Analizando bolsa: 1061
# Analizando bolsa: 1062
# Analizando bolsa: 1063
# Analizando bolsa: 1064
# Analizando bolsa: 1065
# Analizando bolsa: 1066
# Analizando bolsa: 1067
# Analizando bolsa: 1068
# Analizando bolsa: 1069
# Analizando bolsa: 1070
# Analizando bolsa: 1071
# Analizando bolsa: 1072
# Analizando bolsa: 1073
# Analizando bolsa: 1074
# Analizando bolsa: 1075
# Analizando bolsa: 1076
# Analizando bolsa: 1077
# Analizando bolsa: 1078
# Analizando bolsa: 1079
# Analizando bolsa: 1080
# Analizando bolsa: 1081
# Analizando bolsa: 1082
# Analizando bolsa: 1083
# Analizando bolsa: 1084
# Analizando bolsa: 1085
# Analizando bolsa: 1086
# Analizando bolsa: 1087
# Analizando bolsa: 1088
# Analizando bolsa: 1089
# Analizando bolsa: 1090
# Analizando bolsa: 1091
# Analizando bolsa: 1092
# Analizando bolsa: 1093
# Analizando bolsa: 1094
# Analizando bolsa: 1095
# Analizando bolsa: 1096
# Analizando bolsa: 1097
# Analizando bolsa: 1098
# Analizando bolsa: 1099
# Analizando bolsa: 1100
# Analizando bolsa: 1101
# Analizando bolsa: 1102
# Analizando bolsa: 1103
# Analizando bolsa: 1104
# Analizando bolsa: 1105
# Analizando bolsa: 1106
# Analizando bolsa: 1107
# Analizando bolsa: 1108
# Analizando bolsa: 1109
# Analizando bolsa: 1110
# Analizando bolsa: 1111
# Analizando bolsa: 1112
# Analizando bolsa: 1113
# Analizando bolsa: 1114
# Analizando bolsa: 1115
# Analizando bolsa: 1116
# Analizando bolsa: 1117
# Analizando bolsa: 1118
# Analizando bolsa: 1119
# Analizando bolsa: 1120
# Analizando bolsa: 1121
# Analizando bolsa: 1122
# Analizando bolsa: 1123
# Analizando bolsa: 1124
# Analizando bolsa: 1125
# Analizando bolsa: 1126
# Analizando bolsa: 1127
# Analizando bolsa: 1128
# Analizando bolsa: 1129
# Analizando bolsa: 1130
# Analizando bolsa: 1131
# Analizando bolsa: 1132
# Analizando bolsa: 1133
# Analizando bolsa: 1134
# Analizando bolsa: 1135
# Analizando bolsa: 1136
# Analizando bolsa: 1137
# Analizando bolsa: 1138
# Analizando bolsa: 1139
# Analizando bolsa: 1140
# Analizando bolsa: 1141
# Analizando bolsa: 1142
# Analizando bolsa: 1143
# Analizando bolsa: 1144
# Analizando bolsa: 1145
# Analizando bolsa: 1146
# Analizando bolsa: 1147
# Analizando bolsa: 1148
# Analizando bolsa: 1149
# Analizando bolsa: 1150
# Analizando bolsa: 1151
# Analizando bolsa: 1152
# Analizando bolsa: 1153
# Analizando bolsa: 1154
# Analizando bolsa: 1155
# Analizando bolsa: 1156
# Analizando bolsa: 1157
# Analizando bolsa: 1158
# Analizando bolsa: 1159
# Analizando bolsa: 1160
# Analizando bolsa: 1161
# Analizando bolsa: 1162
# Analizando bolsa: 1163
# Analizando bolsa: 1164
# Analizando bolsa: 1165
# Analizando bolsa: 1166
# Analizando bolsa: 1167
# Analizando bolsa: 1168
# Analizando bolsa: 1169
# Analizando bolsa: 1170
# Analizando bolsa: 1171
# Analizando bolsa: 1172
# Analizando bolsa: 1173
# Analizando bolsa: 1174
# Analizando bolsa: 1175
# Analizando bolsa: 1176
# Analizando bolsa: 1177
# Analizando bolsa: 1178
# Analizando bolsa: 1179
# Analizando bolsa: 1180
# Analizando bolsa: 1181
# Analizando bolsa: 1182
# Analizando bolsa: 1183
# Analizando bolsa: 1184
# Analizando bolsa: 1185
# Analizando bolsa: 1186
# Analizando bolsa: 1187
# Analizando bolsa: 1188
# Analizando bolsa: 1189
# Analizando bolsa: 1190
# Analizando bolsa: 1191
# Analizando bolsa: 1192
# Analizando bolsa: 1193
# Analizando bolsa: 1194
# Analizando bolsa: 1195
# Analizando bolsa: 1196
# Analizando bolsa: 1197
# Analizando bolsa: 1198
# Analizando bolsa: 1199
# Analizando bolsa: 1200
# Analizando bolsa: 1201
# Analizando bolsa: 1202
# Analizando bolsa: 1203
# Analizando bolsa: 1204
# Analizando bolsa: 1205
# Analizando bolsa: 1206
# Analizando bolsa: 1207
# Analizando bolsa: 1208
# Analizando bolsa: 1209
# Analizando bolsa: 1210
# Analizando bolsa: 1211
# Analizando bolsa: 1212
# Analizando bolsa: 1213
# Analizando bolsa: 1214
# Analizando bolsa: 1215
# Analizando bolsa: 1216
# Analizando bolsa: 1217
# Analizando bolsa: 1218
# Analizando bolsa: 1219
# Analizando bolsa: 1220
# Analizando bolsa: 1221
# Analizando bolsa: 1222
# Analizando bolsa: 1223
# Analizando bolsa: 1224
# Analizando bolsa: 1225
# Analizando bolsa: 1226
# Analizando bolsa: 1227
# Analizando bolsa: 1228
# Analizando bolsa: 1229
# Analizando bolsa: 1230
# Analizando bolsa: 1231
# Analizando bolsa: 1232
# Analizando bolsa: 1233
# Analizando bolsa: 1234
# Analizando bolsa: 1235
# Analizando bolsa: 1236
# Analizando bolsa: 1237
# Analizando bolsa: 1238
# Analizando bolsa: 1239
# Analizando bolsa: 1240
# Analizando bolsa: 1241
# Analizando bolsa: 1242
# Analizando bolsa: 1243
# Analizando bolsa: 1244
# Analizando bolsa: 1245
# Analizando bolsa: 1246
# Analizando bolsa: 1247
# Analizando bolsa: 1248
# Analizando bolsa: 1249
# Analizando bolsa: 1250
# Analizando bolsa: 1251
# Analizando bolsa: 1252
# Analizando bolsa: 1253
# Analizando bolsa: 1254
# Analizando bolsa: 1255
# Analizando bolsa: 1256
# Analizando bolsa: 1257
# Analizando bolsa: 1258
# Analizando bolsa: 1259
# Analizando bolsa: 1260
# Analizando bolsa: 1261
# Analizando bolsa: 1262
# Analizando bolsa: 1263
# Analizando bolsa: 1264
# Analizando bolsa: 1265
# Analizando bolsa: 1266
# Analizando bolsa: 1267
# Analizando bolsa: 1268
# Analizando bolsa: 1269
# Analizando bolsa: 1270
# Analizando bolsa: 1271
# Analizando bolsa: 1272
# Analizando bolsa: 1273
# Analizando bolsa: 1274
# Analizando bolsa: 1275
# Analizando bolsa: 1276
# Analizando bolsa: 1277
# Analizando bolsa: 1278

# %% [markdown]
# ---
#
# Generando una consulta para el conjunto de validación
#
# ---

# %%
new_consulta = random.randint(0,len(bolsas_validacion)-1)
new_img_cons = Lista_Val[new_consulta]

# %%
print(f"La imagen de consulta es: {new_img_cons}")
obten_imagen(new_img_cons)
# Out:
# La imagen de consulta es: paris_museedorsay_000275

# %%
new_consulta = bolsas_validacion[new_consulta]

# %%
Parecidos = ifs_validacion.recupera(new_consulta)

# %%
mayor = Parecidos.most_common()[1]

# %%
Index_inv_img = Lista_Val[mayor[0]]

# %%
print(f"La imagen con mayor parecido por índice inverso es: {Index_inv_img}")
obten_imagen(Index_inv_img)
# Out:
# La imagen con mayor parecido por índice inverso es: paris_general_002626

# %%
Res = []
comunes = Parecidos.most_common()[1:]#Nuevamente desechamos el primer valor 
print(len(comunes))
k=0
for (_,i) in comunes:
  k+=1
  if i > 2:
    Res.append(comunes[k])
# Out:
# 952

# %%
len(Res)
# Out:
# 368

# %%
Maximos = Evalua_distancias(new_consulta,Res,bolsas_validacion)

# %%
Maximos
# Out:
# [(302, 0.2286453839516825),
#  (207, 0.7518586136732927),
#  (282, 0.5066834264492734)]

# %%
max_dist(new_img_cons,'Coseno',Maximos[0],Lista_Val,Res)
# Out:
# Se evaluó la imagen: paris_museedorsay_000275
#
# La mayor coincidencia en similitud de Coseno fue: paris_notredame_000665
# con un resultado de: 0.2286453839516825

# %%
max_dist(new_img_cons,'Jaccard',Maximos[1],Lista_Val,Res)
# Out:
# Se evaluó la imagen: paris_museedorsay_000275
#
# La mayor coincidencia en similitud de Jaccard fue: paris_notredame_000272
# con un resultado de: 0.7518586136732927

# %%
max_dist(new_img_cons,'MinMax',Maximos[2],Lista_Val,Res)
# Out:
# Se evaluó la imagen: paris_museedorsay_000275
#
# La mayor coincidencia en similitud de MinMax fue: paris_pompidou_000611
# con un resultado de: 0.5066834264492734

# %% [markdown]
# ---
#
# Sigue sin convencerme el desempeño del buscador... :$
#
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanMartignon/LicenciaturaCienciaDeDatos/blob/main/MineriaAvanzadaII/Proyecto_final_100_epocas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto: Conteo por audio (Basado en redes convolucionales y espectogramas)
#
# ## Integrantes:
# - Martiñón Luna Jonathan José
#
# ## Licenciatura en Ciencia de Datos
# ## Minería de Datos Avanzada
# ## Universidad Nacional Autónoma de México

# %% [markdown]
# ---
# # 1.) Librerías
# ---

# %%
#Google Drive
from google.colab import drive

#Tiempo de ejecucion
from time import time

# Graficos
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt

# DataFrames
import pandas as pd

# Arreglos multidimensionales
import numpy as np

# Reproducción de audio
from IPython.display import Audio

# Tensorflow
import tensorflow as tf
from tensorflow.keras import layers, models
   # Audio
try:  
  import tensorflow_io as tfio
except:
  # !pip install tensorflow-io
  import tensorflow_io as tfio

# %% [markdown]
# ---
# # 2.) Funciones
# ---

# %%
def presenta_onda_spect_y_audio(meta, conjunto="Entrenamiento",seed = 2209,
                                nfft=158, window=512, stride=400//2,
                                figsize = (12,6)):
  '''
  @Autor: Jonathan Martiñón

  @Descripción:   Función encargada de mostrar durante el análisis
                  un audio (dependiendo del conjunto seleccionado),
                  su forma y su espectograma.

  @Parámetros:

  meta            Conjunto de metadatos sobre el audio elegido  PANDAS.DATAFRAME

  conjunto        Conjunto del que se extraerá el audio         STR

  seed            Semilla para replicabilidad                   INT

  nfft            tamaño de la muestra                          INT

  window          tamaño de la ventana                          INT

  stride          Tamaño del salto entre ventanas               INT

  figsize         Tamaño del liezo (Figura) de matplotlib       TUPLE
  '''
  # Ajustamos la semilla de nuestro numpy
  np.random.seed(seed)

  if conjunto == "Entrenamiento":
    # Generamos un número aleatorio entre 0 y 100,000
    numero = np.random.randint(low=0,high=100000,dtype=int)
    # Generamos el nombre del audio
    name_audio = "Audio_Train"+str(numero)+".wav"

  elif conjunto == "Validacion":
    # Generamos un número aleatorio entre 0 y 10,000
    numero = np.random.randint(low=0,high=10000,dtype=int)
    # Generamos el nombre del audio
    name_audio = "Audio_Validation"+str(numero)+".wav" 

  else:
    # Generamos un número aleatorio entre 0 y 10,000
    numero = np.random.randint(low=0,high=10000,dtype=int)
    # Generamos el nombre del audio
    name_audio = "Audio_Test"+str(numero)+".wav"

  # Obtenemos la cantidad de hablantes
  hablantes = meta.loc[numero]['Speakers']

  dir_audio = "./Data/"+conjunto+"/"+name_audio 

  # Leemos el audio
  audio = tfio.audio.AudioIOTensor(dir_audio)
  # Convertimos a tensor
  audio_tensor = tf.squeeze(audio[:], axis=[-1])
  

  # Generamos nuestra forma de audio
  waveform = tf.cast(audio_tensor, tf.float32).numpy()

  # Generamos nuestro spectograma
  spectrogram_crud = tfio.audio.spectrogram(
      audio_tensor, nfft=nfft, window=window, stride=stride)
  # Convertimos a Decibeles
  spectrogram = tfio.audio.dbscale(spectrogram_crud, top_db=80)

  # Finalmente graficamos ambos casos
  plt.figure(figsize=figsize)

  # Para la forma de audio
  plt.subplot(1,2,1)
  plt.title(f"Forma de audio para el conjunto de: {conjunto}\nCon {hablantes} hablantes.")
  plt.plot(waveform,color = "orange")
  plt.yticks([])
  plt.xlabel("Tiempo")

  # Para el espectrograma
  plt.subplot(1,2,2)
  plt.title(f"Espectrograma del audio para el conjunto de: {conjunto}\nCon {hablantes} hablantes.\nShape: {spectrogram.shape}")
  plt.imshow(spectrogram)
  cbar = plt.colorbar(shrink=0.75)
  cbar.set_label('DB')
  plt.yticks([])
  plt.xlabel("Tiempo")

  plt.tight_layout()
  plt.show()

  # Reproductor del audio
  Audio(audio_tensor.numpy(), rate=audio.rate.numpy())

# %%
def genera_conjunto(conjunto = "Entrenamiento",num = 100000,
                    nfft=158, window=512, stride=400//2):
  '''
  @Autor: Jonathan Martiñón

  @Descripción:   Función encargada de mostrar durante el análisis
                  un audio (dependiendo del conjunto seleccionado),
                  su forma y su espectograma.

  @Parámetros:

  conjunto        Conjunto del que se extraerá el audio   STR
  
  num             Cantidad de elmentos del conjunto       INT 

  nfft            tamaño de la muestra                    INT

  window          tamaño de la ventana                    INT

  stride          Tamaño del salto entre ventanas         INT

  @Devuelve:

  data            Arreglo de (n,80,80,1) para cada        NUMPY.ARRAY
                  conjunto
  '''
  
  if conjunto == "Entrenamiento":
    # Generamos el nombre del audio
    name_audio = "Audio_Train"

  elif conjunto == "Validacion":
    # Generamos el nombre del audio
    name_audio = "Audio_Validation"

  else:
    # Generamos el nombre del audio
    name_audio = "Audio_Test"

  for i in range(0,num):


    # Leemos el audio
    audio = tfio.audio.AudioIOTensor("./Data/"+conjunto+"/"+name_audio+str(i)+".wav")

    # Convertimos a tensor
    audio_tensor = tf.squeeze(audio[:], axis=[-1])

    # Generamos nuestro spectograma
    spectrogram_crud = tfio.audio.spectrogram(
        audio_tensor, nfft=nfft, window=window, stride=stride)
    
    # Convertimos a Decibeles
    spectrogram = tfio.audio.dbscale(spectrogram_crud, top_db=80)

    # Ajustamos la dimensión a 80,80,1
    new_spectrogram = spectrogram.numpy().reshape(80,80,1)

    # Agregamos al conjunto
    if i == 0:
      # En caso de ser el primero, será nuestro arreglo base
      data = np.array([new_spectrogram])
    else:
      # En otro caso, concatenaremos para finalizar con algo de la forma
      # (n,80,80,1) Similar a la forma de trabajo de los datasets de tf.
      data = np.append(data,[new_spectrogram],axis=0)
    
    # Nuestra bandera para conocer el avance
    if i%1000 == 0:
      print(f"Estamos en el audio: {name_audio}{i}.wav")

  return data

# %% [markdown]
# ---
# # 3.) Pre-procesamiento
# ---

# %% [markdown]
# ## 3.1 Carga de datos

# %% [markdown]
# Montamos drive, para realizar la extracción de los datos a utilizar.

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Para los casos de *recarga* del notebook, eliminamos la carpeta datos, y evitamos que se dupliquen los datos

# %%
# !rm -r "Data"

# %% [markdown]
# Movemos los archivos a una carpeta específica (./Data), para no tener que buscarlos o ingresar la dirección completa.
#
# Comenzamos por descargar los metadatos

# %%
# !mkdir "./Data"
# !cp "drive/MyDrive/Proyecto_MDA/Validacion.csv" "Data"
# !cp "drive/MyDrive/Proyecto_MDA/Entrenamiento.csv" "Data"
# !cp "drive/MyDrive/Proyecto_MDA/Prueba.csv" "Data"

# %% [markdown]
# Posteriormente, cargamos cada uno de los audios

# %%
# !unzip -q "drive/My Drive/Proyecto_MDA/Audios_Prueba.zip" -d "./Data"
# !unzip -q "drive/My Drive/Proyecto_MDA/Audios_Validacion.zip" -d "./Data"
# !unzip -q "drive/My Drive/Proyecto_MDA/Audio_Entrenamiento.zip" -d "./Data"

# %% [markdown]
# Una vez que ya contamos con los archivos necesarios, procedemos a desmontar nuestro drive.

# %%
drive.flush_and_unmount()

# %% [markdown]
# Damos una pre-visualización de los datos que contamos

# %%
! ls -R {'Data'} | head -8
# Out:
# Data:
# Entrenamiento
# Entrenamiento.csv
# Prueba
# Prueba.csv
# Validacion
# Validacion.csv

# %% [markdown]
# ## 3.2) Lectura de Datos

# %% [markdown]
# Leemos los *csv* que contienen información acerca de nuestros audios.

# %%
entrenamiento_df = pd.read_csv("./Data/Entrenamiento.csv")
validacion_df = pd.read_csv("./Data/Validacion.csv")
prueba_df = pd.read_csv("./Data/Prueba.csv")

# %% [markdown]
# Generamos una columna con los datos a predecir (el número de hablantes en el audio)

# %%
entrenamiento_df['Speakers_Class'] = entrenamiento_df['Speakers'] - 1
validacion_df['Speakers_Class'] = validacion_df['Speakers'] - 1
prueba_df['Speakers_Class'] = prueba_df['Speakers'] - 1

# %% [markdown]
# ## 3.3) Análisis de datos

# %% [markdown]
# ### 3.3.1) Balance de datos

# %%
colors = ["deepskyblue","steelblue","paleturquoise"]

# %%
plt.figure(figsize=(14,14))

plt.subplot(1,3,1)
plt.pie(entrenamiento_df["Speakers"].value_counts(), 
        labels=entrenamiento_df["Speakers"].value_counts().index,
        autopct="%1.1f%%", colors=colors)
plt.title("Hablantes en el conjunto de Entrenamiento")

plt.subplot(1,3,2)
plt.pie(validacion_df["Speakers"].value_counts(), 
        labels=validacion_df["Speakers"].value_counts().index,
        autopct="%1.1f%%", colors=colors)
plt.title("Hablantes en el conjunto de Validación")

plt.subplot(1,3,3)
plt.pie(prueba_df["Speakers"].value_counts(), 
        labels=prueba_df["Speakers"].value_counts().index,
        autopct="%1.1f%%", colors=colors)
plt.title("Hablantes en el conjunto de Prueba")

plt.tight_layout()
plt.show()

# %% [markdown]
# De las figuras anteriores, podremos observar que nuestros datos se encuentran completamente balanceados (En cuanto al número de hablantes, que es lo que nos interesa).

# %% [markdown]
# ### 3.3.2) Metadatos

# %%
entrenamiento_df.head()
# Out:
#                                             Waveform  ...  Speakers_Class
# 0  [-0.00354004 -0.00354004 -0.00372314 ...  0.00...  ...               0
# 1  [-0.05560303 -0.03948975 -0.01425171 ...  0.06...  ...               0
# 2  [0.08041382 0.10652161 0.13059998 ... 0.017501...  ...               1
# 3  [0.00216675 0.00177002 0.00131226 ... 0.022705...  ...               0
# 4  [ 0.0064799   0.00262451  0.00343831 ... -0.00...  ...               2
#
# [5 rows x 6 columns]

# %%
validacion_df.head()
# Out:
#                                             Waveform  ...  Speakers_Class
# 0  [ 0.0045166   0.00930786 -0.00366211 ...  0.02...  ...               0
# 1  [ 0.02026367  0.02442932  0.02787781 ... -0.00...  ...               1
# 2  [-0.03646851 -0.03983561 -0.04340617 ... -0.03...  ...               2
# 3  [ 0.02868652  0.0123291   0.00295003 ... -0.02...  ...               2
# 4  [0.01849365 0.02142334 0.01538086 ... 0.020345...  ...               2
#
# [5 rows x 6 columns]

# %%
prueba_df.head()
# Out:
#                                             Waveform  ...  Speakers_Class
# 0  [ 0.00117493  0.00216675  0.0037384  ... -0.01...  ...               1
# 1  [-3.0517578e-05  1.8310547e-04  2.5939941e-04 ...  ...               1
# 2  [-0.03262329 -0.03387451 -0.03366089 ...  0.00...  ...               0
# 3  [-0.03912354 -0.02819824 -0.02289836 ... -0.10...  ...               2
# 4  [ 0.00628662  0.01490784  0.01811218 ... -0.01...  ...               1
#
# [5 rows x 6 columns]

# %% [markdown]
# Tal cual podemos observar, existen 6 columnas para cada conjunto:
# - **Waveform:** Una breve ilustración (string) de lo que es el audio
# - **Speakers:** Cantidad de hablantes en el audio
# - **Speakers_Sex:** Distribución de Hablantes (M: Masculino, F: Femenino)
# - **F:** Cantidad de hablantes femeninos
# - **M:** Cantidad de hablantes masculinos
# - **Speakers_Class:** Clase a la que pertenece el audio

# %% [markdown]
# ### 3.3.3) Audios

# %%
presenta_onda_spect_y_audio(entrenamiento_df, conjunto="Entrenamiento")

# %%
presenta_onda_spect_y_audio(validacion_df, conjunto="Validacion")

# %%
presenta_onda_spect_y_audio(prueba_df, conjunto="Prueba")

# %% [markdown]
# # 4.) Generación de Conjuntos

# %% [markdown]
# ## 4.1) Valores en X

# %%
start = time()
val_data = genera_conjunto(conjunto = "Validacion",num = 10000)
print(f"Tardó:{round((time()-start)/60,2)} minutos")
# Out:
# Estamos en el audio: Audio_Validation0.wav
# Estamos en el audio: Audio_Validation1000.wav
# Estamos en el audio: Audio_Validation2000.wav
# Estamos en el audio: Audio_Validation3000.wav
# Estamos en el audio: Audio_Validation4000.wav
# Estamos en el audio: Audio_Validation5000.wav
# Estamos en el audio: Audio_Validation6000.wav
# Estamos en el audio: Audio_Validation7000.wav
# Estamos en el audio: Audio_Validation8000.wav
# Estamos en el audio: Audio_Validation9000.wav
# Tardó:7.28 minutos

# %%
val_data.shape
# Out:
# (10000, 80, 80, 1)

# %%
start = time()
test_data = genera_conjunto(conjunto = "Prueba",num = 10000)
print(f"Tardó:{round((time()-start)/60,2)} minutos")
# Out:
# Estamos en el audio: Audio_Test0.wav
# Estamos en el audio: Audio_Test1000.wav
# Estamos en el audio: Audio_Test2000.wav
# Estamos en el audio: Audio_Test3000.wav
# Estamos en el audio: Audio_Test4000.wav
# Estamos en el audio: Audio_Test5000.wav
# Estamos en el audio: Audio_Test6000.wav
# Estamos en el audio: Audio_Test7000.wav
# Estamos en el audio: Audio_Test8000.wav
# Estamos en el audio: Audio_Test9000.wav
# Tardó:6.94 minutos

# %%
test_data.shape
# Out:
# (10000, 80, 80, 1)

# %%
start = time()
train_data = genera_conjunto(num = 30000)
print(f"Tardó:{round((time()-start)/60,2)} minutos")
# Out:
# Estamos en el audio: Audio_Train0.wav
# Estamos en el audio: Audio_Train1000.wav
# Estamos en el audio: Audio_Train2000.wav
# Estamos en el audio: Audio_Train3000.wav
# Estamos en el audio: Audio_Train4000.wav
# Estamos en el audio: Audio_Train5000.wav
# Estamos en el audio: Audio_Train6000.wav
# Estamos en el audio: Audio_Train7000.wav
# Estamos en el audio: Audio_Train8000.wav
# Estamos en el audio: Audio_Train9000.wav
# Estamos en el audio: Audio_Train10000.wav
# Estamos en el audio: Audio_Train11000.wav
# Estamos en el audio: Audio_Train12000.wav
# Estamos en el audio: Audio_Train13000.wav
# Estamos en el audio: Audio_Train14000.wav
# Estamos en el audio: Audio_Train15000.wav
# Estamos en el audio: Audio_Train16000.wav
# Estamos en el audio: Audio_Train17000.wav
# Estamos en el audio: Audio_Train18000.wav
# Estamos en el audio: Audio_Train19000.wav
# Estamos en el audio: Audio_Train20000.wav
# Estamos en el audio: Audio_Train21000.wav
# Estamos en el audio: Audio_Train22000.wav
# Estamos en el audio: Audio_Train23000.wav
# Estamos en el audio: Audio_Train24000.wav
# Estamos en el audio: Audio_Train25000.wav
# Estamos en el audio: Audio_Train26000.wav
# Estamos en el audio: Audio_Train27000.wav
# Estamos en el audio: Audio_Train28000.wav
# Estamos en el audio: Audio_Train29000.wav
# Tardó:54.15 minutos

# %%
train_data.shape
# Out:
# (30000, 80, 80, 1)

# %% [markdown]
# ## 4.2) Valores en Y

# %%
train_labels=entrenamiento_df["Speakers_Class"][:30000].values.reshape(-1,1)
test_labels=prueba_df["Speakers_Class"][:].values.reshape(-1,1)
val_labels=validacion_df["Speakers_Class"][:].values.reshape(-1,1)

# %%
train_labels.shape, test_labels.shape, val_labels.shape
# Out:
# ((30000, 1), (10000, 1), (10000, 1))

# %% [markdown]
# # 5.) Modelado
#
# Trabajaremos con 2 modelos distintos

# %% [markdown]
# ## 5.1) Modelo1
#
# Nuestro primer modelo es una extensión del ejemplo desarrollado por Tensorflow en su página para [redes convolucionales](https://www.tensorflow.org/tutorials/images/cnn)

# %%
model = models.Sequential()
model.add(layers.Conv2D(80, (3, 3), activation='relu', input_shape=(80, 80,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(80, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(160, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.4))
model.add(layers.Conv2D(160, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(160, activation='softmax'))
model.add(layers.Dense(3))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 78, 78, 80)        800
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 39, 39, 80)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 39, 39, 80)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 37, 37, 80)        57680
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 18, 18, 80)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 18, 18, 80)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 160)       115360
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 160)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 160)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 6, 6, 160)         230560
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 5760)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 160)               921760
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 483
# =================================================================
# Total params: 1,326,643
# Trainable params: 1,326,643
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5.2) Modelo 2
# El segundo modelo

# %%
model2 = models.Sequential()
model2.add(layers.Conv2D(80, (3, 3), input_shape=(80, 80,1)))
model2.add(layers.BatchNormalization())
model2.add(layers.ReLU())
model2.add(layers.MaxPool2D((2, 2)))
model2.add(layers.Dropout(0.2))
model2.add(layers.Conv2D(80, (3, 3)))
model2.add(layers.BatchNormalization())
model2.add(layers.ReLU())
model2.add(layers.MaxPool2D((2, 2)))
model2.add(layers.Dropout(0.4))
model2.add(layers.Conv2D(160, (3, 3)))
model2.add(layers.GlobalAveragePooling2D())
model2.add(layers.Flatten())
model.add(layers.Dense(160, activation='softmax'))
model2.add(layers.Dense(3))

# %%
model2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 78, 78, 80)        800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 78, 78, 80)        320
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 78, 78, 80)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 39, 39, 80)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 39, 39, 80)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 37, 37, 80)        57680
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 37, 37, 80)        320
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 37, 37, 80)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 18, 18, 80)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 18, 18, 80)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 160)       115360
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 160)               0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 160)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 483
# =================================================================
# Total params: 174,963
# Trainable params: 174,643
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# # 6.) Compilando y entrenando el modelo

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
with tf.device('/device:GPU:0'):
  history = model.fit(train_data, train_labels, epochs=100, 
                    validation_data=(val_data, val_labels))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:4930: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 938/938 [==============================] - 40s 41ms/step - loss: 2.1799 - accuracy: 0.3324 - val_loss: 1.1297 - val_accuracy: 0.3275
# Epoch 2/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.1132 - accuracy: 0.3360 - val_loss: 1.1054 - val_accuracy: 0.3275
# Epoch 3/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.1033 - accuracy: 0.3336 - val_loss: 1.1020 - val_accuracy: 0.3275
# Epoch 4/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.1010 - accuracy: 0.3317 - val_loss: 1.1001 - val_accuracy: 0.3275
# Epoch 5/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.1001 - accuracy: 0.3372 - val_loss: 1.0997 - val_accuracy: 0.3313
# Epoch 6/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0997 - accuracy: 0.3318 - val_loss: 1.1000 - val_accuracy: 0.3313
# Epoch 7/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0993 - accuracy: 0.3349 - val_loss: 1.0994 - val_accuracy: 0.3412
# Epoch 8/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0995 - accuracy: 0.3286 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 9/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0993 - accuracy: 0.3336 - val_loss: 1.0991 - val_accuracy: 0.3412
# Epoch 10/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0994 - accuracy: 0.3300 - val_loss: 1.0991 - val_accuracy: 0.3275
# Epoch 11/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0992 - accuracy: 0.3292 - val_loss: 1.0986 - val_accuracy: 0.3412
# Epoch 12/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0992 - accuracy: 0.3353 - val_loss: 1.1010 - val_accuracy: 0.3275
# Epoch 13/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0992 - accuracy: 0.3329 - val_loss: 1.0990 - val_accuracy: 0.3275
# Epoch 14/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0991 - accuracy: 0.3305 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 15/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0995 - accuracy: 0.3270 - val_loss: 1.0986 - val_accuracy: 0.3313
# Epoch 16/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0992 - accuracy: 0.3310 - val_loss: 1.0990 - val_accuracy: 0.3412
# Epoch 17/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0992 - accuracy: 0.3298 - val_loss: 1.0993 - val_accuracy: 0.3275
# Epoch 18/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0990 - accuracy: 0.3349 - val_loss: 1.0989 - val_accuracy: 0.3313
# Epoch 19/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0991 - accuracy: 0.3365 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 20/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0991 - accuracy: 0.3374 - val_loss: 1.0990 - val_accuracy: 0.3313
# Epoch 21/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0991 - accuracy: 0.3353 - val_loss: 1.0992 - val_accuracy: 0.3412
# Epoch 22/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0991 - accuracy: 0.3335 - val_loss: 1.0996 - val_accuracy: 0.3313
# Epoch 23/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0990 - accuracy: 0.3309 - val_loss: 1.0986 - val_accuracy: 0.3412
# Epoch 24/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0990 - accuracy: 0.3310 - val_loss: 1.0989 - val_accuracy: 0.3412
# Epoch 25/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0992 - accuracy: 0.3320 - val_loss: 1.0986 - val_accuracy: 0.3412
# Epoch 26/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0989 - accuracy: 0.3369 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 27/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0990 - accuracy: 0.3360 - val_loss: 1.0987 - val_accuracy: 0.3412
# Epoch 28/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0991 - accuracy: 0.3319 - val_loss: 1.0988 - val_accuracy: 0.3412
# Epoch 29/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0991 - accuracy: 0.3342 - val_loss: 1.0987 - val_accuracy: 0.3313
# Epoch 30/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0992 - accuracy: 0.3292 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 31/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0990 - accuracy: 0.3311 - val_loss: 1.0991 - val_accuracy: 0.3412
# Epoch 32/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0991 - accuracy: 0.3330 - val_loss: 1.1000 - val_accuracy: 0.3313
# Epoch 33/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0991 - accuracy: 0.3332 - val_loss: 1.0996 - val_accuracy: 0.3313
# Epoch 34/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0990 - accuracy: 0.3349 - val_loss: 1.0986 - val_accuracy: 0.3313
# Epoch 35/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0991 - accuracy: 0.3334 - val_loss: 1.0991 - val_accuracy: 0.3275
# Epoch 36/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0989 - accuracy: 0.3382 - val_loss: 1.0988 - val_accuracy: 0.3313
# Epoch 37/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0992 - accuracy: 0.3329 - val_loss: 1.0988 - val_accuracy: 0.3313
# Epoch 38/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0990 - accuracy: 0.3295 - val_loss: 1.0986 - val_accuracy: 0.3412
# Epoch 39/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0990 - accuracy: 0.3322 - val_loss: 1.0986 - val_accuracy: 0.3412
# Epoch 40/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0992 - accuracy: 0.3309 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 41/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0991 - accuracy: 0.3329 - val_loss: 1.0997 - val_accuracy: 0.3275
# Epoch 42/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0991 - accuracy: 0.3301 - val_loss: 1.0996 - val_accuracy: 0.3313
# Epoch 43/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0988 - accuracy: 0.3365 - val_loss: 1.0991 - val_accuracy: 0.3313
# Epoch 44/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0989 - accuracy: 0.3357 - val_loss: 1.0995 - val_accuracy: 0.3275
# Epoch 45/100
# 938/938 [==============================] - 39s 41ms/step - loss: 1.0989 - accuracy: 0.3347 - val_loss: 1.0999 - val_accuracy: 0.3275
# Epoch 46/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0991 - accuracy: 0.3265 - val_loss: 1.0986 - val_accuracy: 0.3313
# Epoch 47/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0989 - accuracy: 0.3351 - val_loss: 1.0993 - val_accuracy: 0.3313
# Epoch 48/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0989 - accuracy: 0.3345 - val_loss: 1.0990 - val_accuracy: 0.3275
# Epoch 49/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0990 - accuracy: 0.3326 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 50/100
# 938/938 [==============================] - 37s 40ms/step - loss: 1.0989 - accuracy: 0.3341 - val_loss: 1.0995 - val_accuracy: 0.3275
# Epoch 51/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0988 - accuracy: 0.3355 - val_loss: 1.1001 - val_accuracy: 0.3275
# Epoch 52/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0990 - accuracy: 0.3325 - val_loss: 1.0995 - val_accuracy: 0.3275
# Epoch 53/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0990 - accuracy: 0.3336 - val_loss: 1.0987 - val_accuracy: 0.3313
# Epoch 54/100
# 938/938 [==============================] - 37s 40ms/step - loss: 1.0991 - accuracy: 0.3322 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 55/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0989 - accuracy: 0.3345 - val_loss: 1.0986 - val_accuracy: 0.3313
# Epoch 56/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0989 - accuracy: 0.3315 - val_loss: 1.0986 - val_accuracy: 0.3412
# Epoch 57/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0989 - accuracy: 0.3350 - val_loss: 1.0986 - val_accuracy: 0.3412
# Epoch 58/100
# 938/938 [==============================] - 37s 40ms/step - loss: 1.0990 - accuracy: 0.3308 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 59/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0990 - accuracy: 0.3301 - val_loss: 1.0990 - val_accuracy: 0.3275
# Epoch 60/100
# 938/938 [==============================] - 37s 40ms/step - loss: 1.0990 - accuracy: 0.3298 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 61/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0990 - accuracy: 0.3302 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 62/100
# 938/938 [==============================] - 37s 40ms/step - loss: 1.0990 - accuracy: 0.3331 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 63/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0987 - accuracy: 0.3382 - val_loss: 1.0998 - val_accuracy: 0.3313
# Epoch 64/100
# 938/938 [==============================] - 37s 40ms/step - loss: 1.0990 - accuracy: 0.3296 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 65/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0990 - accuracy: 0.3287 - val_loss: 1.0987 - val_accuracy: 0.3313
# Epoch 66/100
# 938/938 [==============================] - 37s 40ms/step - loss: 1.0989 - accuracy: 0.3346 - val_loss: 1.0988 - val_accuracy: 0.3313
# Epoch 67/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0990 - accuracy: 0.3321 - val_loss: 1.0990 - val_accuracy: 0.3313
# Epoch 68/100
# 938/938 [==============================] - 37s 40ms/step - loss: 1.0989 - accuracy: 0.3340 - val_loss: 1.0986 - val_accuracy: 0.3412
# Epoch 69/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0990 - accuracy: 0.3299 - val_loss: 1.0991 - val_accuracy: 0.3313
# Epoch 70/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0990 - accuracy: 0.3293 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 71/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0989 - accuracy: 0.3316 - val_loss: 1.0987 - val_accuracy: 0.3412
# Epoch 72/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0990 - accuracy: 0.3280 - val_loss: 1.0996 - val_accuracy: 0.3313
# Epoch 73/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0989 - accuracy: 0.3305 - val_loss: 1.0989 - val_accuracy: 0.3313
# Epoch 74/100
# 938/938 [==============================] - 37s 40ms/step - loss: 1.0989 - accuracy: 0.3305 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 75/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0988 - accuracy: 0.3293 - val_loss: 1.0985 - val_accuracy: 0.3313
# Epoch 76/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0989 - accuracy: 0.3303 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 77/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0989 - accuracy: 0.3303 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 78/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0988 - accuracy: 0.3346 - val_loss: 1.0987 - val_accuracy: 0.3412
# Epoch 79/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0988 - accuracy: 0.3341 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 80/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0988 - accuracy: 0.3343 - val_loss: 1.0986 - val_accuracy: 0.3412
# Epoch 81/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0989 - accuracy: 0.3314 - val_loss: 1.0989 - val_accuracy: 0.3275
# Epoch 82/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0988 - accuracy: 0.3357 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 83/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0988 - accuracy: 0.3353 - val_loss: 1.0991 - val_accuracy: 0.3313
# Epoch 84/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0988 - accuracy: 0.3323 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 85/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0989 - accuracy: 0.3319 - val_loss: 1.0986 - val_accuracy: 0.3313
# Epoch 86/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0988 - accuracy: 0.3329 - val_loss: 1.0987 - val_accuracy: 0.3412
# Epoch 87/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0989 - accuracy: 0.3294 - val_loss: 1.0993 - val_accuracy: 0.3275
# Epoch 88/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0988 - accuracy: 0.3327 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 89/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0988 - accuracy: 0.3319 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 90/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0988 - accuracy: 0.3337 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 91/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0988 - accuracy: 0.3298 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 92/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0989 - accuracy: 0.3281 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 93/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0988 - accuracy: 0.3285 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 94/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0988 - accuracy: 0.3279 - val_loss: 1.0987 - val_accuracy: 0.3313
# Epoch 95/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0988 - accuracy: 0.3332 - val_loss: 1.0985 - val_accuracy: 0.3412
# Epoch 96/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0987 - accuracy: 0.3329 - val_loss: 1.0988 - val_accuracy: 0.3412
# Epoch 97/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0988 - accuracy: 0.3346 - val_loss: 1.0988 - val_accuracy: 0.3313
# Epoch 98/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0988 - accuracy: 0.3313 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 99/100
# 938/938 [==============================] - 38s 41ms/step - loss: 1.0988 - accuracy: 0.3330 - val_loss: 1.0989 - val_accuracy: 0.3313
# Epoch 100/100
# 938/938 [==============================] - 38s 40ms/step - loss: 1.0987 - accuracy: 0.3323 - val_loss: 1.0993 - val_accuracy: 0.3313

# %%
with tf.device('/device:GPU:0'):
  history2 = model2.fit(train_data, train_labels, epochs=100, 
                    validation_data=(val_data, val_labels))
# Out:
# Epoch 1/100
# 938/938 [==============================] - 42s 44ms/step - loss: 0.8433 - accuracy: 0.6087 - val_loss: 0.8257 - val_accuracy: 0.6203
# Epoch 2/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.7280 - accuracy: 0.6597 - val_loss: 0.8411 - val_accuracy: 0.5965
# Epoch 3/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.7157 - accuracy: 0.6724 - val_loss: 0.9442 - val_accuracy: 0.5423
# Epoch 4/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.7022 - accuracy: 0.6782 - val_loss: 0.7141 - val_accuracy: 0.6571
# Epoch 5/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6959 - accuracy: 0.6791 - val_loss: 1.0495 - val_accuracy: 0.4697
# Epoch 6/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6834 - accuracy: 0.6879 - val_loss: 0.7662 - val_accuracy: 0.6290
# Epoch 7/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6761 - accuracy: 0.6901 - val_loss: 2.0623 - val_accuracy: 0.3718
# Epoch 8/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6663 - accuracy: 0.6966 - val_loss: 0.7001 - val_accuracy: 0.6859
# Epoch 9/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6580 - accuracy: 0.7002 - val_loss: 0.8361 - val_accuracy: 0.6043
# Epoch 10/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6495 - accuracy: 0.7029 - val_loss: 1.1552 - val_accuracy: 0.5054
# Epoch 11/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6392 - accuracy: 0.7141 - val_loss: 0.8904 - val_accuracy: 0.5736
# Epoch 12/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6353 - accuracy: 0.7137 - val_loss: 0.5624 - val_accuracy: 0.7454
# Epoch 13/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6288 - accuracy: 0.7169 - val_loss: 0.6866 - val_accuracy: 0.6906
# Epoch 14/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6137 - accuracy: 0.7258 - val_loss: 0.6660 - val_accuracy: 0.6989
# Epoch 15/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6097 - accuracy: 0.7279 - val_loss: 0.6212 - val_accuracy: 0.7176
# Epoch 16/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.6041 - accuracy: 0.7294 - val_loss: 0.9099 - val_accuracy: 0.5811
# Epoch 17/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5981 - accuracy: 0.7329 - val_loss: 0.5899 - val_accuracy: 0.7229
# Epoch 18/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5984 - accuracy: 0.7314 - val_loss: 0.5992 - val_accuracy: 0.7176
# Epoch 19/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5860 - accuracy: 0.7387 - val_loss: 0.8495 - val_accuracy: 0.6203
# Epoch 20/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5831 - accuracy: 0.7400 - val_loss: 0.5773 - val_accuracy: 0.7485
# Epoch 21/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5890 - accuracy: 0.7341 - val_loss: 0.9091 - val_accuracy: 0.5937
# Epoch 22/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5812 - accuracy: 0.7415 - val_loss: 0.5708 - val_accuracy: 0.7354
# Epoch 23/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5739 - accuracy: 0.7441 - val_loss: 0.6106 - val_accuracy: 0.7301
# Epoch 24/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5793 - accuracy: 0.7394 - val_loss: 0.6400 - val_accuracy: 0.7034
# Epoch 25/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5680 - accuracy: 0.7451 - val_loss: 0.6320 - val_accuracy: 0.7124
# Epoch 26/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5699 - accuracy: 0.7446 - val_loss: 0.5377 - val_accuracy: 0.7582
# Epoch 27/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5699 - accuracy: 0.7449 - val_loss: 0.6225 - val_accuracy: 0.7124
# Epoch 28/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5641 - accuracy: 0.7492 - val_loss: 0.5822 - val_accuracy: 0.7450
# Epoch 29/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5656 - accuracy: 0.7475 - val_loss: 0.5137 - val_accuracy: 0.7855
# Epoch 30/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5581 - accuracy: 0.7536 - val_loss: 0.8279 - val_accuracy: 0.6076
# Epoch 31/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5553 - accuracy: 0.7511 - val_loss: 0.5617 - val_accuracy: 0.7540
# Epoch 32/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5493 - accuracy: 0.7547 - val_loss: 0.5539 - val_accuracy: 0.7609
# Epoch 33/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5519 - accuracy: 0.7535 - val_loss: 0.5601 - val_accuracy: 0.7351
# Epoch 34/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5529 - accuracy: 0.7538 - val_loss: 0.5519 - val_accuracy: 0.7547
# Epoch 35/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5476 - accuracy: 0.7547 - val_loss: 0.5357 - val_accuracy: 0.7582
# Epoch 36/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5465 - accuracy: 0.7544 - val_loss: 0.5099 - val_accuracy: 0.7795
# Epoch 37/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5468 - accuracy: 0.7570 - val_loss: 0.5194 - val_accuracy: 0.7721
# Epoch 38/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5393 - accuracy: 0.7586 - val_loss: 0.6592 - val_accuracy: 0.7025
# Epoch 39/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5407 - accuracy: 0.7576 - val_loss: 0.6518 - val_accuracy: 0.7102
# Epoch 40/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5375 - accuracy: 0.7616 - val_loss: 0.5822 - val_accuracy: 0.7413
# Epoch 41/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5395 - accuracy: 0.7576 - val_loss: 0.5433 - val_accuracy: 0.7623
# Epoch 42/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5365 - accuracy: 0.7595 - val_loss: 0.7574 - val_accuracy: 0.6461
# Epoch 43/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5310 - accuracy: 0.7625 - val_loss: 0.5039 - val_accuracy: 0.7801
# Epoch 44/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5309 - accuracy: 0.7651 - val_loss: 0.6307 - val_accuracy: 0.7143
# Epoch 45/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5283 - accuracy: 0.7631 - val_loss: 0.5169 - val_accuracy: 0.7649
# Epoch 46/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5291 - accuracy: 0.7643 - val_loss: 0.5124 - val_accuracy: 0.7785
# Epoch 47/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5245 - accuracy: 0.7636 - val_loss: 0.6254 - val_accuracy: 0.7235
# Epoch 48/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5231 - accuracy: 0.7687 - val_loss: 0.5124 - val_accuracy: 0.7744
# Epoch 49/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5273 - accuracy: 0.7633 - val_loss: 0.5119 - val_accuracy: 0.7821
# Epoch 50/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5213 - accuracy: 0.7682 - val_loss: 0.5026 - val_accuracy: 0.7816
# Epoch 51/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5235 - accuracy: 0.7651 - val_loss: 0.5262 - val_accuracy: 0.7722
# Epoch 52/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5156 - accuracy: 0.7737 - val_loss: 0.6896 - val_accuracy: 0.6993
# Epoch 53/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5184 - accuracy: 0.7704 - val_loss: 0.5898 - val_accuracy: 0.7337
# Epoch 54/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5163 - accuracy: 0.7681 - val_loss: 0.5268 - val_accuracy: 0.7590
# Epoch 55/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5123 - accuracy: 0.7704 - val_loss: 0.6460 - val_accuracy: 0.7377
# Epoch 56/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5125 - accuracy: 0.7722 - val_loss: 0.5646 - val_accuracy: 0.7548
# Epoch 57/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5110 - accuracy: 0.7738 - val_loss: 0.6234 - val_accuracy: 0.7116
# Epoch 58/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5147 - accuracy: 0.7704 - val_loss: 0.5490 - val_accuracy: 0.7626
# Epoch 59/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5069 - accuracy: 0.7756 - val_loss: 0.5126 - val_accuracy: 0.7816
# Epoch 60/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5108 - accuracy: 0.7743 - val_loss: 0.8302 - val_accuracy: 0.6233
# Epoch 61/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5059 - accuracy: 0.7751 - val_loss: 0.4824 - val_accuracy: 0.7928
# Epoch 62/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5071 - accuracy: 0.7764 - val_loss: 0.6939 - val_accuracy: 0.7116
# Epoch 63/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5022 - accuracy: 0.7781 - val_loss: 0.7372 - val_accuracy: 0.6617
# Epoch 64/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5045 - accuracy: 0.7738 - val_loss: 0.5234 - val_accuracy: 0.7633
# Epoch 65/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5021 - accuracy: 0.7741 - val_loss: 0.5246 - val_accuracy: 0.7724
# Epoch 66/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5017 - accuracy: 0.7778 - val_loss: 0.5689 - val_accuracy: 0.7444
# Epoch 67/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4999 - accuracy: 0.7775 - val_loss: 0.6011 - val_accuracy: 0.7306
# Epoch 68/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.5009 - accuracy: 0.7783 - val_loss: 0.5676 - val_accuracy: 0.7455
# Epoch 69/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4997 - accuracy: 0.7764 - val_loss: 0.5246 - val_accuracy: 0.7714
# Epoch 70/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4955 - accuracy: 0.7802 - val_loss: 0.5322 - val_accuracy: 0.7744
# Epoch 71/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4908 - accuracy: 0.7848 - val_loss: 0.5831 - val_accuracy: 0.7441
# Epoch 72/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4957 - accuracy: 0.7797 - val_loss: 0.6298 - val_accuracy: 0.7272
# Epoch 73/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4900 - accuracy: 0.7823 - val_loss: 0.5612 - val_accuracy: 0.7548
# Epoch 74/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4956 - accuracy: 0.7780 - val_loss: 0.6461 - val_accuracy: 0.7055
# Epoch 75/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4896 - accuracy: 0.7827 - val_loss: 0.5414 - val_accuracy: 0.7698
# Epoch 76/100
# 938/938 [==============================] - 41s 43ms/step - loss: 0.4883 - accuracy: 0.7845 - val_loss: 0.5302 - val_accuracy: 0.7692
# Epoch 77/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4850 - accuracy: 0.7870 - val_loss: 0.6715 - val_accuracy: 0.7104
# Epoch 78/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4874 - accuracy: 0.7830 - val_loss: 0.5688 - val_accuracy: 0.7447
# Epoch 79/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4845 - accuracy: 0.7839 - val_loss: 0.5117 - val_accuracy: 0.7864
# Epoch 80/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4858 - accuracy: 0.7841 - val_loss: 0.5412 - val_accuracy: 0.7599
# Epoch 81/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4847 - accuracy: 0.7840 - val_loss: 0.6062 - val_accuracy: 0.7247
# Epoch 82/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4806 - accuracy: 0.7885 - val_loss: 0.8034 - val_accuracy: 0.6296
# Epoch 83/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4830 - accuracy: 0.7868 - val_loss: 0.6059 - val_accuracy: 0.7301
# Epoch 84/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4785 - accuracy: 0.7887 - val_loss: 0.6621 - val_accuracy: 0.7147
# Epoch 85/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4830 - accuracy: 0.7880 - val_loss: 0.4718 - val_accuracy: 0.7958
# Epoch 86/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4782 - accuracy: 0.7860 - val_loss: 0.5462 - val_accuracy: 0.7639
# Epoch 87/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4784 - accuracy: 0.7884 - val_loss: 0.4992 - val_accuracy: 0.7803
# Epoch 88/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4752 - accuracy: 0.7901 - val_loss: 0.5988 - val_accuracy: 0.7296
# Epoch 89/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4728 - accuracy: 0.7909 - val_loss: 0.5180 - val_accuracy: 0.7737
# Epoch 90/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4766 - accuracy: 0.7883 - val_loss: 0.5000 - val_accuracy: 0.7757
# Epoch 91/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4714 - accuracy: 0.7904 - val_loss: 0.5090 - val_accuracy: 0.7755
# Epoch 92/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4712 - accuracy: 0.7920 - val_loss: 0.5299 - val_accuracy: 0.7735
# Epoch 93/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4705 - accuracy: 0.7941 - val_loss: 0.4837 - val_accuracy: 0.7951
# Epoch 94/100
# 938/938 [==============================] - 41s 43ms/step - loss: 0.4704 - accuracy: 0.7917 - val_loss: 0.5790 - val_accuracy: 0.7366
# Epoch 95/100
# 938/938 [==============================] - 41s 43ms/step - loss: 0.4689 - accuracy: 0.7917 - val_loss: 0.5835 - val_accuracy: 0.7429
# Epoch 96/100
# 938/938 [==============================] - 41s 43ms/step - loss: 0.4685 - accuracy: 0.7951 - val_loss: 0.5857 - val_accuracy: 0.7307
# Epoch 97/100
# 938/938 [==============================] - 41s 43ms/step - loss: 0.4731 - accuracy: 0.7908 - val_loss: 0.6225 - val_accuracy: 0.7447
# Epoch 98/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4652 - accuracy: 0.7942 - val_loss: 0.4883 - val_accuracy: 0.7856
# Epoch 99/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4678 - accuracy: 0.7927 - val_loss: 0.5352 - val_accuracy: 0.7684
# Epoch 100/100
# 938/938 [==============================] - 40s 43ms/step - loss: 0.4666 - accuracy: 0.7939 - val_loss: 0.4791 - val_accuracy: 0.7882

# %% [markdown]
# # 7.) Evaluando los modelos

# %%
with tf.device('/device:GPU:0'):
  resultado_1 = model.evaluate(test_data, test_labels)
# Out:
# 313/313 [==============================] - 4s 13ms/step - loss: 1.0991 - accuracy: 0.3383

# %%
with tf.device('/device:GPU:0'):
  resultado_2 = model2.evaluate(test_data, test_labels)
# Out:
# 313/313 [==============================] - 4s 13ms/step - loss: 0.4808 - accuracy: 0.7864

# %% [markdown]
# # 8.) Interpretándo resultados

# %%
hist = pd.DataFrame(history.history)
hist2 = pd.DataFrame(history2.history)

# %%
plt.figure(figsize=(14,6))

plt.plot(hist["accuracy"],label="Acc Train Modelo 1",marker="o",color="green")
plt.plot(hist2["accuracy"],label="Acc Train Model 2",marker="*",color="limegreen")
plt.plot(hist["val_accuracy"],label="Acc Eval Model1",marker="o",color="purple")
plt.plot(hist2["val_accuracy"],label="Acc Eval Model 2",marker="*",color="violet")

plt.title('Comparación de Accuracy ',fontsize = 16)
plt.legend()
plt.xticks(np.arange(0,len(history.history["accuracy"]),2),
           np.arange(1,len(history.history["accuracy"])+1,2))
plt.xlabel("Épocas",fontsize = 14)
plt.ylim(0,1)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,6))


plt.plot(hist2["loss"],label="Loss Train Model 2",marker="*",color="limegreen")
plt.plot(hist["val_loss"],label="Loss Eval Model 1",marker="o",color="green")
plt.plot(hist["loss"],label="Loss Train Model 1",marker="o",color="purple")
plt.plot(hist2["val_loss"],label="Loss Eval Model 2",marker="*",color="violet")
plt.title('Pérdida',fontsize = 16)
plt.legend()
plt.xticks(np.arange(0,len(history2.history["accuracy"]),2),
           np.arange(1,len(history2.history["accuracy"])+1,2))
plt.xlabel("Épocas",fontsize = 14)
plt.tight_layout()
plt.show()
